# %%
import pandas as pd
from pprint import pprint
from util.managers.DataframeManager import DataframeManager
from util.managers.DataframeManager import ColumnName
from util.managers.CountryCodeManager import CountryCodeManager
from util.managers.UnitConverterManager import UnitConverterManager

# %% [markdown]
# # Variables used across the notebook and not changed

# %%
DATASET_ID = "T005"
dataframeManager = DataframeManager(DATASET_ID)
countryCodeManager = CountryCodeManager()

# %% [markdown]
# # Opening the dataset

# %%
filename = "v50_CO2_excl_short-cycle_org_C_1970_2018.csv"
path = "/Users/hlinero/Desktop/iTEM Material/raw dataset/T005/{}".format(filename)
df = dataframeManager.get_dataframe_from_csv_file(path)
df
# Out:
#          IPCC-Annex   World Region ISO_A3           Name      IPCC  \
# 0           Annex_I         Canada    CAN         Canada   1.A.1.a
# 1           Annex_I         Canada    CAN         Canada  1.A.1.bc
# 2           Annex_I         Canada    CAN         Canada     1.A.2
# 3           Annex_I         Canada    CAN         Canada   1.A.3.a
# 4           Annex_I         Canada    CAN         Canada   1.A.3.b
# ...             ...            ...    ...            ...       ...
# 3358    Non-Annex_I        Oceania    WSM          Samoa     1.B.2
# 3359    Non-Annex_I        Oceania    WSM          Samoa     2.A.3
# 3360    Non-Annex_I        Oceania    WSM          Samoa       2.D
# 3361  Int. Shipping  Int. Shipping    SEA  Int. Shipping   1.A.3.d
# 3362  Int. Aviation  Int. Aviation    AIR  Int. Aviation   1.A.3.a
#
#                                        IPCC_description          1970  \
# 0         Main Activity Electricity and Heat Production   45000.00000
# 1     Petroleum Refining - Manufacture of Solid Fuel...   29500.00000
# 2             Manufacturing Industries and Construction   78300.00000
# 3                                        Civil Aviation    5970.00000
# 4                                   Road Transportation   64300.00000
# ...                                                 ...           ...
# 3358                                Oil and Natural Gas       0.00002
# 3359                                   Glass Production       0.00716
# 3360     Non-Energy Products from Fuels and Solvent Use       1.05000
# 3361                             Water-borne Navigation  354000.00000
# 3362                                     Civil Aviation  169000.00000
#
#               1971          1972           1973  ...          2009  \
# 0      49300.00000   50100.00000   51900.000000  ...  107000.00000
# 1      30600.00000   32200.00000   34300.000000  ...   96500.00000
# 2      77200.00000   79500.00000   96500.000000  ...   58500.00000
# 3       6140.00000    6470.00000    7340.000000  ...   10600.00000
# 4      66700.00000   71500.00000   78300.000000  ...  135000.00000
# ...            ...           ...            ...  ...           ...
# 3358       0.00002       0.00002       0.000039  ...       0.08840
# 3359       0.00727       0.00737       0.007440  ...       0.00924
# 3360       1.06000       1.09000       1.120000  ...       1.34000
# 3361  354000.00000  371000.00000  392000.000000  ...  616000.00000
# 3362  169000.00000  179000.00000  187000.000000  ...  435000.00000
#
#              2010          2011          2012           2013           2014  \
# 0     110000.0000  107000.00000  101000.00000  100896.528700  101494.798400
# 1     100000.0000  101000.00000  110000.00000  116569.985400  117834.506100
# 2      61800.0000   66200.00000   67300.00000   65597.043900   64490.986900
# 3       9970.0000   10700.00000   13200.00000   14438.269950   14326.140000
# 4     139000.0000  139000.00000  138000.00000  141366.555000  140104.328500
# ...           ...           ...           ...            ...            ...
# 3358       0.0763       0.07280       0.06830       0.056962       0.066701
# 3359       0.0093       0.00937       0.00945       0.009442       0.009519
# 3360       1.3200       1.32000       1.32000       1.302925       1.299835
# 3361  663000.0000  668000.00000  605000.00000  611213.371200  628002.812600
# 3362  458000.0000  473000.00000  480000.00000  490178.788900  504486.996300
#
#                2015           2016           2017           2018
# 0     102929.457500   99422.722410  100415.874400   89066.181500
# 1     117305.138200  123630.805000  126432.233500  131379.301800
# 2      62075.863900   63398.469410   64582.363050   63941.293950
# 3      14440.560000   14835.419060   14828.293890   14991.278770
# 4     140013.656200  138703.119800  138639.758100  140167.662000
# ...             ...            ...            ...            ...
# 3358       0.080413            NaN            NaN            NaN
# 3359       0.009596       0.009655       0.009714       0.009774
# 3360       1.296412       1.291261       1.286466       1.282006
# 3361  657324.001400  677043.721400  683814.158600  697490.441800
# 3362  529686.625500  553076.212300  559247.439500  564612.451700
#
# [3363 rows x 55 columns]

# %% [markdown]
# # Dropping Unnecessary columns
#     Rule: To comply with the latest template, we will drop all the unnecessary columns and rename others

# %%
df.drop(columns=["IPCC-Annex", "World Region", "ISO_A3"], inplace=True)
df
# Out:
#                Name      IPCC  \
# 0            Canada   1.A.1.a
# 1            Canada  1.A.1.bc
# 2            Canada     1.A.2
# 3            Canada   1.A.3.a
# 4            Canada   1.A.3.b
# ...             ...       ...
# 3358          Samoa     1.B.2
# 3359          Samoa     2.A.3
# 3360          Samoa       2.D
# 3361  Int. Shipping   1.A.3.d
# 3362  Int. Aviation   1.A.3.a
#
#                                        IPCC_description          1970  \
# 0         Main Activity Electricity and Heat Production   45000.00000
# 1     Petroleum Refining - Manufacture of Solid Fuel...   29500.00000
# 2             Manufacturing Industries and Construction   78300.00000
# 3                                        Civil Aviation    5970.00000
# 4                                   Road Transportation   64300.00000
# ...                                                 ...           ...
# 3358                                Oil and Natural Gas       0.00002
# 3359                                   Glass Production       0.00716
# 3360     Non-Energy Products from Fuels and Solvent Use       1.05000
# 3361                             Water-borne Navigation  354000.00000
# 3362                                     Civil Aviation  169000.00000
#
#               1971          1972           1973           1974           1975  \
# 0      49300.00000   50100.00000   51900.000000   50500.000000   54000.000000
# 1      30600.00000   32200.00000   34300.000000   32700.000000   34000.000000
# 2      77200.00000   79500.00000   96500.000000  100000.000000   90700.000000
# 3       6140.00000    6470.00000    7340.000000    8020.000000    8300.000000
# 4      66700.00000   71500.00000   78300.000000   81900.000000   85300.000000
# ...            ...           ...            ...            ...            ...
# 3358       0.00002       0.00002       0.000039       0.000039       0.000039
# 3359       0.00727       0.00737       0.007440       0.007510       0.007570
# 3360       1.06000       1.09000       1.120000       1.130000       1.160000
# 3361  354000.00000  371000.00000  392000.000000  366000.000000  341000.000000
# 3362  169000.00000  179000.00000  187000.000000  180000.000000  174000.000000
#
#               1976  ...          2009         2010          2011  \
# 0      58700.00000  ...  107000.00000  110000.0000  107000.00000
# 1      32400.00000  ...   96500.00000  100000.0000  101000.00000
# 2      90500.00000  ...   58500.00000   61800.0000   66200.00000
# 3       8170.00000  ...   10600.00000    9970.0000   10700.00000
# 4      90900.00000  ...  135000.00000  139000.0000  139000.00000
# ...            ...  ...           ...          ...           ...
# 3358       0.00002  ...       0.08840       0.0763       0.07280
# 3359       0.00762  ...       0.00924       0.0093       0.00937
# 3360       1.08000  ...       1.34000       1.3200       1.32000
# 3361  352000.00000  ...  616000.00000  663000.0000  668000.00000
# 3362  174000.00000  ...  435000.00000  458000.0000  473000.00000
#
#               2012           2013           2014           2015  \
# 0     101000.00000  100896.528700  101494.798400  102929.457500
# 1     110000.00000  116569.985400  117834.506100  117305.138200
# 2      67300.00000   65597.043900   64490.986900   62075.863900
# 3      13200.00000   14438.269950   14326.140000   14440.560000
# 4     138000.00000  141366.555000  140104.328500  140013.656200
# ...            ...            ...            ...            ...
# 3358       0.06830       0.056962       0.066701       0.080413
# 3359       0.00945       0.009442       0.009519       0.009596
# 3360       1.32000       1.302925       1.299835       1.296412
# 3361  605000.00000  611213.371200  628002.812600  657324.001400
# 3362  480000.00000  490178.788900  504486.996300  529686.625500
#
#                2016           2017           2018
# 0      99422.722410  100415.874400   89066.181500
# 1     123630.805000  126432.233500  131379.301800
# 2      63398.469410   64582.363050   63941.293950
# 3      14835.419060   14828.293890   14991.278770
# 4     138703.119800  138639.758100  140167.662000
# ...             ...            ...            ...
# 3358            NaN            NaN            NaN
# 3359       0.009655       0.009714       0.009774
# 3360       1.291261       1.286466       1.282006
# 3361  677043.721400  683814.158600  697490.441800
# 3362  553076.212300  559247.439500  564612.451700
#
# [3363 rows x 52 columns]
