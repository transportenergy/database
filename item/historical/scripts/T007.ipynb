# %%
import pandas as pd
import json
from pprint import pprint
from item.historical.scripts.util.managers.dataframe import DataframeManager
from item.historical.scripts.util.managers.dataframe import ColumnName
from item.historical.scripts.util.managers.country_code import CountryCodeManager
from item.common import paths

# %% [markdown]
# # Variables used across the noteboook and not changed

# %%
DATASET_ID = "T007"
dataframeManager = DataframeManager(DATASET_ID)
countryCodeManager = CountryCodeManager()

# %% [markdown]
# # Opening the dataset

# %%
path = paths['data']/'historical'/'input'/'T007_input.csv'
df = pd.read_csv(path, ";")
df
# Out:
#       Date Frequency                                               Geo  \
# 0     2000    Annual                     European Union (28 countries)
# 1     2007    Annual                     European Union (28 countries)
# 2     2000    Annual                     European Union (28 countries)
# 3     2002    Annual                     European Union (28 countries)
# 4     2005    Annual                     European Union (28 countries)
# ...    ...       ...                                               ...
# 2549  1990    Annual  Germany (until 1990 former territory of the FRG)
# 2550  1997    Annual  Germany (until 1990 former territory of the FRG)
# 2551  2004    Annual  Germany (until 1990 former territory of the FRG)
# 2552  2010    Annual  Germany (until 1990 former territory of the FRG)
# 2553  2015    Annual  Germany (until 1990 former territory of the FRG)
#
#          Measure  Value                                 Vehicle
# 0     Percentage    7.1                                  Trains
# 1     Percentage    7.1                                  Trains
# 2     Percentage   82.5                          Passenger cars
# 3     Percentage   83.4                          Passenger cars
# 4     Percentage   83.4                          Passenger cars
# ...          ...    ...                                     ...
# 2549  Percentage    9.1  Motor coaches, buses and trolley buses
# 2550  Percentage    7.1  Motor coaches, buses and trolley buses
# 2551  Percentage    6.7  Motor coaches, buses and trolley buses
# 2552  Percentage    6.0  Motor coaches, buses and trolley buses
# 2553  Percentage    6.0  Motor coaches, buses and trolley buses
#
# [2554 rows x 6 columns]

# %% [markdown]
# # Dropping unnecessary columns

# %%
df.drop(columns=["Frequency", "Measure" ], inplace = True)
df
# Out:
#       Date                                               Geo  Value  \
# 0     2000                     European Union (28 countries)    7.1
# 1     2007                     European Union (28 countries)    7.1
# 2     2000                     European Union (28 countries)   82.5
# 3     2002                     European Union (28 countries)   83.4
# 4     2005                     European Union (28 countries)   83.4
# ...    ...                                               ...    ...
# 2549  1990  Germany (until 1990 former territory of the FRG)    9.1
# 2550  1997  Germany (until 1990 former territory of the FRG)    7.1
# 2551  2004  Germany (until 1990 former territory of the FRG)    6.7
# 2552  2010  Germany (until 1990 former territory of the FRG)    6.0
# 2553  2015  Germany (until 1990 former territory of the FRG)    6.0
#
#                                      Vehicle
# 0                                     Trains
# 1                                     Trains
# 2                             Passenger cars
# 3                             Passenger cars
# 4                             Passenger cars
# ...                                      ...
# 2549  Motor coaches, buses and trolley buses
# 2550  Motor coaches, buses and trolley buses
# 2551  Motor coaches, buses and trolley buses
# 2552  Motor coaches, buses and trolley buses
# 2553  Motor coaches, buses and trolley buses
#
# [2554 rows x 4 columns]

# %% [markdown]
# # Renaming the "Geo" column to "Country"

# %%
dataframeManager.rename_column(current_name="Geo",df=df,new_name=ColumnName.COUNTRY.value)
df
# Out:
#       Date                                           Country  Value  \
# 0     2000                     European Union (28 countries)    7.1
# 1     2007                     European Union (28 countries)    7.1
# 2     2000                     European Union (28 countries)   82.5
# 3     2002                     European Union (28 countries)   83.4
# 4     2005                     European Union (28 countries)   83.4
# ...    ...                                               ...    ...
# 2549  1990  Germany (until 1990 former territory of the FRG)    9.1
# 2550  1997  Germany (until 1990 former territory of the FRG)    7.1
# 2551  2004  Germany (until 1990 former territory of the FRG)    6.7
# 2552  2010  Germany (until 1990 former territory of the FRG)    6.0
# 2553  2015  Germany (until 1990 former territory of the FRG)    6.0
#
#                                      Vehicle
# 0                                     Trains
# 1                                     Trains
# 2                             Passenger cars
# 3                             Passenger cars
# 4                             Passenger cars
# ...                                      ...
# 2549  Motor coaches, buses and trolley buses
# 2550  Motor coaches, buses and trolley buses
# 2551  Motor coaches, buses and trolley buses
# 2552  Motor coaches, buses and trolley buses
# 2553  Motor coaches, buses and trolley buses
#
# [2554 rows x 4 columns]

# %% [markdown]
# # Renaming the "Date" column to "Year"

# %%
dataframeManager.rename_column(current_name="Date",df=df,new_name=ColumnName.YEAR.value)
df
# Out:
#       Year                                           Country  Value  \
# 0     2000                     European Union (28 countries)    7.1
# 1     2007                     European Union (28 countries)    7.1
# 2     2000                     European Union (28 countries)   82.5
# 3     2002                     European Union (28 countries)   83.4
# 4     2005                     European Union (28 countries)   83.4
# ...    ...                                               ...    ...
# 2549  1990  Germany (until 1990 former territory of the FRG)    9.1
# 2550  1997  Germany (until 1990 former territory of the FRG)    7.1
# 2551  2004  Germany (until 1990 former territory of the FRG)    6.7
# 2552  2010  Germany (until 1990 former territory of the FRG)    6.0
# 2553  2015  Germany (until 1990 former territory of the FRG)    6.0
#
#                                      Vehicle
# 0                                     Trains
# 1                                     Trains
# 2                             Passenger cars
# 3                             Passenger cars
# 4                             Passenger cars
# ...                                      ...
# 2549  Motor coaches, buses and trolley buses
# 2550  Motor coaches, buses and trolley buses
# 2551  Motor coaches, buses and trolley buses
# 2552  Motor coaches, buses and trolley buses
# 2553  Motor coaches, buses and trolley buses
#
# [2554 rows x 4 columns]

# %% [markdown]
# # Adding the "Source" column
#     Rue: This dataset comes from Eurostat

# %%
dataframeManager.simple_column_insert(cell_value="Eurostat", dataframe=df, column_name= ColumnName.SOURCE.value)
df
# Out:
#         Source  Year                                           Country  Value  \
# 0     Eurostat  2000                     European Union (28 countries)    7.1
# 1     Eurostat  2007                     European Union (28 countries)    7.1
# 2     Eurostat  2000                     European Union (28 countries)   82.5
# 3     Eurostat  2002                     European Union (28 countries)   83.4
# 4     Eurostat  2005                     European Union (28 countries)   83.4
# ...        ...   ...                                               ...    ...
# 2549  Eurostat  1990  Germany (until 1990 former territory of the FRG)    9.1
# 2550  Eurostat  1997  Germany (until 1990 former territory of the FRG)    7.1
# 2551  Eurostat  2004  Germany (until 1990 former territory of the FRG)    6.7
# 2552  Eurostat  2010  Germany (until 1990 former territory of the FRG)    6.0
# 2553  Eurostat  2015  Germany (until 1990 former territory of the FRG)    6.0
#
#                                      Vehicle
# 0                                     Trains
# 1                                     Trains
# 2                             Passenger cars
# 3                             Passenger cars
# 4                             Passenger cars
# ...                                      ...
# 2549  Motor coaches, buses and trolley buses
# 2550  Motor coaches, buses and trolley buses
# 2551  Motor coaches, buses and trolley buses
# 2552  Motor coaches, buses and trolley buses
# 2553  Motor coaches, buses and trolley buses
#
# [2554 rows x 5 columns]

# %% [markdown]
# # Renaming the "Germany" country name
#     Rule: In this dataset, the country "Germany" appears as "Germany (until 1990 former territory of the FRG)." To make it consistent with the other datsasets, we will rename "Germany (until 1990 former territory of the FRG)" to just "Germany"

# %%
# variable holding the cleaned list of countries
cleaned_list_of_countries = []

# Cleaning the country names
for country in list(df["Country"]):
    if country == "Germany (until 1990 former territory of the FRG)":
        cleaned_list_of_countries.append("Germany")
    else:
        cleaned_list_of_countries.append(country)

# Ensure the new list of countries is the same size as the df
assert len(df) == len(cleaned_list_of_countries)

# Dropping the current country column
df.drop(columns=["Country" ], inplace = True)

# Adding the new country column
df.insert(2, ColumnName.COUNTRY.value, cleaned_list_of_countries, True)
df
# Out:
#         Source  Year                        Country  Value  \
# 0     Eurostat  2000  European Union (28 countries)    7.1
# 1     Eurostat  2007  European Union (28 countries)    7.1
# 2     Eurostat  2000  European Union (28 countries)   82.5
# 3     Eurostat  2002  European Union (28 countries)   83.4
# 4     Eurostat  2005  European Union (28 countries)   83.4
# ...        ...   ...                            ...    ...
# 2549  Eurostat  1990                        Germany    9.1
# 2550  Eurostat  1997                        Germany    7.1
# 2551  Eurostat  2004                        Germany    6.7
# 2552  Eurostat  2010                        Germany    6.0
# 2553  Eurostat  2015                        Germany    6.0
#
#                                      Vehicle
# 0                                     Trains
# 1                                     Trains
# 2                             Passenger cars
# 3                             Passenger cars
# 4                             Passenger cars
# ...                                      ...
# 2549  Motor coaches, buses and trolley buses
# 2550  Motor coaches, buses and trolley buses
# 2551  Motor coaches, buses and trolley buses
# 2552  Motor coaches, buses and trolley buses
# 2553  Motor coaches, buses and trolley buses
#
# [2554 rows x 5 columns]

# %% [markdown]
# # Getting the ISO code for each country

# %% [markdown]
# ## Determining which countries do not have an ISO code
#     Rule: As shown below, there are countries which do not have an ISO code. The mapping that will be done in order to handle those cases are as follows:
#        > European Union (28 countries) ----> EU28
#        > European Union (27 countries) ----> EU27
#        > Former Yugoslav Republic of Macedonia, the --> As in T005, we had problem with this country. We will do the same as in T005

# %%
list_of_countries = list(set(df[ColumnName.COUNTRY.value]))
countries_with_no_iso_code = countryCodeManager.get_list_of_countries_with_no_iso_code(list_of_countries)
countries_with_no_iso_code
# Out:
# ['European Union (27 countries)',
#  'Former Yugoslav Republic of Macedonia, the',
#  'European Union (28 countries)']

# %% [markdown]
# # Cleaning the list of countries to obtain their ISO code

# %%
country_column = list(df[ColumnName.COUNTRY.value])
list_of_iso_code = []

for country in country_column:
    if country == "European Union (28 countries)":
        code = "EU28"
    elif country == "European Union (27 countries)":
        code = "EU27"
    else:
        code = countryCodeManager.get_iso_code_for_country(country)

    # Appending the code to the list
    list_of_iso_code.append(code)
        
# Assert that the size of the list of iso codes is equivalent to the size of country column
assert len(list_of_iso_code) == len(country_column)
    
# Adding the ISO column to the dataframe
df.insert(2, ColumnName.ISO_CODE.value, list_of_iso_code, True)
df
# Out:
#         Source  Year ISO Code                        Country  Value  \
# 0     Eurostat  2000     EU28  European Union (28 countries)    7.1
# 1     Eurostat  2007     EU28  European Union (28 countries)    7.1
# 2     Eurostat  2000     EU28  European Union (28 countries)   82.5
# 3     Eurostat  2002     EU28  European Union (28 countries)   83.4
# 4     Eurostat  2005     EU28  European Union (28 countries)   83.4
# ...        ...   ...      ...                            ...    ...
# 2549  Eurostat  1990      DEU                        Germany    9.1
# 2550  Eurostat  1997      DEU                        Germany    7.1
# 2551  Eurostat  2004      DEU                        Germany    6.7
# 2552  Eurostat  2010      DEU                        Germany    6.0
# 2553  Eurostat  2015      DEU                        Germany    6.0
#
#                                      Vehicle
# 0                                     Trains
# 1                                     Trains
# 2                             Passenger cars
# 3                             Passenger cars
# 4                             Passenger cars
# ...                                      ...
# 2549  Motor coaches, buses and trolley buses
# 2550  Motor coaches, buses and trolley buses
# 2551  Motor coaches, buses and trolley buses
# 2552  Motor coaches, buses and trolley buses
# 2553  Motor coaches, buses and trolley buses
#
# [2554 rows x 6 columns]

# %% [markdown]
# # Getting the ITEM region for each ISO code

# %% [markdown]
# ## Determining which countries do not have an ITEM region
#     Rule: As seen below, EU27,EU28, N/A (which comes from Macedonia) do not have a region. Therefore, the following mapping will be done to assign a region
#     ISO code --> ITEM region
#     EU27 --> EU-27
#     EU28 --> EU-28

# %%
list_of_unique_iso_codes = list(set(df[ColumnName.ISO_CODE.value]))
iso_codes_with_no_region = countryCodeManager.get_list_of_iso_codes_with_no_region(list_of_unique_iso_codes)
iso_codes_with_no_region
# Out:
# ['N/A', 'EU28', 'EU27']

# %% [markdown]
# ## Assigning the ITEM region column

# %%
# Getting the complete list of iso codes
list_of_all_codes = df[ColumnName.ISO_CODE.value]

# Getting the list of regions
item_regions = countryCodeManager.get_list_of_regions_for_iso_codes(list_of_all_codes)

# Hardcoding the region value for WLD ISO Code
for index in range(0, len(list_of_all_codes)):
    if list_of_all_codes[index] == "EU27":
        item_regions[index] = "EU-27"
    elif list_of_all_codes[index] == "EU28":
        item_regions[index] = "EU-28"

# Adding the column to the dataframe
df.insert(3, ColumnName.ITEM_REGION.value, item_regions, True)
df
# Out:
#         Source  Year ISO Code Region                        Country  Value  \
# 0     Eurostat  2000     EU28  EU-28  European Union (28 countries)    7.1
# 1     Eurostat  2007     EU28  EU-28  European Union (28 countries)    7.1
# 2     Eurostat  2000     EU28  EU-28  European Union (28 countries)   82.5
# 3     Eurostat  2002     EU28  EU-28  European Union (28 countries)   83.4
# 4     Eurostat  2005     EU28  EU-28  European Union (28 countries)   83.4
# ...        ...   ...      ...    ...                            ...    ...
# 2549  Eurostat  1990      DEU  EU-27                        Germany    9.1
# 2550  Eurostat  1997      DEU  EU-27                        Germany    7.1
# 2551  Eurostat  2004      DEU  EU-27                        Germany    6.7
# 2552  Eurostat  2010      DEU  EU-27                        Germany    6.0
# 2553  Eurostat  2015      DEU  EU-27                        Germany    6.0
#
#                                      Vehicle
# 0                                     Trains
# 1                                     Trains
# 2                             Passenger cars
# 3                             Passenger cars
# 4                             Passenger cars
# ...                                      ...
# 2549  Motor coaches, buses and trolley buses
# 2550  Motor coaches, buses and trolley buses
# 2551  Motor coaches, buses and trolley buses
# 2552  Motor coaches, buses and trolley buses
# 2553  Motor coaches, buses and trolley buses
#
# [2554 rows x 7 columns]

# %% [markdown]
# # Adding the 'Variable' and 'Unit' columns
#     Rule: This dataset is associated to passenger data. Therefore, the variable is "Passenger Activity" and the unit is '% in total inland passenger-km / yr'

# %% [markdown]
# ## Variable column

# %%
dataframeManager.simple_column_insert(df, ColumnName.VARIABLE.value, "Passenger Activity", 4)
df
# Out:
#         Source  Year ISO Code Region            Variable  \
# 0     Eurostat  2000     EU28  EU-28  Passenger Activity
# 1     Eurostat  2007     EU28  EU-28  Passenger Activity
# 2     Eurostat  2000     EU28  EU-28  Passenger Activity
# 3     Eurostat  2002     EU28  EU-28  Passenger Activity
# 4     Eurostat  2005     EU28  EU-28  Passenger Activity
# ...        ...   ...      ...    ...                 ...
# 2549  Eurostat  1990      DEU  EU-27  Passenger Activity
# 2550  Eurostat  1997      DEU  EU-27  Passenger Activity
# 2551  Eurostat  2004      DEU  EU-27  Passenger Activity
# 2552  Eurostat  2010      DEU  EU-27  Passenger Activity
# 2553  Eurostat  2015      DEU  EU-27  Passenger Activity
#
#                             Country  Value  \
# 0     European Union (28 countries)    7.1
# 1     European Union (28 countries)    7.1
# 2     European Union (28 countries)   82.5
# 3     European Union (28 countries)   83.4
# 4     European Union (28 countries)   83.4
# ...                             ...    ...
# 2549                        Germany    9.1
# 2550                        Germany    7.1
# 2551                        Germany    6.7
# 2552                        Germany    6.0
# 2553                        Germany    6.0
#
#                                      Vehicle
# 0                                     Trains
# 1                                     Trains
# 2                             Passenger cars
# 3                             Passenger cars
# 4                             Passenger cars
# ...                                      ...
# 2549  Motor coaches, buses and trolley buses
# 2550  Motor coaches, buses and trolley buses
# 2551  Motor coaches, buses and trolley buses
# 2552  Motor coaches, buses and trolley buses
# 2553  Motor coaches, buses and trolley buses
#
# [2554 rows x 8 columns]

# %% [markdown]
# ## Unit column

# %%
dataframeManager.simple_column_insert(df, ColumnName.UNIT.value, "% in total inland passenger-km / yr", 5)
df
# Out:
#         Source  Year ISO Code Region            Variable  \
# 0     Eurostat  2000     EU28  EU-28  Passenger Activity
# 1     Eurostat  2007     EU28  EU-28  Passenger Activity
# 2     Eurostat  2000     EU28  EU-28  Passenger Activity
# 3     Eurostat  2002     EU28  EU-28  Passenger Activity
# 4     Eurostat  2005     EU28  EU-28  Passenger Activity
# ...        ...   ...      ...    ...                 ...
# 2549  Eurostat  1990      DEU  EU-27  Passenger Activity
# 2550  Eurostat  1997      DEU  EU-27  Passenger Activity
# 2551  Eurostat  2004      DEU  EU-27  Passenger Activity
# 2552  Eurostat  2010      DEU  EU-27  Passenger Activity
# 2553  Eurostat  2015      DEU  EU-27  Passenger Activity
#
#                                      Unit                        Country  \
# 0     % in total inland passenger-km / yr  European Union (28 countries)
# 1     % in total inland passenger-km / yr  European Union (28 countries)
# 2     % in total inland passenger-km / yr  European Union (28 countries)
# 3     % in total inland passenger-km / yr  European Union (28 countries)
# 4     % in total inland passenger-km / yr  European Union (28 countries)
# ...                                   ...                            ...
# 2549  % in total inland passenger-km / yr                        Germany
# 2550  % in total inland passenger-km / yr                        Germany
# 2551  % in total inland passenger-km / yr                        Germany
# 2552  % in total inland passenger-km / yr                        Germany
# 2553  % in total inland passenger-km / yr                        Germany
#
#       Value                                 Vehicle
# 0       7.1                                  Trains
# 1       7.1                                  Trains
# 2      82.5                          Passenger cars
# 3      83.4                          Passenger cars
# 4      83.4                          Passenger cars
# ...     ...                                     ...
# 2549    9.1  Motor coaches, buses and trolley buses
# 2550    7.1  Motor coaches, buses and trolley buses
# 2551    6.7  Motor coaches, buses and trolley buses
# 2552    6.0  Motor coaches, buses and trolley buses
# 2553    6.0  Motor coaches, buses and trolley buses
#
# [2554 rows x 9 columns]

# %% [markdown]
# # Adding the 'Service' column
#     Rule: Since all the variable is 'Passenger Activity' the service is 'Passenger'

# %%
dataframeManager.simple_column_insert(df, ColumnName.SERVICE.value, "Passenger", 6)
df
# Out:
#         Source  Year ISO Code Region            Variable  \
# 0     Eurostat  2000     EU28  EU-28  Passenger Activity
# 1     Eurostat  2007     EU28  EU-28  Passenger Activity
# 2     Eurostat  2000     EU28  EU-28  Passenger Activity
# 3     Eurostat  2002     EU28  EU-28  Passenger Activity
# 4     Eurostat  2005     EU28  EU-28  Passenger Activity
# ...        ...   ...      ...    ...                 ...
# 2549  Eurostat  1990      DEU  EU-27  Passenger Activity
# 2550  Eurostat  1997      DEU  EU-27  Passenger Activity
# 2551  Eurostat  2004      DEU  EU-27  Passenger Activity
# 2552  Eurostat  2010      DEU  EU-27  Passenger Activity
# 2553  Eurostat  2015      DEU  EU-27  Passenger Activity
#
#                                      Unit    Service  \
# 0     % in total inland passenger-km / yr  Passenger
# 1     % in total inland passenger-km / yr  Passenger
# 2     % in total inland passenger-km / yr  Passenger
# 3     % in total inland passenger-km / yr  Passenger
# 4     % in total inland passenger-km / yr  Passenger
# ...                                   ...        ...
# 2549  % in total inland passenger-km / yr  Passenger
# 2550  % in total inland passenger-km / yr  Passenger
# 2551  % in total inland passenger-km / yr  Passenger
# 2552  % in total inland passenger-km / yr  Passenger
# 2553  % in total inland passenger-km / yr  Passenger
#
#                             Country  Value  \
# 0     European Union (28 countries)    7.1
# 1     European Union (28 countries)    7.1
# 2     European Union (28 countries)   82.5
# 3     European Union (28 countries)   83.4
# 4     European Union (28 countries)   83.4
# ...                             ...    ...
# 2549                        Germany    9.1
# 2550                        Germany    7.1
# 2551                        Germany    6.7
# 2552                        Germany    6.0
# 2553                        Germany    6.0
#
#                                      Vehicle
# 0                                     Trains
# 1                                     Trains
# 2                             Passenger cars
# 3                             Passenger cars
# 4                             Passenger cars
# ...                                      ...
# 2549  Motor coaches, buses and trolley buses
# 2550  Motor coaches, buses and trolley buses
# 2551  Motor coaches, buses and trolley buses
# 2552  Motor coaches, buses and trolley buses
# 2553  Motor coaches, buses and trolley buses
#
# [2554 rows x 10 columns]

# %% [markdown]
# # Adding the 'Technology' and 'Fuel' columns
#     Rule: Since the dataset does not provide any information about 'technology' and 'fuel,' we set both values as 'All'

# %%
dataframeManager.simple_column_insert(df, ColumnName.TECHNOLOGY.value, "All", 7)
dataframeManager.simple_column_insert(df, ColumnName.FUEL.value, "All", 8)
df
# Out:
#         Source  Year ISO Code Region            Variable  \
# 0     Eurostat  2000     EU28  EU-28  Passenger Activity
# 1     Eurostat  2007     EU28  EU-28  Passenger Activity
# 2     Eurostat  2000     EU28  EU-28  Passenger Activity
# 3     Eurostat  2002     EU28  EU-28  Passenger Activity
# 4     Eurostat  2005     EU28  EU-28  Passenger Activity
# ...        ...   ...      ...    ...                 ...
# 2549  Eurostat  1990      DEU  EU-27  Passenger Activity
# 2550  Eurostat  1997      DEU  EU-27  Passenger Activity
# 2551  Eurostat  2004      DEU  EU-27  Passenger Activity
# 2552  Eurostat  2010      DEU  EU-27  Passenger Activity
# 2553  Eurostat  2015      DEU  EU-27  Passenger Activity
#
#                                      Unit    Service Technology Fuel  \
# 0     % in total inland passenger-km / yr  Passenger        All  All
# 1     % in total inland passenger-km / yr  Passenger        All  All
# 2     % in total inland passenger-km / yr  Passenger        All  All
# 3     % in total inland passenger-km / yr  Passenger        All  All
# 4     % in total inland passenger-km / yr  Passenger        All  All
# ...                                   ...        ...        ...  ...
# 2549  % in total inland passenger-km / yr  Passenger        All  All
# 2550  % in total inland passenger-km / yr  Passenger        All  All
# 2551  % in total inland passenger-km / yr  Passenger        All  All
# 2552  % in total inland passenger-km / yr  Passenger        All  All
# 2553  % in total inland passenger-km / yr  Passenger        All  All
#
#                             Country  Value  \
# 0     European Union (28 countries)    7.1
# 1     European Union (28 countries)    7.1
# 2     European Union (28 countries)   82.5
# 3     European Union (28 countries)   83.4
# 4     European Union (28 countries)   83.4
# ...                             ...    ...
# 2549                        Germany    9.1
# 2550                        Germany    7.1
# 2551                        Germany    6.7
# 2552                        Germany    6.0
# 2553                        Germany    6.0
#
#                                      Vehicle
# 0                                     Trains
# 1                                     Trains
# 2                             Passenger cars
# 3                             Passenger cars
# 4                             Passenger cars
# ...                                      ...
# 2549  Motor coaches, buses and trolley buses
# 2550  Motor coaches, buses and trolley buses
# 2551  Motor coaches, buses and trolley buses
# 2552  Motor coaches, buses and trolley buses
# 2553  Motor coaches, buses and trolley buses
#
# [2554 rows x 12 columns]

# %% [markdown]
# # Setting the 'Mode' and 'Vehicle Type' Columns based on the given data
#     Rule: The following is the mapping done for setting the mode:
#     Vehicle --> Mode --> Vehicle Type
#     Trains --> Rail --> All
#     Passenger cars --> Road --> LDV
#     Motor coaches, buses and trolley buses --> Road --> Bus

# %%
list(set(df["Vehicle"]))
# Out:
# ['Passenger cars', 'Motor coaches, buses and trolley buses', 'Trains']

# %%
# variables holding the mode and vehicle type
result_mode = []
result_vehicle_type = []

# Getting the mode and vehicle type of each row
for index, row in df.iterrows():
    vehicle = row['Vehicle']
    if vehicle == 'Trains':
        result_mode.append("Rail")
        result_vehicle_type.append("All")
    elif vehicle == 'Motor coaches, buses and trolley buses':
        result_mode.append("Road")
        result_vehicle_type.append("Bus")
    else:
        result_mode.append("Road")
        result_vehicle_type.append("LDV")

# Asserting that the len of the results
assert len(df) == len(result_mode)
assert len(df) == len(result_vehicle_type)

# Adding the columns to the dataframe
df.insert(7, ColumnName.MODE.value, result_mode, True)
df.insert(8, ColumnName.VEHICLE_TYPE.value, result_vehicle_type, True)

# Removing the 'Tra Mode' column
df.drop(columns=["Vehicle"], inplace = True)
df
# Out:
#         Source  Year ISO Code Region            Variable  \
# 0     Eurostat  2000     EU28  EU-28  Passenger Activity
# 1     Eurostat  2007     EU28  EU-28  Passenger Activity
# 2     Eurostat  2000     EU28  EU-28  Passenger Activity
# 3     Eurostat  2002     EU28  EU-28  Passenger Activity
# 4     Eurostat  2005     EU28  EU-28  Passenger Activity
# ...        ...   ...      ...    ...                 ...
# 2549  Eurostat  1990      DEU  EU-27  Passenger Activity
# 2550  Eurostat  1997      DEU  EU-27  Passenger Activity
# 2551  Eurostat  2004      DEU  EU-27  Passenger Activity
# 2552  Eurostat  2010      DEU  EU-27  Passenger Activity
# 2553  Eurostat  2015      DEU  EU-27  Passenger Activity
#
#                                      Unit    Service  Mode Vehicle Type  \
# 0     % in total inland passenger-km / yr  Passenger  Rail          All
# 1     % in total inland passenger-km / yr  Passenger  Rail          All
# 2     % in total inland passenger-km / yr  Passenger  Road          LDV
# 3     % in total inland passenger-km / yr  Passenger  Road          LDV
# 4     % in total inland passenger-km / yr  Passenger  Road          LDV
# ...                                   ...        ...   ...          ...
# 2549  % in total inland passenger-km / yr  Passenger  Road          Bus
# 2550  % in total inland passenger-km / yr  Passenger  Road          Bus
# 2551  % in total inland passenger-km / yr  Passenger  Road          Bus
# 2552  % in total inland passenger-km / yr  Passenger  Road          Bus
# 2553  % in total inland passenger-km / yr  Passenger  Road          Bus
#
#      Technology Fuel                        Country  Value
# 0           All  All  European Union (28 countries)    7.1
# 1           All  All  European Union (28 countries)    7.1
# 2           All  All  European Union (28 countries)   82.5
# 3           All  All  European Union (28 countries)   83.4
# 4           All  All  European Union (28 countries)   83.4
# ...         ...  ...                            ...    ...
# 2549        All  All                        Germany    9.1
# 2550        All  All                        Germany    7.1
# 2551        All  All                        Germany    6.7
# 2552        All  All                        Germany    6.0
# 2553        All  All                        Germany    6.0
#
# [2554 rows x 13 columns]

# %% [markdown]
# # Reordering the columns
#     Rule: To comply with the current template, the columns must be shown in a specific order. The dataframe manager specifies the order of the columns

# %%
df = dataframeManager.reorder_columns(df)
df
# Out:
#         Source                        Country ISO Code Region  \
# 0     Eurostat  European Union (28 countries)     EU28  EU-28
# 1     Eurostat  European Union (28 countries)     EU28  EU-28
# 2     Eurostat  European Union (28 countries)     EU28  EU-28
# 3     Eurostat  European Union (28 countries)     EU28  EU-28
# 4     Eurostat  European Union (28 countries)     EU28  EU-28
# ...        ...                            ...      ...    ...
# 2549  Eurostat                        Germany      DEU  EU-27
# 2550  Eurostat                        Germany      DEU  EU-27
# 2551  Eurostat                        Germany      DEU  EU-27
# 2552  Eurostat                        Germany      DEU  EU-27
# 2553  Eurostat                        Germany      DEU  EU-27
#
#                 Variable                                 Unit    Service  \
# 0     Passenger Activity  % in total inland passenger-km / yr  Passenger
# 1     Passenger Activity  % in total inland passenger-km / yr  Passenger
# 2     Passenger Activity  % in total inland passenger-km / yr  Passenger
# 3     Passenger Activity  % in total inland passenger-km / yr  Passenger
# 4     Passenger Activity  % in total inland passenger-km / yr  Passenger
# ...                  ...                                  ...        ...
# 2549  Passenger Activity  % in total inland passenger-km / yr  Passenger
# 2550  Passenger Activity  % in total inland passenger-km / yr  Passenger
# 2551  Passenger Activity  % in total inland passenger-km / yr  Passenger
# 2552  Passenger Activity  % in total inland passenger-km / yr  Passenger
# 2553  Passenger Activity  % in total inland passenger-km / yr  Passenger
#
#       Mode Vehicle Type Technology Fuel  Value  Year
# 0     Rail          All        All  All    7.1  2000
# 1     Rail          All        All  All    7.1  2007
# 2     Road          LDV        All  All   82.5  2000
# 3     Road          LDV        All  All   83.4  2002
# 4     Road          LDV        All  All   83.4  2005
# ...    ...          ...        ...  ...    ...   ...
# 2549  Road          Bus        All  All    9.1  1990
# 2550  Road          Bus        All  All    7.1  1997
# 2551  Road          Bus        All  All    6.7  2004
# 2552  Road          Bus        All  All    6.0  2010
# 2553  Road          Bus        All  All    6.0  2015
#
# [2554 rows x 13 columns]

# %% [markdown]
# # Exporting Results

# %%
# Programming Friendly View
dataframeManager.create_programming_friendly_file(df)

# User Friendly View
dataframeManager.create_user_friendly_file(df)
# Out:
# > PF File saved at: /Users/hlinero/Documents/database/item/historical/scripts
# > UF File saved at: /Users/hlinero/Documents/database/item/historical/scripts
