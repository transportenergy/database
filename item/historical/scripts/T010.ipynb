# %%
import pandas as pd
import json
from pprint import pprint
from util.managers.DataframeManager import DataframeManager
from util.managers.DataframeManager import ColumnName
from util.managers.CountryCodeManager import CountryCodeManager

# %% [markdown]
# # Variables used across the noteboook and not changed

# %%
DATASET_ID = "T010"
dataframeManager = DataframeManager(DATASET_ID)
countryCodeManager = CountryCodeManager()

# %%
filename = "CV_Vehicles-in-use.csv"
path = "/Users/hlinero/Desktop/iTEM Material/raw dataset/T010/{}".format(filename)
df = dataframeManager.get_dataframe_from_csv_file(path)
df
# Out:
#     REGIONS/COUNTRIES   2005   2006   2007   2008   2009   2010   2011   2012  \
# 0             AUSTRIA    367    374    382    391    398    406    417    426
# 1             BELGIUM    674    691    712    731    743    761    779    791
# 2             DENMARK    479    519    546    541    518    495    479    465
# 3             FINLAND     87     91     93     93     92     94     97     97
# 4              FRANCE  6,198  6,261  6,333  6,362  6,388  6,444  6,517  6,538
# ..                ...    ...    ...    ...    ...    ...    ...    ...    ...
# 136              TOGO     47     47     48     49     49     50     51     52
# 137           TUNISIA    122    126    220    390    400    411    414    417
# 138            UGANDA    171    176    212    219    259    265    270    280
# 139            ZAMBIA     73     74     80     83    108    110    110    110
# 140          ZIMBABWE     89     91     90     93     95     97    100    100
#
#       2013   2014   2015
# 0      434    445    454
# 1      802    817    839
# 2      451    448    446
# 3       97     95     95
# 4    6,550  6,608  6,652
# ..     ...    ...    ...
# 136     54     56     58
# 137    439    450    460
# 138    300    320    340
# 139    113    120    120
# 140    103    110    110
#
# [141 rows x 12 columns]

# %% [markdown]
# # Tranforming the view from PF to UF

# %%
df = dataframeManager.transform_from_uf_to_pf_view(df, 1)
df
# Out:
#      REGIONS/COUNTRIES  Year Value
# 0              AUSTRIA  2005   367
# 1              AUSTRIA  2006   374
# 2              AUSTRIA  2007   382
# 3              AUSTRIA  2008   391
# 4              AUSTRIA  2009   398
# ...                ...   ...   ...
# 1546          ZIMBABWE  2011   100
# 1547          ZIMBABWE  2012   100
# 1548          ZIMBABWE  2013   103
# 1549          ZIMBABWE  2014   110
# 1550          ZIMBABWE  2015   110
#
# [1551 rows x 3 columns]

# %% [markdown]
# # Renaming the "Country" column

# %%
dataframeManager.rename_column(current_name="REGIONS/COUNTRIES",df=df,new_name=ColumnName.COUNTRY.value)
df
# Out:
#        Country  Year Value
# 0      AUSTRIA  2005   367
# 1      AUSTRIA  2006   374
# 2      AUSTRIA  2007   382
# 3      AUSTRIA  2008   391
# 4      AUSTRIA  2009   398
# ...        ...   ...   ...
# 1546  ZIMBABWE  2011   100
# 1547  ZIMBABWE  2012   100
# 1548  ZIMBABWE  2013   103
# 1549  ZIMBABWE  2014   110
# 1550  ZIMBABWE  2015   110
#
# [1551 rows x 3 columns]

# %% [markdown]
# # Setting the "Source" column
#     Rule: This dataset comes from "International Organization of Motor Vehicle Manufacturers"

# %%
dataframeManager.simple_column_insert(cell_value="International Organization of Motor Vehicle Manufacturers", dataframe=df, column_name= ColumnName.SOURCE.value)
df
# Out:
#                                                  Source   Country  Year Value
# 0     International Organization of Motor Vehicle Ma...   AUSTRIA  2005   367
# 1     International Organization of Motor Vehicle Ma...   AUSTRIA  2006   374
# 2     International Organization of Motor Vehicle Ma...   AUSTRIA  2007   382
# 3     International Organization of Motor Vehicle Ma...   AUSTRIA  2008   391
# 4     International Organization of Motor Vehicle Ma...   AUSTRIA  2009   398
# ...                                                 ...       ...   ...   ...
# 1546  International Organization of Motor Vehicle Ma...  ZIMBABWE  2011   100
# 1547  International Organization of Motor Vehicle Ma...  ZIMBABWE  2012   100
# 1548  International Organization of Motor Vehicle Ma...  ZIMBABWE  2013   103
# 1549  International Organization of Motor Vehicle Ma...  ZIMBABWE  2014   110
# 1550  International Organization of Motor Vehicle Ma...  ZIMBABWE  2015   110
#
# [1551 rows x 4 columns]

# %% [markdown]
# # Getting the ISO code for each country

# %% [markdown]
# ## Determining which countries do not have an ISO code
#     Rule: As seen below, 13 countries do not have an ISO code. The transformation that will be done for each country is as follows:
#     ORIGINAL NAME --> NAME TO USE
#      RUSSIA --> Russian Federation
#      SYRIA --> Syrian Arab Republic
#      IRAN --> Iran, Islamic Republic of
#      BOSNIA --> Bosnia and Herzegovina
#      HONG-KONG --> Hong Kong
#      IVORY COAST --> Côte d'Ivoire
#      BRUNEI --> Brunei Darussalam
#      MOLDAVIA --> Moldova, Republic of
#      SOUTH KOREA --> Korea, Republic of
#      CONGO KINSHASA --> Congo, The Democratic Republic of the
#      PALESTINE --> Palestine, State of
#      MACEDONIA --> North Macedonia
#      AZERBAIDJAN --> ??

# %%
list_of_countries = list(set(df[ColumnName.COUNTRY.value]))
countries_with_no_iso_code = countryCodeManager.get_list_of_countries_with_no_iso_code(list_of_countries)
countries_with_no_iso_code
# Out:
# ['PALESTINE',
#  'AZERBAIDJAN',
#  'SOUTH KOREA',
#  'IVORY COAST',
#  'BRUNEI',
#  'IRAN',
#  'BOSNIA',
#  'RUSSIA',
#  'SYRIA',
#  'MOLDAVIA',
#  'MACEDONIA',
#  'HONG-KONG',
#  'CONGO KINSHASA ']

# %%
# Creating a list to hold all the iso_codes
dirty_list_of_all_countries = df["Country"]
clean_list_of_all_countries = []

# Cleaning the list and replacing the missing countries with the appropriate name
for country in dirty_list_of_all_countries:
    if country == "RUSSIA":
        clean_list_of_all_countries.append("Russian Federation")
    elif country == "SYRIA":
        clean_list_of_all_countries.append("Syrian Arab Republic")
    elif country == "IRAN":
        clean_list_of_all_countries.append("Iran, Islamic Republic of")
    elif country == "BOSNIA":
        clean_list_of_all_countries.append("Bosnia and Herzegovina")
    elif country == "HONG-KONG":
        clean_list_of_all_countries.append("Hong Kong")
    elif country == "IVORY COAST":
        clean_list_of_all_countries.append("Côte d'Ivoire")
    elif country == "BRUNEI":
        clean_list_of_all_countries.append("Brunei Darussalam")
    elif country == "MOLDAVIA":
        clean_list_of_all_countries.append("Moldova, Republic of")
    elif country == "SOUTH KOREA":
        clean_list_of_all_countries.append("Korea, Republic of")
    elif country == "CONGO KINSHASA ":
        clean_list_of_all_countries.append("Congo, The Democratic Republic of the")
    elif country == "PALESTINE":
        clean_list_of_all_countries.append("Palestine, State of")
    elif country == "MACEDONIA":
        clean_list_of_all_countries.append("North Macedonia")
    else:
        clean_list_of_all_countries.append(country)
        
# Ensuring the size of the clean list is equal to the old list
assert len(clean_list_of_all_countries) == len(dirty_list_of_all_countries)

# Getting the list of iso codes
list_of_iso_codes = countryCodeManager.get_list_of_iso_for_countries(clean_list_of_all_countries)

# Setting the new country column
df.drop(columns=["Country"], inplace = True)
df[ColumnName.COUNTRY.value] = clean_list_of_all_countries

# Adding the column to the dataframe
df[ColumnName.ISO_CODE.value] = list_of_iso_codes
df
# Out:
#                                                  Source  Year Value   Country  \
# 0     International Organization of Motor Vehicle Ma...  2005   367   AUSTRIA
# 1     International Organization of Motor Vehicle Ma...  2006   374   AUSTRIA
# 2     International Organization of Motor Vehicle Ma...  2007   382   AUSTRIA
# 3     International Organization of Motor Vehicle Ma...  2008   391   AUSTRIA
# 4     International Organization of Motor Vehicle Ma...  2009   398   AUSTRIA
# ...                                                 ...   ...   ...       ...
# 1546  International Organization of Motor Vehicle Ma...  2011   100  ZIMBABWE
# 1547  International Organization of Motor Vehicle Ma...  2012   100  ZIMBABWE
# 1548  International Organization of Motor Vehicle Ma...  2013   103  ZIMBABWE
# 1549  International Organization of Motor Vehicle Ma...  2014   110  ZIMBABWE
# 1550  International Organization of Motor Vehicle Ma...  2015   110  ZIMBABWE
#
#      ISO Code
# 0         AUT
# 1         AUT
# 2         AUT
# 3         AUT
# 4         AUT
# ...       ...
# 1546      ZWE
# 1547      ZWE
# 1548      ZWE
# 1549      ZWE
# 1550      ZWE
#
# [1551 rows x 5 columns]

# %% [markdown]
# # Getting the ITEM region for each ISO code

# %% [markdown]
# # Determining which countries do not have an ITEM region
#     Rule: As seen below, all ISO code have a respective region.

# %%
list_of_unique_iso_codes = list(set(df[ColumnName.ISO_CODE.value]))
iso_codes_with_no_region = countryCodeManager.get_list_of_iso_codes_with_no_region(list_of_unique_iso_codes)
iso_codes_with_no_region
# Out:
# ['N/A']

# %% [markdown]
# ## Assigning the ITEM region
#     Rule: AZERBAIDJAN is the only country to which we found no ISO code from the pycountry library

# %%
# Getting the complete list of iso codes
list_of_all_codes = df[ColumnName.ISO_CODE.value]

# Getting the list of regions
item_regions = countryCodeManager.get_list_of_regions_for_iso_codes(list_of_all_codes)

# Assert that the size of the list of iso codes is equivalent to the size of country column
assert len(df) == len(item_regions)

# Adding the column to the dataframe
df.insert(3, ColumnName.ITEM_REGION.value, item_regions, True)
df
# Out:
#                                                  Source  Year Value  Region  \
# 0     International Organization of Motor Vehicle Ma...  2005   367   EU-27
# 1     International Organization of Motor Vehicle Ma...  2006   374   EU-27
# 2     International Organization of Motor Vehicle Ma...  2007   382   EU-27
# 3     International Organization of Motor Vehicle Ma...  2008   391   EU-27
# 4     International Organization of Motor Vehicle Ma...  2009   398   EU-27
# ...                                                 ...   ...   ...     ...
# 1546  International Organization of Motor Vehicle Ma...  2011   100  Africa
# 1547  International Organization of Motor Vehicle Ma...  2012   100  Africa
# 1548  International Organization of Motor Vehicle Ma...  2013   103  Africa
# 1549  International Organization of Motor Vehicle Ma...  2014   110  Africa
# 1550  International Organization of Motor Vehicle Ma...  2015   110  Africa
#
#        Country ISO Code
# 0      AUSTRIA      AUT
# 1      AUSTRIA      AUT
# 2      AUSTRIA      AUT
# 3      AUSTRIA      AUT
# 4      AUSTRIA      AUT
# ...        ...      ...
# 1546  ZIMBABWE      ZWE
# 1547  ZIMBABWE      ZWE
# 1548  ZIMBABWE      ZWE
# 1549  ZIMBABWE      ZWE
# 1550  ZIMBABWE      ZWE
#
# [1551 rows x 6 columns]

# %% [markdown]
# # Modifying the country name and making them capital and not upper case

# %%
# Variable holding the new names
new_names = []
old_names =list(df["Country"])

# Changing the names
for name in old_names:
    new_names.append(name.capitalize())
    
# Asserting that no data is missing
assert len(new_names) == len(df)

# Dropping current name and adding the new column
df.drop(columns=["Country"], inplace = True)
df.insert(0, ColumnName.COUNTRY.value, new_names, True)
df
# Out:
#        Country                                             Source  Year Value  \
# 0      Austria  International Organization of Motor Vehicle Ma...  2005   367
# 1      Austria  International Organization of Motor Vehicle Ma...  2006   374
# 2      Austria  International Organization of Motor Vehicle Ma...  2007   382
# 3      Austria  International Organization of Motor Vehicle Ma...  2008   391
# 4      Austria  International Organization of Motor Vehicle Ma...  2009   398
# ...        ...                                                ...   ...   ...
# 1546  Zimbabwe  International Organization of Motor Vehicle Ma...  2011   100
# 1547  Zimbabwe  International Organization of Motor Vehicle Ma...  2012   100
# 1548  Zimbabwe  International Organization of Motor Vehicle Ma...  2013   103
# 1549  Zimbabwe  International Organization of Motor Vehicle Ma...  2014   110
# 1550  Zimbabwe  International Organization of Motor Vehicle Ma...  2015   110
#
#       Region ISO Code
# 0      EU-27      AUT
# 1      EU-27      AUT
# 2      EU-27      AUT
# 3      EU-27      AUT
# 4      EU-27      AUT
# ...      ...      ...
# 1546  Africa      ZWE
# 1547  Africa      ZWE
# 1548  Africa      ZWE
# 1549  Africa      ZWE
# 1550  Africa      ZWE
#
# [1551 rows x 6 columns]

# %% [markdown]
# # Adding the 'Service' column
#     Rule: The dataset is associated to commercial data, therefore, the "Service," is "Freight"

# %%
dataframeManager.simple_column_insert(df, ColumnName.SERVICE.value, "Freight", 6)
df
# Out:
#        Country                                             Source  Year Value  \
# 0      Austria  International Organization of Motor Vehicle Ma...  2005   367
# 1      Austria  International Organization of Motor Vehicle Ma...  2006   374
# 2      Austria  International Organization of Motor Vehicle Ma...  2007   382
# 3      Austria  International Organization of Motor Vehicle Ma...  2008   391
# 4      Austria  International Organization of Motor Vehicle Ma...  2009   398
# ...        ...                                                ...   ...   ...
# 1546  Zimbabwe  International Organization of Motor Vehicle Ma...  2011   100
# 1547  Zimbabwe  International Organization of Motor Vehicle Ma...  2012   100
# 1548  Zimbabwe  International Organization of Motor Vehicle Ma...  2013   103
# 1549  Zimbabwe  International Organization of Motor Vehicle Ma...  2014   110
# 1550  Zimbabwe  International Organization of Motor Vehicle Ma...  2015   110
#
#       Region ISO Code  Service
# 0      EU-27      AUT  Freight
# 1      EU-27      AUT  Freight
# 2      EU-27      AUT  Freight
# 3      EU-27      AUT  Freight
# 4      EU-27      AUT  Freight
# ...      ...      ...      ...
# 1546  Africa      ZWE  Freight
# 1547  Africa      ZWE  Freight
# 1548  Africa      ZWE  Freight
# 1549  Africa      ZWE  Freight
# 1550  Africa      ZWE  Freight
#
# [1551 rows x 7 columns]

# %% [markdown]
# # Adding the "Technology", "Fuel", and "Vehicle Type" columns
#     Rule: Since the dataset does not provide information about technology or fuel, we set both as "All"

# %%
dataframeManager.simple_column_insert(df, ColumnName.TECHNOLOGY.value, "All", 7)
dataframeManager.simple_column_insert(df, ColumnName.VEHICLE_TYPE.value, "All", 8)
dataframeManager.simple_column_insert(df, ColumnName.FUEL.value, "All", 9)
df
# Out:
#        Country                                             Source  Year Value  \
# 0      Austria  International Organization of Motor Vehicle Ma...  2005   367
# 1      Austria  International Organization of Motor Vehicle Ma...  2006   374
# 2      Austria  International Organization of Motor Vehicle Ma...  2007   382
# 3      Austria  International Organization of Motor Vehicle Ma...  2008   391
# 4      Austria  International Organization of Motor Vehicle Ma...  2009   398
# ...        ...                                                ...   ...   ...
# 1546  Zimbabwe  International Organization of Motor Vehicle Ma...  2011   100
# 1547  Zimbabwe  International Organization of Motor Vehicle Ma...  2012   100
# 1548  Zimbabwe  International Organization of Motor Vehicle Ma...  2013   103
# 1549  Zimbabwe  International Organization of Motor Vehicle Ma...  2014   110
# 1550  Zimbabwe  International Organization of Motor Vehicle Ma...  2015   110
#
#       Region ISO Code  Service Technology Vehicle Type Fuel
# 0      EU-27      AUT  Freight        All          All  All
# 1      EU-27      AUT  Freight        All          All  All
# 2      EU-27      AUT  Freight        All          All  All
# 3      EU-27      AUT  Freight        All          All  All
# 4      EU-27      AUT  Freight        All          All  All
# ...      ...      ...      ...        ...          ...  ...
# 1546  Africa      ZWE  Freight        All          All  All
# 1547  Africa      ZWE  Freight        All          All  All
# 1548  Africa      ZWE  Freight        All          All  All
# 1549  Africa      ZWE  Freight        All          All  All
# 1550  Africa      ZWE  Freight        All          All  All
#
# [1551 rows x 10 columns]

# %% [markdown]
# # Adding the "Mode" column
#     Rule: This dataset is about vehicles, the mode is "Road"

# %%
dataframeManager.simple_column_insert(df, ColumnName.MODE.value, "Road", 8)
df
# Out:
#        Country                                             Source  Year Value  \
# 0      Austria  International Organization of Motor Vehicle Ma...  2005   367
# 1      Austria  International Organization of Motor Vehicle Ma...  2006   374
# 2      Austria  International Organization of Motor Vehicle Ma...  2007   382
# 3      Austria  International Organization of Motor Vehicle Ma...  2008   391
# 4      Austria  International Organization of Motor Vehicle Ma...  2009   398
# ...        ...                                                ...   ...   ...
# 1546  Zimbabwe  International Organization of Motor Vehicle Ma...  2011   100
# 1547  Zimbabwe  International Organization of Motor Vehicle Ma...  2012   100
# 1548  Zimbabwe  International Organization of Motor Vehicle Ma...  2013   103
# 1549  Zimbabwe  International Organization of Motor Vehicle Ma...  2014   110
# 1550  Zimbabwe  International Organization of Motor Vehicle Ma...  2015   110
#
#       Region ISO Code  Service Technology  Mode Vehicle Type Fuel
# 0      EU-27      AUT  Freight        All  Road          All  All
# 1      EU-27      AUT  Freight        All  Road          All  All
# 2      EU-27      AUT  Freight        All  Road          All  All
# 3      EU-27      AUT  Freight        All  Road          All  All
# 4      EU-27      AUT  Freight        All  Road          All  All
# ...      ...      ...      ...        ...   ...          ...  ...
# 1546  Africa      ZWE  Freight        All  Road          All  All
# 1547  Africa      ZWE  Freight        All  Road          All  All
# 1548  Africa      ZWE  Freight        All  Road          All  All
# 1549  Africa      ZWE  Freight        All  Road          All  All
# 1550  Africa      ZWE  Freight        All  Road          All  All
#
# [1551 rows x 11 columns]

# %% [markdown]
# # Adding the "Variable" and "Unit" columns
#     Rule: This dataset is associated to stock data. Therefore, the variable is "Stock." The units of this data are expressed as either "10^6 vehicle"

# %% [markdown]
# ## Variable Column

# %%
dataframeManager.simple_column_insert(df, ColumnName.VARIABLE.value, "Stock", 4)
df
# Out:
#        Country                                             Source  Year Value  \
# 0      Austria  International Organization of Motor Vehicle Ma...  2005   367
# 1      Austria  International Organization of Motor Vehicle Ma...  2006   374
# 2      Austria  International Organization of Motor Vehicle Ma...  2007   382
# 3      Austria  International Organization of Motor Vehicle Ma...  2008   391
# 4      Austria  International Organization of Motor Vehicle Ma...  2009   398
# ...        ...                                                ...   ...   ...
# 1546  Zimbabwe  International Organization of Motor Vehicle Ma...  2011   100
# 1547  Zimbabwe  International Organization of Motor Vehicle Ma...  2012   100
# 1548  Zimbabwe  International Organization of Motor Vehicle Ma...  2013   103
# 1549  Zimbabwe  International Organization of Motor Vehicle Ma...  2014   110
# 1550  Zimbabwe  International Organization of Motor Vehicle Ma...  2015   110
#
#      Variable  Region ISO Code  Service Technology  Mode Vehicle Type Fuel
# 0       Stock   EU-27      AUT  Freight        All  Road          All  All
# 1       Stock   EU-27      AUT  Freight        All  Road          All  All
# 2       Stock   EU-27      AUT  Freight        All  Road          All  All
# 3       Stock   EU-27      AUT  Freight        All  Road          All  All
# 4       Stock   EU-27      AUT  Freight        All  Road          All  All
# ...       ...     ...      ...      ...        ...   ...          ...  ...
# 1546    Stock  Africa      ZWE  Freight        All  Road          All  All
# 1547    Stock  Africa      ZWE  Freight        All  Road          All  All
# 1548    Stock  Africa      ZWE  Freight        All  Road          All  All
# 1549    Stock  Africa      ZWE  Freight        All  Road          All  All
# 1550    Stock  Africa      ZWE  Freight        All  Road          All  All
#
# [1551 rows x 12 columns]

# %% [markdown]
# ## Unit column

# %%
dataframeManager.simple_column_insert(df, ColumnName.UNIT.value, "10^6 vehicle", 5)
df
# Out:
#        Country                                             Source  Year Value  \
# 0      Austria  International Organization of Motor Vehicle Ma...  2005   367
# 1      Austria  International Organization of Motor Vehicle Ma...  2006   374
# 2      Austria  International Organization of Motor Vehicle Ma...  2007   382
# 3      Austria  International Organization of Motor Vehicle Ma...  2008   391
# 4      Austria  International Organization of Motor Vehicle Ma...  2009   398
# ...        ...                                                ...   ...   ...
# 1546  Zimbabwe  International Organization of Motor Vehicle Ma...  2011   100
# 1547  Zimbabwe  International Organization of Motor Vehicle Ma...  2012   100
# 1548  Zimbabwe  International Organization of Motor Vehicle Ma...  2013   103
# 1549  Zimbabwe  International Organization of Motor Vehicle Ma...  2014   110
# 1550  Zimbabwe  International Organization of Motor Vehicle Ma...  2015   110
#
#      Variable          Unit  Region ISO Code  Service Technology  Mode  \
# 0       Stock  10^6 vehicle   EU-27      AUT  Freight        All  Road
# 1       Stock  10^6 vehicle   EU-27      AUT  Freight        All  Road
# 2       Stock  10^6 vehicle   EU-27      AUT  Freight        All  Road
# 3       Stock  10^6 vehicle   EU-27      AUT  Freight        All  Road
# 4       Stock  10^6 vehicle   EU-27      AUT  Freight        All  Road
# ...       ...           ...     ...      ...      ...        ...   ...
# 1546    Stock  10^6 vehicle  Africa      ZWE  Freight        All  Road
# 1547    Stock  10^6 vehicle  Africa      ZWE  Freight        All  Road
# 1548    Stock  10^6 vehicle  Africa      ZWE  Freight        All  Road
# 1549    Stock  10^6 vehicle  Africa      ZWE  Freight        All  Road
# 1550    Stock  10^6 vehicle  Africa      ZWE  Freight        All  Road
#
#      Vehicle Type Fuel
# 0             All  All
# 1             All  All
# 2             All  All
# 3             All  All
# 4             All  All
# ...           ...  ...
# 1546          All  All
# 1547          All  All
# 1548          All  All
# 1549          All  All
# 1550          All  All
#
# [1551 rows x 13 columns]

# %% [markdown]
# # Value Column
#     Rule: The dataset provides values in thousands so we much change it to million

# %%
# Variable holding the new value
new_values = []
old_values = list(df["Value"])

# Transforming each value
for old_val in old_values:
    val = str(old_val).replace(",","")
    new_val = float(val) / float(1000)
    new_values.append(new_val)
    
# Asserting no data was lost
assert len(new_values) == len(df)

# Setting the new column
df.drop(columns=["Value"], inplace = True)
df[ColumnName.VALUE.value] = new_values
df
# Out:
#        Country                                             Source  Year  \
# 0      Austria  International Organization of Motor Vehicle Ma...  2005
# 1      Austria  International Organization of Motor Vehicle Ma...  2006
# 2      Austria  International Organization of Motor Vehicle Ma...  2007
# 3      Austria  International Organization of Motor Vehicle Ma...  2008
# 4      Austria  International Organization of Motor Vehicle Ma...  2009
# ...        ...                                                ...   ...
# 1546  Zimbabwe  International Organization of Motor Vehicle Ma...  2011
# 1547  Zimbabwe  International Organization of Motor Vehicle Ma...  2012
# 1548  Zimbabwe  International Organization of Motor Vehicle Ma...  2013
# 1549  Zimbabwe  International Organization of Motor Vehicle Ma...  2014
# 1550  Zimbabwe  International Organization of Motor Vehicle Ma...  2015
#
#      Variable          Unit  Region ISO Code  Service Technology  Mode  \
# 0       Stock  10^6 vehicle   EU-27      AUT  Freight        All  Road
# 1       Stock  10^6 vehicle   EU-27      AUT  Freight        All  Road
# 2       Stock  10^6 vehicle   EU-27      AUT  Freight        All  Road
# 3       Stock  10^6 vehicle   EU-27      AUT  Freight        All  Road
# 4       Stock  10^6 vehicle   EU-27      AUT  Freight        All  Road
# ...       ...           ...     ...      ...      ...        ...   ...
# 1546    Stock  10^6 vehicle  Africa      ZWE  Freight        All  Road
# 1547    Stock  10^6 vehicle  Africa      ZWE  Freight        All  Road
# 1548    Stock  10^6 vehicle  Africa      ZWE  Freight        All  Road
# 1549    Stock  10^6 vehicle  Africa      ZWE  Freight        All  Road
# 1550    Stock  10^6 vehicle  Africa      ZWE  Freight        All  Road
#
#      Vehicle Type Fuel  Value
# 0             All  All  0.367
# 1             All  All  0.374
# 2             All  All  0.382
# 3             All  All  0.391
# 4             All  All  0.398
# ...           ...  ...    ...
# 1546          All  All  0.100
# 1547          All  All  0.100
# 1548          All  All  0.103
# 1549          All  All  0.110
# 1550          All  All  0.110
#
# [1551 rows x 13 columns]

# %% [markdown]
# # Reordering Columns
#     Rule: To comply with the current template, the columns must be shown in a specific order. The dataframe manager specifies the order of the columns

# %%
df = dataframeManager.reorder_columns(df)
df
# Out:
#                                                  Source   Country ISO Code  \
# 0     International Organization of Motor Vehicle Ma...   Austria      AUT
# 1     International Organization of Motor Vehicle Ma...   Austria      AUT
# 2     International Organization of Motor Vehicle Ma...   Austria      AUT
# 3     International Organization of Motor Vehicle Ma...   Austria      AUT
# 4     International Organization of Motor Vehicle Ma...   Austria      AUT
# ...                                                 ...       ...      ...
# 1546  International Organization of Motor Vehicle Ma...  Zimbabwe      ZWE
# 1547  International Organization of Motor Vehicle Ma...  Zimbabwe      ZWE
# 1548  International Organization of Motor Vehicle Ma...  Zimbabwe      ZWE
# 1549  International Organization of Motor Vehicle Ma...  Zimbabwe      ZWE
# 1550  International Organization of Motor Vehicle Ma...  Zimbabwe      ZWE
#
#       Region Variable          Unit  Service  Mode Vehicle Type Technology  \
# 0      EU-27    Stock  10^6 vehicle  Freight  Road          All        All
# 1      EU-27    Stock  10^6 vehicle  Freight  Road          All        All
# 2      EU-27    Stock  10^6 vehicle  Freight  Road          All        All
# 3      EU-27    Stock  10^6 vehicle  Freight  Road          All        All
# 4      EU-27    Stock  10^6 vehicle  Freight  Road          All        All
# ...      ...      ...           ...      ...   ...          ...        ...
# 1546  Africa    Stock  10^6 vehicle  Freight  Road          All        All
# 1547  Africa    Stock  10^6 vehicle  Freight  Road          All        All
# 1548  Africa    Stock  10^6 vehicle  Freight  Road          All        All
# 1549  Africa    Stock  10^6 vehicle  Freight  Road          All        All
# 1550  Africa    Stock  10^6 vehicle  Freight  Road          All        All
#
#      Fuel  Value  Year
# 0     All  0.367  2005
# 1     All  0.374  2006
# 2     All  0.382  2007
# 3     All  0.391  2008
# 4     All  0.398  2009
# ...   ...    ...   ...
# 1546  All  0.100  2011
# 1547  All  0.100  2012
# 1548  All  0.103  2013
# 1549  All  0.110  2014
# 1550  All  0.110  2015
#
# [1551 rows x 13 columns]

# %% [markdown]
# # Exporting Results

# %%
# Programming Friendly View
dataframeManager.create_programming_friendly_file(df)

# User Friendly View
dataframeManager.create_user_friendly_file(df)
# Out:
# > PF File saved at: /Users/hlinero/Documents/database/item/historical/scripts
# > UF File saved at: /Users/hlinero/Documents/database/item/historical/scripts
