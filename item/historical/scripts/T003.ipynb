# %%
import pandas as pd
from pprint import pprint
from item.historical.scripts.util.managers.dataframe import DataframeManager
from item.historical.scripts.util.managers.dataframe import ColumnName
from item.historical.scripts.util.managers.country_code import CountryCodeManager
from item.historical.scripts.util.managers.unit import UnitConverterManager

# %% [markdown]
# # Variables used all over the notebook

# %%
DATASET_ID = "T003"
dataframeManager = DataframeManager(DATASET_ID)
countryCodeManager = CountryCodeManager()

# %% [markdown]
# # Opening the dataset

# %%
filename = "T003_ITF_GOODS_TRANSPORT_25102019113754397.csv"
path = "/Users/hlinero/Desktop/iTEM Material/raw dataset/T003/{}".format(filename)
df = dataframeManager.get_dataframe_from_csv_file(path)
df
# Out:
#       COUNTRY   Country        VARIABLE  \
# 0         SVN  Slovenia  T-GOODS-RD-OWN
# 1         SVN  Slovenia  T-GOODS-RD-OWN
# 2         SVN  Slovenia  T-GOODS-RD-OWN
# 3         SVN  Slovenia  T-GOODS-RD-OWN
# 4         SVN  Slovenia  T-GOODS-RD-OWN
# ...       ...       ...             ...
# 13207     KOR     Korea  T-GOODS-RD-REW
# 13208     KOR     Korea  T-GOODS-RD-REW
# 13209     KOR     Korea  T-GOODS-RD-REW
# 13210     KOR     Korea  T-GOODS-RD-REW
# 13211     KOR     Korea  T-GOODS-RD-REW
#
#                                          Variable  YEAR  Year Unit Code  \
# 0           Road freight transport on own account  1970  1970   TONNEKM
# 1           Road freight transport on own account  1971  1971   TONNEKM
# 2           Road freight transport on own account  1972  1972   TONNEKM
# 3           Road freight transport on own account  1973  1973   TONNEKM
# 4           Road freight transport on own account  1974  1974   TONNEKM
# ...                                           ...   ...   ...       ...
# 13207  Road freight transport for hire and reward  2013  2013   TONNEKM
# 13208  Road freight transport for hire and reward  2014  2014   TONNEKM
# 13209  Road freight transport for hire and reward  2015  2015   TONNEKM
# 13210  Road freight transport for hire and reward  2016  2016   TONNEKM
# 13211  Road freight transport for hire and reward  2017  2017   TONNEKM
#
#                     Unit  PowerCode Code PowerCode  Reference Period Code  \
# 0      Tonnes-kilometres               6  Millions                    NaN
# 1      Tonnes-kilometres               6  Millions                    NaN
# 2      Tonnes-kilometres               6  Millions                    NaN
# 3      Tonnes-kilometres               6  Millions                    NaN
# 4      Tonnes-kilometres               6  Millions                    NaN
# ...                  ...             ...       ...                    ...
# 13207  Tonnes-kilometres               6  Millions                    NaN
# 13208  Tonnes-kilometres               6  Millions                    NaN
# 13209  Tonnes-kilometres               6  Millions                    NaN
# 13210  Tonnes-kilometres               6  Millions                    NaN
# 13211  Tonnes-kilometres               6  Millions                    NaN
#
#        Reference Period     Value Flag Codes Flags
# 0                   NaN     534.0        NaN   NaN
# 1                   NaN     700.0        NaN   NaN
# 2                   NaN    1098.0        NaN   NaN
# 3                   NaN    1078.0        NaN   NaN
# 4                   NaN     745.0        NaN   NaN
# ...                 ...       ...        ...   ...
# 13207               NaN  118582.0        NaN   NaN
# 13208               NaN  124650.0        NaN   NaN
# 13209               NaN  132382.0        NaN   NaN
# 13210               NaN  135259.0        NaN   NaN
# 13211               NaN  140374.0        NaN   NaN
#
# [13212 rows x 15 columns]

# %% [markdown]
# # Removing all unnecessary columns
#     Rule: To comply with the latest template, we will drop all the unnecessary columns and rename others.

# %%
# Droping the repeated columns
columns_to_delete = ["COUNTRY", "YEAR", "VARIABLE","Reference Period Code","Unit Code","Reference Period", "Flag Codes", "Flags", "PowerCode Code"]
df.drop(columns=columns_to_delete, inplace = True)
df
# Out:
#         Country                                    Variable  Year  \
# 0      Slovenia       Road freight transport on own account  1970
# 1      Slovenia       Road freight transport on own account  1971
# 2      Slovenia       Road freight transport on own account  1972
# 3      Slovenia       Road freight transport on own account  1973
# 4      Slovenia       Road freight transport on own account  1974
# ...         ...                                         ...   ...
# 13207     Korea  Road freight transport for hire and reward  2013
# 13208     Korea  Road freight transport for hire and reward  2014
# 13209     Korea  Road freight transport for hire and reward  2015
# 13210     Korea  Road freight transport for hire and reward  2016
# 13211     Korea  Road freight transport for hire and reward  2017
#
#                     Unit PowerCode     Value
# 0      Tonnes-kilometres  Millions     534.0
# 1      Tonnes-kilometres  Millions     700.0
# 2      Tonnes-kilometres  Millions    1098.0
# 3      Tonnes-kilometres  Millions    1078.0
# 4      Tonnes-kilometres  Millions     745.0
# ...                  ...       ...       ...
# 13207  Tonnes-kilometres  Millions  118582.0
# 13208  Tonnes-kilometres  Millions  124650.0
# 13209  Tonnes-kilometres  Millions  132382.0
# 13210  Tonnes-kilometres  Millions  135259.0
# 13211  Tonnes-kilometres  Millions  140374.0
#
# [13212 rows x 6 columns]

# %% [markdown]
# # Identifying the countries with missing values
#     Rule: We will erase all the countries with missing values

# %%
list_of_countries_with_missing_values = list(set(df[df['Value'].isnull()]["Country"]))
print(">> Number of countries missing values: {}".format(len(list_of_countries_with_missing_values)))
print(">> Countries missing values:")
pprint(list_of_countries_with_missing_values)
print(">> Number of rows to erase: {}".format(len(df[df['Value'].isnull()])))
# Out:
# >> Number of countries missing values: 29
# >> Countries missing values:
# ['Slovenia',
#  'Luxembourg',
#  'Denmark',
#  'Bosnia-Herzegovina',
#  'North Macedonia',
#  'Greece',
#  'Norway',
#  'Japan',
#  'Ireland',
#  'Spain',
#  'Georgia',
#  'New Zealand',
#  'Mexico',
#  'Sweden',
#  'Iceland',
#  'Estonia',
#  'Montenegro, Republic of',
#  'Liechtenstein',
#  'Israel',
#  'Moldova',
#  'Australia',
#  'Azerbaijan',
#  'Korea',
#  'Turkey',
#  'Malta',
#  'Armenia',
#  'Finland',
#  'Portugal',
#  'Albania']
# >> Number of rows to erase: 2067

# %%
# Dropping the values
df.dropna(inplace = True)

# %% [markdown]
# # Adding the "Source" Column
#     Rule: Since all the data comes from the same dataset, all rows have the same source, which is the "International Transport Forum"

# %%
dataframeManager.simple_column_insert(df,ColumnName.SOURCE.value,"International Transport Forum")
df
# Out:
#                               Source   Country  \
# 0      International Transport Forum  Slovenia
# 1      International Transport Forum  Slovenia
# 2      International Transport Forum  Slovenia
# 3      International Transport Forum  Slovenia
# 4      International Transport Forum  Slovenia
# ...                              ...       ...
# 13207  International Transport Forum     Korea
# 13208  International Transport Forum     Korea
# 13209  International Transport Forum     Korea
# 13210  International Transport Forum     Korea
# 13211  International Transport Forum     Korea
#
#                                          Variable  Year               Unit  \
# 0           Road freight transport on own account  1970  Tonnes-kilometres
# 1           Road freight transport on own account  1971  Tonnes-kilometres
# 2           Road freight transport on own account  1972  Tonnes-kilometres
# 3           Road freight transport on own account  1973  Tonnes-kilometres
# 4           Road freight transport on own account  1974  Tonnes-kilometres
# ...                                           ...   ...                ...
# 13207  Road freight transport for hire and reward  2013  Tonnes-kilometres
# 13208  Road freight transport for hire and reward  2014  Tonnes-kilometres
# 13209  Road freight transport for hire and reward  2015  Tonnes-kilometres
# 13210  Road freight transport for hire and reward  2016  Tonnes-kilometres
# 13211  Road freight transport for hire and reward  2017  Tonnes-kilometres
#
#       PowerCode     Value
# 0      Millions     534.0
# 1      Millions     700.0
# 2      Millions    1098.0
# 3      Millions    1078.0
# 4      Millions     745.0
# ...         ...       ...
# 13207  Millions  118582.0
# 13208  Millions  124650.0
# 13209  Millions  132382.0
# 13210  Millions  135259.0
# 13211  Millions  140374.0
#
# [11145 rows x 7 columns]

# %% [markdown]
# # Determing what countries have missing data related to the "Road" mode and Determining what countries have missing data related to "Total Inland FT" mode.
#
#     Rationale 1: Mode "Road" and VT "All" is broken down into two VTs: "Road freight transport for hire and reward" and "Road freight transport on own account." We need to identify for each country, the years in which the the "All" VT is presented but one if its components is missing.
#
#     Rationale 2: Just as above with the "Road" mode, the "Inland" mode has "All" as VT. However, the components that make up the "All" include the VT "Pipeline," "Inland Waterway," "Rail," and "Road ALL". Therefore, if one of those components are missing for a country, we need to identify it.

# %%
list(set(df["Variable"]))
# Out:
# ['Road freight transport on own account',
#  'Rail freight transport',
#  'Road freight transport for hire and reward',
#  'Total inland freight transport',
#  'Road freight transport',
#  'Pipelines transport',
#  'Inland waterways freight transport']

# %%
# group the datafram by country
df_by_country = df.groupby(df["Country"])

# Variable holding for each country the list of problematic year
result_problematic_countries_road_mode = {}
result_problematic_countries_inland_mode = {}

# Loop through each country
for name, group in df_by_country:
    
    # For country X, group the df by year
    country_x_by_year = group.groupby(group.Year)
    
    # variable holding the problematic years for country X
    problematic_years_road_analysis = []
    problematic_years_inland_analysis = []
    
    # For each year Y in country X, check what values are missing
    for year_name, year_group in country_x_by_year:
        list_of_variables_for_country_x = set(year_group["Variable"])
        
        # Checking for problems with "Road" mode
        if "Road freight transport" in list_of_variables_for_country_x:
            for_hire_name = "Road freight transport for hire and reward"
            on_account_name = "Road freight transport on own account"
            if (for_hire_name not in list_of_variables_for_country_x and on_account_name in list_of_variables_for_country_x) or (for_hire_name in list_of_variables_for_country_x and on_account_name not in list_of_variables_for_country_x):
                problematic_years_road_analysis.append(year_name)

        # Checking for problem with "Inland" Mode
        if "Total inland freight transport" in list_of_variables_for_country_x:
            variables_of_interest_to_be_present = ['Inland waterways freight transport','Road freight transport','Pipelines transport','Rail freight transport']
            is_at_leat_one_variable_of_interest_present = False
            for variable in variables_of_interest_to_be_present:
                if variable in list_of_variables_for_country_x:
                    is_at_leat_one_variable_of_interest_present = True
            
            if is_at_leat_one_variable_of_interest_present == True:
                problematic_years_inland_analysis.append(year_name)
                    
    # Adding the list of problematic years to the country
    if len(problematic_years_road_analysis) > 0:
        result_problematic_countries_road_mode[name] = problematic_years_road_analysis
        
    
    if len(problematic_years_inland_analysis) > 0:
        result_problematic_countries_inland_mode[name] = problematic_years_inland_analysis

print("These are the countries with the year in which there are problem with the Road mode")
# result_problematic_countries_road_mode
result_problematic_countries_inland_mode
# Out:
# These are the countries with the year in which there are problem with the Road mode
# {'Albania': [1970,
#   1971,
#   1972,
#   1973,
#   1974,
#   1975,
#   1976,
#   1977,
#   1978,
#   1979,
#   1980,
#   1981,
#   1982,
#   1983,
#   1984,
#   1985,
#   1986,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013],
#  'Armenia': [2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017],
#  'Australia': [1970,
#   1971,
#   1972,
#   1973,
#   1974,
#   1975,
#   1976,
#   1977,
#   1978,
#   1979,
#   1980,
#   1981,
#   1982,
#   1983,
#   1984,
#   1985,
#   1986,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016],
#  'Austria': [1970,
#   1971,
#   1972,
#   1973,
#   1974,
#   1975,
#   1976,
#   1977,
#   1978,
#   1979,
#   1980,
#   1981,
#   1982,
#   1983,
#   1984,
#   1985,
#   1986,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017,
#   2018],
#  'Azerbaijan': [1970,
#   1971,
#   1972,
#   1973,
#   1974,
#   1975,
#   1976,
#   1977,
#   1978,
#   1979,
#   1980,
#   1981,
#   1982,
#   1983,
#   1984,
#   1985,
#   1986,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017,
#   2018],
#  'Belarus': [1970,
#   1971,
#   1972,
#   1973,
#   1974,
#   1975,
#   1976,
#   1977,
#   1978,
#   1979,
#   1980,
#   1981,
#   1982,
#   1983,
#   1984,
#   1985,
#   1986,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017,
#   2018],
#  'Belgium': [1970,
#   1971,
#   1972,
#   1973,
#   1974,
#   1975,
#   1976,
#   1977,
#   1978,
#   1979,
#   1980,
#   1981,
#   1982,
#   1983,
#   1984,
#   1985,
#   1986,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011],
#  'Bosnia-Herzegovina': [1970,
#   1971,
#   1972,
#   1973,
#   1974,
#   1975,
#   1976,
#   1977,
#   1978,
#   1979,
#   1980,
#   1981,
#   1982,
#   1983,
#   1984,
#   1985,
#   1986,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   2007,
#   2008,
#   2009,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017],
#  'Bulgaria': [1970,
#   1971,
#   1972,
#   1973,
#   1974,
#   1975,
#   1976,
#   1977,
#   1978,
#   1979,
#   1980,
#   1981,
#   1982,
#   1983,
#   1984,
#   1985,
#   1986,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017,
#   2018],
#  'Canada': [1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015],
#  'China': [1978,
#   1980,
#   1985,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017],
#  'Croatia': [1970,
#   1971,
#   1972,
#   1973,
#   1974,
#   1975,
#   1976,
#   1977,
#   1978,
#   1979,
#   1980,
#   1981,
#   1982,
#   1983,
#   1984,
#   1985,
#   1986,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017,
#   2018],
#  'Czech Republic': [1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017,
#   2018],
#  'Denmark': [1970,
#   1971,
#   1972,
#   1973,
#   1974,
#   1975,
#   1976,
#   1977,
#   1978,
#   1979,
#   1980,
#   1981,
#   1982,
#   1983,
#   1984,
#   1985,
#   1986,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016],
#  'Estonia': [1970,
#   1971,
#   1972,
#   1973,
#   1974,
#   1975,
#   1976,
#   1977,
#   1978,
#   1979,
#   1980,
#   1981,
#   1982,
#   1983,
#   1984,
#   1985,
#   1986,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017,
#   2018],
#  'Finland': [1970,
#   1971,
#   1972,
#   1973,
#   1974,
#   1975,
#   1976,
#   1977,
#   1978,
#   1979,
#   1980,
#   1981,
#   1982,
#   1983,
#   1984,
#   1985,
#   1986,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017,
#   2018],
#  'France': [1970,
#   1971,
#   1972,
#   1973,
#   1974,
#   1975,
#   1976,
#   1977,
#   1978,
#   1979,
#   1980,
#   1981,
#   1982,
#   1983,
#   1984,
#   1985,
#   1986,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017,
#   2018],
#  'Georgia': [1999, 2000, 2001, 2002, 2003, 2004, 2005],
#  'Germany': [1970,
#   1971,
#   1972,
#   1973,
#   1974,
#   1975,
#   1976,
#   1977,
#   1978,
#   1979,
#   1980,
#   1981,
#   1982,
#   1983,
#   1984,
#   1985,
#   1986,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017,
#   2018],
#  'Greece': [1970,
#   1971,
#   1972,
#   1973,
#   1974,
#   1975,
#   1976,
#   1977,
#   1978,
#   1979,
#   1980,
#   1981,
#   1982,
#   1983,
#   1984,
#   1985,
#   1986,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016],
#  'Hungary': [1970,
#   1971,
#   1972,
#   1973,
#   1974,
#   1975,
#   1976,
#   1977,
#   1978,
#   1979,
#   1980,
#   1981,
#   1982,
#   1983,
#   1984,
#   1985,
#   1986,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017,
#   2018],
#  'Iceland': [2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017],
#  'India': [1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017],
#  'Ireland': [1979,
#   1980,
#   1981,
#   1982,
#   1983,
#   1984,
#   1985,
#   1986,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017,
#   2018],
#  'Italy': [1971,
#   1972,
#   1973,
#   1974,
#   1975,
#   1976,
#   1977,
#   1978,
#   1979,
#   1980,
#   1981,
#   1982,
#   1983,
#   1984,
#   1985,
#   1986,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017,
#   2018],
#  'Japan': [1970,
#   1971,
#   1972,
#   1973,
#   1974,
#   1975,
#   1976,
#   1977,
#   1978,
#   1979,
#   1980,
#   1981,
#   1982,
#   1983,
#   1984,
#   1985,
#   1986,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017],
#  'Korea': [2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017],
#  'Latvia': [1970,
#   1971,
#   1972,
#   1973,
#   1974,
#   1975,
#   1976,
#   1977,
#   1978,
#   1979,
#   1980,
#   1981,
#   1982,
#   1983,
#   1984,
#   1985,
#   1986,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017,
#   2018],
#  'Liechtenstein': [2007, 2008, 2009, 2010, 2011, 2012, 2013],
#  'Lithuania': [1970,
#   1971,
#   1972,
#   1973,
#   1974,
#   1975,
#   1976,
#   1977,
#   1978,
#   1979,
#   1980,
#   1981,
#   1982,
#   1983,
#   1984,
#   1985,
#   1986,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017,
#   2018],
#  'Luxembourg': [1970,
#   1971,
#   1972,
#   1973,
#   1974,
#   1975,
#   1976,
#   1977,
#   1978,
#   1979,
#   1980,
#   1981,
#   1982,
#   1983,
#   1984,
#   1985,
#   1986,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015],
#  'Mexico': [1970,
#   1971,
#   1972,
#   1973,
#   1974,
#   1975,
#   1976,
#   1977,
#   1978,
#   1979,
#   1980,
#   1981,
#   1982,
#   1983,
#   1984,
#   1985,
#   1986,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017,
#   2018],
#  'Moldova': [1970,
#   1971,
#   1972,
#   1973,
#   1974,
#   1975,
#   1976,
#   1977,
#   1978,
#   1979,
#   1980,
#   1981,
#   1982,
#   1983,
#   1984,
#   1985,
#   1986,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017,
#   2018],
#  'Montenegro, Republic of': [2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017],
#  'Netherlands': [1970,
#   1971,
#   1972,
#   1973,
#   1974,
#   1975,
#   1976,
#   1977,
#   1978,
#   1979,
#   1980,
#   1981,
#   1982,
#   1983,
#   1984,
#   1985,
#   1986,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017,
#   2018],
#  'New Zealand': [1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017,
#   2018],
#  'North Macedonia': [1970,
#   1971,
#   1972,
#   1973,
#   1974,
#   1975,
#   1976,
#   1977,
#   1978,
#   1979,
#   1980,
#   1981,
#   1982,
#   1983,
#   1984,
#   1985,
#   1986,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017,
#   2018],
#  'Norway': [1970,
#   1971,
#   1972,
#   1973,
#   1974,
#   1975,
#   1976,
#   1977,
#   1978,
#   1979,
#   1980,
#   1981,
#   1982,
#   1983,
#   1984,
#   1985,
#   1986,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016],
#  'Poland': [1970,
#   1971,
#   1972,
#   1973,
#   1974,
#   1975,
#   1976,
#   1977,
#   1978,
#   1979,
#   1980,
#   1981,
#   1982,
#   1983,
#   1984,
#   1985,
#   1986,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017,
#   2018],
#  'Portugal': [1979,
#   1980,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017],
#  'Romania': [1970,
#   1971,
#   1972,
#   1973,
#   1974,
#   1975,
#   1976,
#   1977,
#   1978,
#   1979,
#   1980,
#   1981,
#   1982,
#   1983,
#   1984,
#   1985,
#   1986,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017,
#   2018],
#  'Russian Federation': [1970,
#   1971,
#   1972,
#   1973,
#   1974,
#   1975,
#   1976,
#   1977,
#   1978,
#   1979,
#   1980,
#   1981,
#   1982,
#   1983,
#   1984,
#   1985,
#   1986,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017,
#   2018],
#  'Serbia, Republic of': [1970,
#   1971,
#   1972,
#   1973,
#   1974,
#   1975,
#   1976,
#   1977,
#   1978,
#   1979,
#   1980,
#   1981,
#   1982,
#   1983,
#   1984,
#   1985,
#   1986,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017],
#  'Slovak Republic': [1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017,
#   2018],
#  'Slovenia': [1970,
#   1971,
#   1972,
#   1973,
#   1974,
#   1975,
#   1976,
#   1977,
#   1978,
#   1979,
#   1980,
#   1981,
#   1982,
#   1983,
#   1984,
#   1985,
#   1986,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017],
#  'Spain': [1970,
#   1971,
#   1972,
#   1973,
#   1974,
#   1975,
#   1976,
#   1977,
#   1978,
#   1979,
#   1980,
#   1981,
#   1982,
#   1983,
#   1984,
#   1985,
#   1986,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016],
#  'Sweden': [1970,
#   1971,
#   1972,
#   1973,
#   1974,
#   1975,
#   1976,
#   1977,
#   1978,
#   1979,
#   1980,
#   1981,
#   1982,
#   1983,
#   1984,
#   1985,
#   1986,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017,
#   2018],
#  'Switzerland': [1970,
#   1971,
#   1972,
#   1973,
#   1974,
#   1975,
#   1976,
#   1977,
#   1978,
#   1979,
#   1980,
#   1981,
#   1982,
#   1983,
#   1984,
#   1985,
#   1986,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017],
#  'Turkey': [1970,
#   1971,
#   1972,
#   1973,
#   1974,
#   1975,
#   1976,
#   1977,
#   1978,
#   1979,
#   1980,
#   1981,
#   1982,
#   1983,
#   1984,
#   1985,
#   1986,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017,
#   2018],
#  'Ukraine': [1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017,
#   2018],
#  'United Kingdom': [1970,
#   1971,
#   1972,
#   1973,
#   1974,
#   1975,
#   1976,
#   1977,
#   1978,
#   1979,
#   1980,
#   1981,
#   1982,
#   1983,
#   1984,
#   1985,
#   1986,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017,
#   2018],
#  'United States': [1980,
#   1981,
#   1982,
#   1983,
#   1984,
#   1985,
#   1986,
#   1987,
#   1988,
#   1989,
#   1990,
#   1991,
#   1992,
#   1993,
#   1994,
#   1995,
#   1996,
#   1997,
#   1998,
#   1999,
#   2000,
#   2001,
#   2002,
#   2003,
#   2004,
#   2005,
#   2006,
#   2007,
#   2008,
#   2009,
#   2010,
#   2011,
#   2012,
#   2013,
#   2014,
#   2015,
#   2016,
#   2017]}

# %% [markdown]
# # Adding the "Service" column
#     Rule: As seen from the above section, there are seven(7) variables. Six (6) of them are related to freight, while one is related to pipeline. Therefore, depending on the case, the service is either "Freight" or "Pipeline"

# %%
# Variables holding the service value for each row
service_column = []

# For each value row, determine
for index, row in df.iterrows():
    if row["Variable"] == "Pipelines transport":
        service_column.append("Pipeline")
    else:
        service_column.append("Freight")
        
# Adding the service column to the df
df[ColumnName.SERVICE.value] = service_column

# Validating the data by asserting that the service assigned matches with the variable
for index, row in df.iterrows():
    if row["Variable"] == "Pipelines transport":
        assert row["Service"] == "Pipeline"
    else:
        assert row["Service"] == "Freight"

df
# Out:
#                               Source   Country  \
# 0      International Transport Forum  Slovenia
# 1      International Transport Forum  Slovenia
# 2      International Transport Forum  Slovenia
# 3      International Transport Forum  Slovenia
# 4      International Transport Forum  Slovenia
# ...                              ...       ...
# 13207  International Transport Forum     Korea
# 13208  International Transport Forum     Korea
# 13209  International Transport Forum     Korea
# 13210  International Transport Forum     Korea
# 13211  International Transport Forum     Korea
#
#                                          Variable  Year               Unit  \
# 0           Road freight transport on own account  1970  Tonnes-kilometres
# 1           Road freight transport on own account  1971  Tonnes-kilometres
# 2           Road freight transport on own account  1972  Tonnes-kilometres
# 3           Road freight transport on own account  1973  Tonnes-kilometres
# 4           Road freight transport on own account  1974  Tonnes-kilometres
# ...                                           ...   ...                ...
# 13207  Road freight transport for hire and reward  2013  Tonnes-kilometres
# 13208  Road freight transport for hire and reward  2014  Tonnes-kilometres
# 13209  Road freight transport for hire and reward  2015  Tonnes-kilometres
# 13210  Road freight transport for hire and reward  2016  Tonnes-kilometres
# 13211  Road freight transport for hire and reward  2017  Tonnes-kilometres
#
#       PowerCode     Value  Service
# 0      Millions     534.0  Freight
# 1      Millions     700.0  Freight
# 2      Millions    1098.0  Freight
# 3      Millions    1078.0  Freight
# 4      Millions     745.0  Freight
# ...         ...       ...      ...
# 13207  Millions  118582.0  Freight
# 13208  Millions  124650.0  Freight
# 13209  Millions  132382.0  Freight
# 13210  Millions  135259.0  Freight
# 13211  Millions  140374.0  Freight
#
# [11145 rows x 8 columns]

# %% [markdown]
# # Adding the "Fuel" and "Technology" columns
#     Rule: The dataset does not provide any information about fuel and technology. Therefore, we assing "All" to both cases.

# %%
dataframeManager.simple_column_insert(df,ColumnName.TECHNOLOGY.value,"All")
dataframeManager.simple_column_insert(df,ColumnName.FUEL.value,"All")
df
# Out:
#       Fuel Technology                         Source   Country  \
# 0      All        All  International Transport Forum  Slovenia
# 1      All        All  International Transport Forum  Slovenia
# 2      All        All  International Transport Forum  Slovenia
# 3      All        All  International Transport Forum  Slovenia
# 4      All        All  International Transport Forum  Slovenia
# ...    ...        ...                            ...       ...
# 13207  All        All  International Transport Forum     Korea
# 13208  All        All  International Transport Forum     Korea
# 13209  All        All  International Transport Forum     Korea
# 13210  All        All  International Transport Forum     Korea
# 13211  All        All  International Transport Forum     Korea
#
#                                          Variable  Year               Unit  \
# 0           Road freight transport on own account  1970  Tonnes-kilometres
# 1           Road freight transport on own account  1971  Tonnes-kilometres
# 2           Road freight transport on own account  1972  Tonnes-kilometres
# 3           Road freight transport on own account  1973  Tonnes-kilometres
# 4           Road freight transport on own account  1974  Tonnes-kilometres
# ...                                           ...   ...                ...
# 13207  Road freight transport for hire and reward  2013  Tonnes-kilometres
# 13208  Road freight transport for hire and reward  2014  Tonnes-kilometres
# 13209  Road freight transport for hire and reward  2015  Tonnes-kilometres
# 13210  Road freight transport for hire and reward  2016  Tonnes-kilometres
# 13211  Road freight transport for hire and reward  2017  Tonnes-kilometres
#
#       PowerCode     Value  Service
# 0      Millions     534.0  Freight
# 1      Millions     700.0  Freight
# 2      Millions    1098.0  Freight
# 3      Millions    1078.0  Freight
# 4      Millions     745.0  Freight
# ...         ...       ...      ...
# 13207  Millions  118582.0  Freight
# 13208  Millions  124650.0  Freight
# 13209  Millions  132382.0  Freight
# 13210  Millions  135259.0  Freight
# 13211  Millions  140374.0  Freight
#
# [11145 rows x 10 columns]

# %% [markdown]
# # Adding the "Mode" column
#     Rule: The mapping from each variable to the corresponding Mode is as follows:
#
#          'Road freight transport' --> Road
#          'Road freight transport for hire and reward' --> Road
#          'Road freight transport on own account' --> Road
#          'Rail freight transport' --> Rail
#          'Pipelines transport' --> Pipeline
#          'Inland waterways freight transport' --> Shipping
#          'Total inland freight transport' --> Inland

# %%
# Variable holding info about mode of each column
mode_column = []

# For each row, do the following analysis
for index, row in df.iterrows():
    if "Road" in row["Variable"]:
        mode_column.append("Road")
        
    elif "Rail" in row["Variable"]:
        mode_column.append("Rail")
        
    elif "Pipelines" in row["Variable"]:
        mode_column.append("Pipeline")
        
    elif row["Variable"] == "Inland waterways freight transport" :
        mode_column.append("Shipping")
    
    elif row["Variable"] == "Total inland freight transport":
        mode_column.append("Inland")

# Assigning the mode column to the df
df[ColumnName.MODE.value] = mode_column
df
# Out:
#       Fuel Technology                         Source   Country  \
# 0      All        All  International Transport Forum  Slovenia
# 1      All        All  International Transport Forum  Slovenia
# 2      All        All  International Transport Forum  Slovenia
# 3      All        All  International Transport Forum  Slovenia
# 4      All        All  International Transport Forum  Slovenia
# ...    ...        ...                            ...       ...
# 13207  All        All  International Transport Forum     Korea
# 13208  All        All  International Transport Forum     Korea
# 13209  All        All  International Transport Forum     Korea
# 13210  All        All  International Transport Forum     Korea
# 13211  All        All  International Transport Forum     Korea
#
#                                          Variable  Year               Unit  \
# 0           Road freight transport on own account  1970  Tonnes-kilometres
# 1           Road freight transport on own account  1971  Tonnes-kilometres
# 2           Road freight transport on own account  1972  Tonnes-kilometres
# 3           Road freight transport on own account  1973  Tonnes-kilometres
# 4           Road freight transport on own account  1974  Tonnes-kilometres
# ...                                           ...   ...                ...
# 13207  Road freight transport for hire and reward  2013  Tonnes-kilometres
# 13208  Road freight transport for hire and reward  2014  Tonnes-kilometres
# 13209  Road freight transport for hire and reward  2015  Tonnes-kilometres
# 13210  Road freight transport for hire and reward  2016  Tonnes-kilometres
# 13211  Road freight transport for hire and reward  2017  Tonnes-kilometres
#
#       PowerCode     Value  Service  Mode
# 0      Millions     534.0  Freight  Road
# 1      Millions     700.0  Freight  Road
# 2      Millions    1098.0  Freight  Road
# 3      Millions    1078.0  Freight  Road
# 4      Millions     745.0  Freight  Road
# ...         ...       ...      ...   ...
# 13207  Millions  118582.0  Freight  Road
# 13208  Millions  124650.0  Freight  Road
# 13209  Millions  132382.0  Freight  Road
# 13210  Millions  135259.0  Freight  Road
# 13211  Millions  140374.0  Freight  Road
#
# [11145 rows x 11 columns]

# %% [markdown]
# # Adding the "Vehicle Type" column
#     Rule: The mapping from each variable to the corresponding Vehicle Type is as follows:
#
#          'Pipelines transport' --> Pipeline
#          'Rail freight transport' --> All
#          'Road freight transport' --> All
#          'Road freight transport for hire and reward' --> For Hire and Reward
#          'Road freight transport on own account' --> For Own Account
#          'Inland waterways freight transport' --> Inland
#          'Total inland freight transport' --> All

# %%
# Variable holding the vehhicle type
vehicle_type = []

# For each row, do the following:
for index, row in df.iterrows():
    if row["Variable"] == "Pipelines transport":
        vehicle_type.append("Pipeline")
        
    elif row["Variable"] == "Rail freight transport":
        vehicle_type.append("All")
        
    elif row["Variable"] == "Road freight transport":
        vehicle_type.append("All")
        
    elif row["Variable"] == "Road freight transport for hire and reward":
        vehicle_type.append("For hire and reward")
    
    elif row["Variable"] == "Road freight transport on own account":
        vehicle_type.append("For Own Account")
    
    elif row["Variable"] == "Inland waterways freight transport":
        vehicle_type.append("Inland Waterway")
    
    elif row["Variable"] == "Total inland freight transport":
        vehicle_type.append("All")

# Adding the vehicle type column
df[ColumnName.VEHICLE_TYPE.value] = vehicle_type
df
# Out:
#       Fuel Technology                         Source   Country  \
# 0      All        All  International Transport Forum  Slovenia
# 1      All        All  International Transport Forum  Slovenia
# 2      All        All  International Transport Forum  Slovenia
# 3      All        All  International Transport Forum  Slovenia
# 4      All        All  International Transport Forum  Slovenia
# ...    ...        ...                            ...       ...
# 13207  All        All  International Transport Forum     Korea
# 13208  All        All  International Transport Forum     Korea
# 13209  All        All  International Transport Forum     Korea
# 13210  All        All  International Transport Forum     Korea
# 13211  All        All  International Transport Forum     Korea
#
#                                          Variable  Year               Unit  \
# 0           Road freight transport on own account  1970  Tonnes-kilometres
# 1           Road freight transport on own account  1971  Tonnes-kilometres
# 2           Road freight transport on own account  1972  Tonnes-kilometres
# 3           Road freight transport on own account  1973  Tonnes-kilometres
# 4           Road freight transport on own account  1974  Tonnes-kilometres
# ...                                           ...   ...                ...
# 13207  Road freight transport for hire and reward  2013  Tonnes-kilometres
# 13208  Road freight transport for hire and reward  2014  Tonnes-kilometres
# 13209  Road freight transport for hire and reward  2015  Tonnes-kilometres
# 13210  Road freight transport for hire and reward  2016  Tonnes-kilometres
# 13211  Road freight transport for hire and reward  2017  Tonnes-kilometres
#
#       PowerCode     Value  Service  Mode         Vehicle Type
# 0      Millions     534.0  Freight  Road      For Own Account
# 1      Millions     700.0  Freight  Road      For Own Account
# 2      Millions    1098.0  Freight  Road      For Own Account
# 3      Millions    1078.0  Freight  Road      For Own Account
# 4      Millions     745.0  Freight  Road      For Own Account
# ...         ...       ...      ...   ...                  ...
# 13207  Millions  118582.0  Freight  Road  For hire and reward
# 13208  Millions  124650.0  Freight  Road  For hire and reward
# 13209  Millions  132382.0  Freight  Road  For hire and reward
# 13210  Millions  135259.0  Freight  Road  For hire and reward
# 13211  Millions  140374.0  Freight  Road  For hire and reward
#
# [11145 rows x 12 columns]

# %% [markdown]
# # Analyzing how many units are available

# %%
set(df["Unit"])
# Out:
# {'Tonnes-kilometres'}

# %% [markdown]
# # Setting the "Unit" column
#     Rule: Since there the dataset only has one unit, we will change it to the appropriate unit which is "10 ^9 tonnes - km / yr"

# %%
# Erasing the current "Unit" column
df.drop(columns=["Unit"], inplace = True)
dataframeManager.simple_column_insert(df,ColumnName.UNIT.value,"10^9 tonne-km / yr")
df
# Out:
#                      Unit Fuel Technology                         Source  \
# 0      10^9 tonne-km / yr  All        All  International Transport Forum
# 1      10^9 tonne-km / yr  All        All  International Transport Forum
# 2      10^9 tonne-km / yr  All        All  International Transport Forum
# 3      10^9 tonne-km / yr  All        All  International Transport Forum
# 4      10^9 tonne-km / yr  All        All  International Transport Forum
# ...                   ...  ...        ...                            ...
# 13207  10^9 tonne-km / yr  All        All  International Transport Forum
# 13208  10^9 tonne-km / yr  All        All  International Transport Forum
# 13209  10^9 tonne-km / yr  All        All  International Transport Forum
# 13210  10^9 tonne-km / yr  All        All  International Transport Forum
# 13211  10^9 tonne-km / yr  All        All  International Transport Forum
#
#         Country                                    Variable  Year PowerCode  \
# 0      Slovenia       Road freight transport on own account  1970  Millions
# 1      Slovenia       Road freight transport on own account  1971  Millions
# 2      Slovenia       Road freight transport on own account  1972  Millions
# 3      Slovenia       Road freight transport on own account  1973  Millions
# 4      Slovenia       Road freight transport on own account  1974  Millions
# ...         ...                                         ...   ...       ...
# 13207     Korea  Road freight transport for hire and reward  2013  Millions
# 13208     Korea  Road freight transport for hire and reward  2014  Millions
# 13209     Korea  Road freight transport for hire and reward  2015  Millions
# 13210     Korea  Road freight transport for hire and reward  2016  Millions
# 13211     Korea  Road freight transport for hire and reward  2017  Millions
#
#           Value  Service  Mode         Vehicle Type
# 0         534.0  Freight  Road      For Own Account
# 1         700.0  Freight  Road      For Own Account
# 2        1098.0  Freight  Road      For Own Account
# 3        1078.0  Freight  Road      For Own Account
# 4         745.0  Freight  Road      For Own Account
# ...         ...      ...   ...                  ...
# 13207  118582.0  Freight  Road  For hire and reward
# 13208  124650.0  Freight  Road  For hire and reward
# 13209  132382.0  Freight  Road  For hire and reward
# 13210  135259.0  Freight  Road  For hire and reward
# 13211  140374.0  Freight  Road  For hire and reward
#
# [11145 rows x 12 columns]

# %% [markdown]
# # Setting the "Value" column
#     Rule: The magnitude of the value is millions. We are changing it to billion, given than 1B = 1000M

# %%
# Variable holding the new magnitude
magnitude_in_billion = []

for index, row in df.iterrows():
    current_magnitude = row["Value"]
    new_magnitude = current_magnitude/1000
    magnitude_in_billion.append(new_magnitude)

# Removing the old magnitude
df.drop(columns=["Value"], inplace=True)

# Adding the new values in Billion
df[ColumnName.VALUE.value] = magnitude_in_billion
df
# Out:
#                      Unit Fuel Technology                         Source  \
# 0      10^9 tonne-km / yr  All        All  International Transport Forum
# 1      10^9 tonne-km / yr  All        All  International Transport Forum
# 2      10^9 tonne-km / yr  All        All  International Transport Forum
# 3      10^9 tonne-km / yr  All        All  International Transport Forum
# 4      10^9 tonne-km / yr  All        All  International Transport Forum
# ...                   ...  ...        ...                            ...
# 13207  10^9 tonne-km / yr  All        All  International Transport Forum
# 13208  10^9 tonne-km / yr  All        All  International Transport Forum
# 13209  10^9 tonne-km / yr  All        All  International Transport Forum
# 13210  10^9 tonne-km / yr  All        All  International Transport Forum
# 13211  10^9 tonne-km / yr  All        All  International Transport Forum
#
#         Country                                    Variable  Year PowerCode  \
# 0      Slovenia       Road freight transport on own account  1970  Millions
# 1      Slovenia       Road freight transport on own account  1971  Millions
# 2      Slovenia       Road freight transport on own account  1972  Millions
# 3      Slovenia       Road freight transport on own account  1973  Millions
# 4      Slovenia       Road freight transport on own account  1974  Millions
# ...         ...                                         ...   ...       ...
# 13207     Korea  Road freight transport for hire and reward  2013  Millions
# 13208     Korea  Road freight transport for hire and reward  2014  Millions
# 13209     Korea  Road freight transport for hire and reward  2015  Millions
# 13210     Korea  Road freight transport for hire and reward  2016  Millions
# 13211     Korea  Road freight transport for hire and reward  2017  Millions
#
#        Service  Mode         Vehicle Type    Value
# 0      Freight  Road      For Own Account    0.534
# 1      Freight  Road      For Own Account    0.700
# 2      Freight  Road      For Own Account    1.098
# 3      Freight  Road      For Own Account    1.078
# 4      Freight  Road      For Own Account    0.745
# ...        ...   ...                  ...      ...
# 13207  Freight  Road  For hire and reward  118.582
# 13208  Freight  Road  For hire and reward  124.650
# 13209  Freight  Road  For hire and reward  132.382
# 13210  Freight  Road  For hire and reward  135.259
# 13211  Freight  Road  For hire and reward  140.374
#
# [11145 rows x 12 columns]

# %% [markdown]
# # Setting the "Variable" column
#     Rule: Since all data is associated to freight, the variable is "Freight Activity"

# %%
# Removing the current variable column
df.drop(columns=["Variable"], inplace=True)

# Adding the new "Variable" column
df[ColumnName.VARIABLE.value] = ["Freight Activity"] * len(df)
df
# Out:
#                      Unit Fuel Technology                         Source  \
# 0      10^9 tonne-km / yr  All        All  International Transport Forum
# 1      10^9 tonne-km / yr  All        All  International Transport Forum
# 2      10^9 tonne-km / yr  All        All  International Transport Forum
# 3      10^9 tonne-km / yr  All        All  International Transport Forum
# 4      10^9 tonne-km / yr  All        All  International Transport Forum
# ...                   ...  ...        ...                            ...
# 13207  10^9 tonne-km / yr  All        All  International Transport Forum
# 13208  10^9 tonne-km / yr  All        All  International Transport Forum
# 13209  10^9 tonne-km / yr  All        All  International Transport Forum
# 13210  10^9 tonne-km / yr  All        All  International Transport Forum
# 13211  10^9 tonne-km / yr  All        All  International Transport Forum
#
#         Country  Year PowerCode  Service  Mode         Vehicle Type    Value  \
# 0      Slovenia  1970  Millions  Freight  Road      For Own Account    0.534
# 1      Slovenia  1971  Millions  Freight  Road      For Own Account    0.700
# 2      Slovenia  1972  Millions  Freight  Road      For Own Account    1.098
# 3      Slovenia  1973  Millions  Freight  Road      For Own Account    1.078
# 4      Slovenia  1974  Millions  Freight  Road      For Own Account    0.745
# ...         ...   ...       ...      ...   ...                  ...      ...
# 13207     Korea  2013  Millions  Freight  Road  For hire and reward  118.582
# 13208     Korea  2014  Millions  Freight  Road  For hire and reward  124.650
# 13209     Korea  2015  Millions  Freight  Road  For hire and reward  132.382
# 13210     Korea  2016  Millions  Freight  Road  For hire and reward  135.259
# 13211     Korea  2017  Millions  Freight  Road  For hire and reward  140.374
#
#                Variable
# 0      Freight Activity
# 1      Freight Activity
# 2      Freight Activity
# 3      Freight Activity
# 4      Freight Activity
# ...                 ...
# 13207  Freight Activity
# 13208  Freight Activity
# 13209  Freight Activity
# 13210  Freight Activity
# 13211  Freight Activity
#
# [11145 rows x 12 columns]

# %% [markdown]
# # Creating a Mode "Inland (exl. Pipeline)" which is the same as the "Inland" mode but without pipeline data

# %%
# Creating the new variable 
df_grouping_by_country = df.groupby(df["Country"])

# Variable holding the complete data
complete_data_per_country = {}

# For each country group, do the following
for country_name, country_group in df_grouping_by_country:
    # Group country X by year
    year_group_country_x = country_group.groupby(country_group["Year"])
    
    # Variable holding the information about <year, inland exl pipeline>
    local_result_per_year = {}
    
    # Loop each year
    for year_name, year_group in year_group_country_x:
        # Variable holding the sum for the year
        inland_exl_pipeline = 0
        
        # Loop through each data available for each year
        for index, row in year_group.iterrows():
            if row["Mode"] != "Inland" and row["Mode"] != "Pipeline" and row["Vehicle Type"] != "For Own Account" and row["Vehicle Type"] != "For hire and reward":
                inland_exl_pipeline = inland_exl_pipeline + row["Value"]
        
        # Setting the result 
        local_result_per_year[year_name] = inland_exl_pipeline
    
    # Assing the result to the country
    complete_data_per_country[country_name] = local_result_per_year

# Printing all the data
complete_data_per_country
# Out:
# {'Albania': {1970: 0.936,
#   1971: 1.025,
#   1972: 1.2,
#   1973: 1.134,
#   1974: 1.16,
#   1975: 1.3639999999999999,
#   1976: 1.23,
#   1977: 1.26,
#   1978: 1.5030000000000001,
#   1979: 1.649,
#   1980: 1.779,
#   1981: 1.7440000000000002,
#   1982: 1.896,
#   1983: 1.917,
#   1984: 1.896,
#   1985: 1.826,
#   1986: 1.8250000000000002,
#   1987: 1.897,
#   1988: 1.894,
#   1989: 1.9780000000000002,
#   1990: 1.779,
#   1991: 0.909,
#   1992: 0.6040000000000001,
#   1993: 1.464,
#   1994: 1.9929999999999999,
#   1995: 2.13,
#   1996: 2.29,
#   1997: 1.363,
#   1998: 1.855,
#   1999: 2.037,
#   2000: 2.192,
#   2001: 2.25,
#   2002: 2.3729999999999998,
#   2003: 2.562,
#   2004: 2.83,
#   2005: 3.2359999999999998,
#   2006: 3.342,
#   2007: 3.637,
#   2008: 4.1499999999999995,
#   2009: 4.4910000000000005,
#   2010: 4.692,
#   2011: 3.855,
#   2012: 3.2479999999999998,
#   2013: 3.52,
#   2014: 0.039887,
#   2015: 0.023124000000000002,
#   2016: 0.0088,
#   2017: 0.0253,
#   2018: 0.020399999999999998},
#  'Argentina': {1994: 6.663,
#   1995: 7.613,
#   1996: 8.506,
#   1997: 9.835,
#   1998: 9.824,
#   1999: 9.102,
#   2000: 8.696,
#   2001: 8.987,
#   2002: 9.445,
#   2003: 10.989,
#   2004: 11.603,
#   2005: 12.262,
#   2006: 12.628,
#   2007: 12.871,
#   2008: 12.025,
#   2009: 10.649,
#   2010: 12.112,
#   2011: 12.198,
#   2012: 10.583,
#   2013: 9.746,
#   2014: 8.893,
#   2015: 8.274,
#   2016: 8.529,
#   2017: 8.377},
#  'Armenia': {1997: 0.381,
#   1998: 0.419,
#   1999: 0.323,
#   2000: 0.354,
#   2001: 0.487,
#   2002: 0.657,
#   2003: 0.809,
#   2004: 0.888,
#   2005: 0.885,
#   2006: 1.1,
#   2007: 1.4809999999999999,
#   2008: 1.7389999999999999,
#   2009: 0.8999999999999999,
#   2010: 0.979,
#   2011: 1.103,
#   2012: 1.268,
#   2013: 1.335,
#   2014: 1.33,
#   2015: 1.119,
#   2016: 1.334,
#   2017: 1.415},
#  'Australia': {1970: 60.814,
#   1971: 66.23400000000001,
#   1972: 69.638,
#   1973: 77.1028984,
#   1974: 87.55749637,
#   1975: 90.43109333,
#   1976: 89.53003859,
#   1977: 94.55601364,
#   1978: 97.86942593,
#   1979: 103.57953306,
#   1980: 110.87710576,
#   1981: 117.15700883,
#   1982: 120.44624845999999,
#   1983: 114.9480671,
#   1984: 127.73727099,
#   1985: 140.51857538,
#   1986: 149.03826217,
#   1987: 154.03204234,
#   1988: 162.61548735,
#   1989: 164.86995794,
#   1990: 175.80898953,
#   1991: 176.45802635,
#   1992: 184.53953359,
#   1993: 190.82031449,
#   1994: 198.34021223999997,
#   1995: 207.57734549999998,
#   1996: 217.6581838,
#   1981: 21.942,
#   1982: 22.527,
#   1983: 23.185,
#   1984: 24.208,
#   1985: 23.897,
#   1986: 25.065,
#   1987: 25.068,
#   1988: 24.784,
#   1989: 25.715000000000003,
#   1990: 19.021,
#   1991: 16.478,
#   1992: 13.131,
#   1993: 5.423,
#   1994: 5.0920000000000005,
#   1995: 6.234,
#   1996: 8.031,
#   1997: 5.191,
#   1998: 5.006,
#   1999: 2.52,
#   2000: 3.479,
#   2001: 3.447,
#   2002: 3.7940000000000005,
#   2003: 3.8770000000000002,
#   2004: 4.556,
#   2005: 5.784,
#   2006: 6.67,
#   2007: 7.295999999999999,
#   2008: 6.82,
#   2009: 5.266,
#   2010: 6.086,
#   2011: 6.481000000000001,
#   2012: 5.848000000000001,
#   2013: 6.547,
#   2014: 6.706,
#   2015: 7.08,
#   2016: 8.312000000000001,
#   2017: 8.993},
#  'Slovak Republic': {1993: 21.877000000000002,
#   1994: 25.011000000000003,
#   1995: 41.678,
#   1996: 29.465,
#   1997: 29.241999999999997,
#   1998: 30.972,
#   1999: 30.037999999999997,
#   2000: 26.958,
#   2001: 25.743000000000002,
#   2002: 25.906,
#   2003: 27.520000000000003,
#   2004: 28.939999999999998,
#   2005: 32.693,
#   2006: 33.038,
#   2007: 37.701,
#   2008: 39.494,
#   2009: 35.347,
#   2010: 36.705,
#   2011: 37.936,
#   2012: 38.081,
#   2013: 39.504999999999995,
#   2014: 41.038,
#   2015: 42.705,
#   2016: 46.120000000000005,
#   2017: 44.781000000000006,
#   2018: 45.059000000000005},
#  'Slovenia': {1970: 5.425,
#   1971: 5.58,
#   1972: 5.824,
#   1973: 6.263999999999999,
#   1974: 6.689,
#   1975: 6.2490000000000006,
#   1976: 6.728,
#   1977: 7.088,
#   1978: 7.697,
#   1979: 7.872,
#   1980: 7.765000000000001,
#   1981: 7.848000000000001,
#   1982: 8.198,
#   1983: 8.186,
#   1984: 8.776,
#   1985: 8.977,
#   1986: 8.917,
#   1987: 9.163,
#   1988: 9.439,
#   1989: 9.642,
#   1990: 9.096,
#   1991: 7.568,
#   1992: 4.009,
#   1993: 3.69,
#   1994: 4.005,
#   1995: 4.7780000000000005,
#   1996: 4.337,
#   1997: 4.648,
#   1998: 4.723,
#   1999: 4.678,
#   2000: 4.7940000000000005,
#   2001: 4.764,
#   2002: 5.023,
#   2003: 5.269,
#   2004: 5.416,
#   2005: 5.606,
#   2006: 5.652,
#   2007: 6.175000000000001,
#   2008: 6.154999999999999,
#   2009: 4.944,
#   2010: 5.71,
#   2011: 5.928,
#   2012: 5.319,
#   2013: 5.688,
#   2014: 6.172000000000001,
#   2015: 6.244,
#   2016: 6.495,
#   2017: 7.439},
#  'Spain': {1970: 62.039,
#   1971: 68.712,
#   1972: 75.853,
#   1973: 82.80199999999999,
#   1974: 90.109,
#   1975: 87.57900000000001,
#   1976: 90.35900000000001,
#   1977: 96.626,
#   1978: 99.877,
#   1979: 103.11200000000001,
#   1980: 100.782,
#   1981: 115.22200000000001,
#   1982: 116.628,
#   1983: 118.019,
#   1984: 119.67699999999999,
#   1985: 122.575,
#   2009: 160.15847749000002,
#   2010: 172.53041986,
#   2011: 171.20741716999999,
#   2012: 174.32954215,
#   2013: 163.48644861999998,
#   2014: 159.18488492000003,
#   2015: 171.26758857540003,
#   2016: 174.81785615,
#   2017: 173.33015981,
#   2018: 178.41096332},
#  'United States': {1980: 3632.003,
#   1981: 3630.1130000000003,
#   1982: 3450.6639999999998,
#   1983: 3599.6389999999997,
#   1984: 3817.383,
#   1985: 3794.478,
#   1986: 3885.682,
#   1987: 4114.433,
#   1988: 4327.147000000001,
#   1989: 4442.242,
#   1990: 4562.5650000000005,
#   1991: 4574.296,
#   1992: 4734.046,
#   1993: 4879.284,
#   1994: 5203.878000000001,
#   1995: 5493.994000000001,
#   1996: 5647.763,
#   1997: 5812.483,
#   1998: 5954.484,
#   1999: 6077.581,
#   2000: 6180.472,
#   2001: 6288.259,
#   2002: 6395.099,
#   2003: 6435.842000000001,
#   2004: 6498.1810000000005,
#   2005: 6588.799,
#   2006: 6707.974,
#   2007: 6770.270999999999,
#   2008: 6998.545,
#   2009: 6292.634,
#   2010: 6610.056,
#   2011: 6848.869000000001,
#   2012: 5716.241,
#   2013: 5825.031,
#   2014: 6098.066999999999,
#   2015: 5928.872,
#   2016: 5707.325999999999,
#   2017: 5402.67,
#   2018: 2523.408}}

# %%
# Getting the list of countries
list_of_countries = complete_data_per_country.keys()

for country in list_of_countries:
    # Getting list of years
    dic_new_value_per_country = complete_data_per_country[country]
    list_of_years = list(complete_data_per_country[country].keys())
    
    # Loop through each year
    for year in list_of_years:
        value = dic_new_value_per_country[year]
        local_DF = pd.DataFrame({ColumnName.SOURCE.value:["International Transport Forum"],ColumnName.COUNTRY.value:[country],ColumnName.VARIABLE.value:["Freight Activity"],ColumnName.UNIT.value:["10^9 tonne-km / yr"],ColumnName.SERVICE.value:["Freight"], ColumnName.MODE.value:["Inland (exl. Pipeline)"], ColumnName.VEHICLE_TYPE.value:["All"], ColumnName.TECHNOLOGY.value:["All"], ColumnName.FUEL.value:["All"], ColumnName.VALUE.value:[value], ColumnName.YEAR.value:[year]})
        df.append(local_DF,ignore_index = True, sort=False)
        df = pd.concat([df, local_DF],ignore_index=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:14: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
df
# Out:
#              Country Fuel                    Mode PowerCode  Service  \
# 0           Slovenia  All                    Road  Millions  Freight
# 1           Slovenia  All                    Road  Millions  Freight
# 2           Slovenia  All                    Road  Millions  Freight
# 3           Slovenia  All                    Road  Millions  Freight
# 4           Slovenia  All                    Road  Millions  Freight
# ...              ...  ...                     ...       ...      ...
# 13458  United States  All  Inland (exl. Pipeline)       NaN  Freight
# 13459  United States  All  Inland (exl. Pipeline)       NaN  Freight
# 13460  United States  All  Inland (exl. Pipeline)       NaN  Freight
# 13461  United States  All  Inland (exl. Pipeline)       NaN  Freight
# 13462  United States  All  Inland (exl. Pipeline)       NaN  Freight
#
#                               Source Technology                Unit     Value  \
# 0      International Transport Forum        All  10^9 tonne-km / yr     0.534
# 1      International Transport Forum        All  10^9 tonne-km / yr     0.700
# 2      International Transport Forum        All  10^9 tonne-km / yr     1.098
# 3      International Transport Forum        All  10^9 tonne-km / yr     1.078
# 4      International Transport Forum        All  10^9 tonne-km / yr     0.745
# ...                              ...        ...                 ...       ...
# 13458  International Transport Forum        All  10^9 tonne-km / yr  6098.067
# 13459  International Transport Forum        All  10^9 tonne-km / yr  5928.872
# 13460  International Transport Forum        All  10^9 tonne-km / yr  5707.326
# 13461  International Transport Forum        All  10^9 tonne-km / yr  5402.670
# 13462  International Transport Forum        All  10^9 tonne-km / yr  2523.408
#
#                Variable     Vehicle Type  Year
# 0      Freight Activity  For Own Account  1970
# 1      Freight Activity  For Own Account  1971
# 2      Freight Activity  For Own Account  1972
# 3      Freight Activity  For Own Account  1973
# 4      Freight Activity  For Own Account  1974
# ...                 ...              ...   ...
# 13458  Freight Activity              All  2014
# 13459  Freight Activity              All  2015
# 13460  Freight Activity              All  2016
# 13461  Freight Activity              All  2017
# 13462  Freight Activity              All  2018
#
# [13463 rows x 12 columns]

# %% [markdown]
# # Removing inconsistent data from selected countries. See section: *"Determing what countries have missing data related to the "Road" mode and Determining what countries have missing data related to "Total Inland FT" mode"* Each Country is handled as follows:
#     >> Albania:
#         - Remove all rows with mode "Inland" for range [1970 - 2002] --> Road data is missing
#         - Remove all rows with mode "Inland (Exl. Pipeline)" for range [1970 - 2002] --> Road data is missing
#
#     >> Armenia:
#         - Remove all rows with mode "Inland (Exl. Pipeline)" for range [1970 - 2002] -->
#
#     >> Belarus:
#         - Remove all rows with mode "Inland" for range [1970 - 1995] --> Pipeline data is missing
#
#     >> Belgium
#         - Remove all rows with mode "Inland (Exl. Pipeline)" for range [2012 - 2018] --> Rail data is missing
#
#     >> Bosnia-Herzegovina:
#         - Remove all rows with mode "Inland" for range [1998 - 2006] and 2010 --> Road data is missing
#         - Remove all rows with mode "Inland (Exl. Pipeline)" for range [1998 - 2006] and 2010 --> Road data is missing
#
#     >> Bulgaria:
#         - Remove all rows with mode "Inland" for range [1970 - 1977] --> Pipeline data is missing
#
#     >> Canada:
#         - Remove all rows with mode "Inland" for range [1970 - 1994] and [2014-2018] --> Multiple data is missing
#         - Remove all rows with mode "Inland (Exl. Pipeline)" for range [1970 - 1995] and [2014-2018] --> Multiple data is missing
#
#     >> China:
#         - Remove all rows with mode "Inland" for range [1970 - 1977], [1979], [1981 - 1984], and [1986 - 1989] --> Road data is missing
#         - Remove all rows with mode "Inland (Exl. Pipeline)" for range [1970 - 1977], [1979], [1981 - 1984], and [1986 - 1989] --> Road data is missing
#
#     >> Croatia
#         - Remove all rows with mode "Inland" for range [1970 - 1995] --> Multiple data is missing
#         - Remove all rows with mode "Inland (Exl. Pipeline)" for range [1970 - 1995] --> Multiple data is missing
#
#     >> Czech Republic:
#         - Remove all rows with mode "Inland" for range [1970 - 1992] --> Road data is missing
#         - Remove all rows with mode "Inland (Exl. Pipeline)" for range [1970 - 1992] --> Road data is missing
#
#     >> Denmark:
#         - Remove all rows with mode "Inland" for range [1971 - 1983] --> Pipeline data is missing
#
#     >> Greece:
#         - Remove all rows with mode "Inland" for range [2018]
#         - Remove all rows with mode "Inland (Exl. Pipeline)" for range [2018]
#
#     >> India:
#         - Remove all rows with mode "Inland" for range [1970 - 2004] and [2013 - 2017]
#         - Remove all rows with mode "Inland (Exl. Pipeline)" for range [1970 - 2004]
#
#     >> Ireland:
#         - Remove all rows with mode "Inland" for range [1979]
#         - Remove all rows with mode "Road" and VT "All" for range [1979]
#         - Remove all rows with mode "Inland (Exl. Pipeline)" for range [1979]
#
#     >> Japan
#         - Remove all rows with mode "Inland" for range [2018]
#         - Remove all rows with mode "Inland (Exl. Pipeline)" for range [2018]
#
#     >> Korea:
#         - Remove all rows with mode "Inland" for range [2018]
#         - Remove all rows with mode "Inland (Exl. Pipeline)" for range [2018]
#
#     >> Latvia:
#         - Remove all rows with mode "Inland" for range [1970 - 1994]
#
#     >> Liechtenstein:
#         - Remove all rows with mode "Inland" for range [2005 - 2006]
#         - Remove all rows with mode "Inland (Exl. Pipeline)" for range [2005 - 2006]
#
#     >> New Zealand:
#         - Remove all rows with mode "Inland (Exl. Pipeline)" for range [1970 - 1998]
#
#     >> Norway:
#         - Remove all rows with mode "Inland (Exl. Pipeline)" for range [2017]
#
#     >> Portugal:
#         - Remove all rows with mode "Inland (Exl. Pipeline)" for range [1970 - 1978] and [1981-1986]
#
#     >> Serbia, Republic of:
#         - Remove all rows with mode "Inland" for range [1997 - 2018]
#         - Remove all rows with mode "Road" and VT "All" for range [1997 - 2018]
#         - Remove all rows with mode "Inland (Exl. Pipeline)" for range [1997 - 2018]
#
#     >> Spain:
#         - Remove all rows with mode "Inland" for range [2017 - 2018]
#         - Remove all rows with mode "Inland (Exl. Pipeline)" for range [2017 - 2018]
#
#     >> Switzerland:
#         - Remove all rows with mode "Inland" for range [2018]
#         - Remove all rows with mode "Inland (Exl. Pipeline)" for range [2018]
#
#     >> Ukraine:
#         - Remove all rows with mode "Inland" for range [1990 - 2008]
#         - Remove all rows with mode "Road" and VT "All" for range [1990 - 2008]
#         - Remove all rows with mode "Inland (Exl. Pipeline)" for range [1990 - 2008]
#
#     >> United Kingdom:
#         - Remove all rows with mode "Inland" for range [2013 - 2018]
#
#     >> United States:
#         - Remove all rows with mode "Inland" for range [2012 - 2018]
#         - Remove all rows with mode "Inland (Exl. Pipeline)" for range [2017 - 2018]

# %%
list_of_index_to_erase = []

# 27 Total countries = 21 handled here and 6 handled in coming cells
conditions = {}
conditions["Albania"] = {"years": list(range(1970,2003)), "modes": ["Inland","Inland (exl. Pipeline)"]}
conditions["Armenia"] = {"years": list(range(1970,2003)), "modes": ["Inland (exl. Pipeline)"]}
conditions["Belarus"] = {"years": list(range(1970,1995)), "modes": ["Inland"]}
conditions["Belgium"] = {"years": list(range(2012,2019)), "modes": ["Inland (exl. Pipeline)"]}
conditions["Bosnia-Herzegovina"] = {"years": list(range(1998,2007))+[2010], "modes": ["Inland (exl. Pipeline)"]}
conditions["Bulgaria"] = {"years": list(range(1970,1978)), "modes": ["Inland"]}
conditions["China"] = {"years": list(range(1970,1978))+[1979]+list(range(1981,1985))+list(range(1986,1990)), "modes": ["Inland","Inland (exl. Pipeline)"]}
conditions["Croatia"] = {"years": list(range(1970,1996)), "modes": ["Inland","Inland (exl. Pipeline)"]}
conditions["Czech Republic"] = {"years": list(range(1970,1993)), "modes": ["Inland","Inland (exl. Pipeline)"]}
conditions["Denmark"] = {"years": list(range(1971,1984)), "modes": ["Inland"]}
conditions["Greece"] = {"years": [2018], "modes": ["Inland","Inland (exl. Pipeline)"]}
conditions["Japan"] = {"years": [2018], "modes": ["Inland","Inland (exl. Pipeline)"]}
conditions["Korea"] = {"years": [2018], "modes": ["Inland","Inland (exl. Pipeline)"]}
conditions["Latvia"] = {"years": list(range(1970,1995)), "modes": ["Inland"]}
conditions["Liechtenstein"] = {"years": [2005,2006], "modes": ["Inland","Inland (exl. Pipeline)"]}
conditions["New Zealand"] = {"years": list(range(1970,1999)), "modes": ["Inland (exl. Pipeline)"]}
conditions["Norway"] = {"years": [2017], "modes": ["Inland (exl. Pipeline)"]}
conditions["Portugal"] = {"years": list(range(1970,1979))+list(range(1981,1987)), "modes": ["Inland (exl. Pipeline)"]}
conditions["Spain"] = {"years": list(range(2017,2019)), "modes": ["Inland","Inland (exl. Pipeline)"]}
conditions["Switzerland"] = {"years": [2018], "modes": ["Inland","Inland (exl. Pipeline)"]}
conditions["United Kingdom"] = {"years": list(range(2013,2019)), "modes": ["Inland"]}

list_of_countries_to_clean = list(conditions.keys())

# For each country, perform the following operations based on the data passed to each country
for index, row in df.iterrows():
    country = row["Country"]
    if country in list_of_countries_to_clean:
        list_of_years_to_erase = conditions[country]["years"]
        modes_to_erase = conditions[country]["modes"]
        if (row["Year"] in list_of_years_to_erase) and (row["Mode"] in modes_to_erase):
            list_of_index_to_erase.append(index)

len(list_of_index_to_erase)
# Out:
# 249

# %% [markdown]
# ### Note: Canada, India, and United States are going to be managed in this cell because they have more special conditions than the contries above

# %%
# Setting the special conditions
special_conditions = {}
special_conditions["Canada"] = {"years_1": list(range(1970,1995)) +list(range(2014,2019)), "modes_1": ["Inland"], "years_2": list(range(1970,1996))+list(range(2014,2019)), "modes_2": ["Inland (exl. Pipeline)"]}
special_conditions["India"] = {"years_1": list(range(1970,2005)) +list(range(2013,2018)), "modes_1": ["Inland"], "years_2": list(range(1970,2005)), "modes_2": ["Inland (exl. Pipeline)"]}
special_conditions["United States"] = {"years_1": list(range(2012,2019)), "modes_1": ["Inland"], "years_2": list(range(2017,2019)), "modes_2": ["Inland (exl. Pipeline)"]}

list_of_countries_with_special_conditions = list(special_conditions.keys())

# For each country, perform the following operations based on the data passed to each country
for index, row in df.iterrows():
    country = row["Country"]
    if country in list_of_countries_with_special_conditions:
        
        # Conditions 1
        modes_to_erase_condition_1 = special_conditions[country]["modes_1"]
        list_of_years_to_erase_condition_1 = special_conditions[country]["years_1"]
        
        # Conditions 2
        modes_to_erase_condition_2 = special_conditions[country]["modes_2"]
        list_of_years_to_erase_condition_2 = special_conditions[country]["years_1"]
        
        # Testing the conditions
        if row["Mode"] in modes_to_erase_condition_1 and row["Year"] in list_of_years_to_erase_condition_1:
            list_of_index_to_erase.append(index)
        elif row["Mode"] in modes_to_erase_condition_2 and row["Year"] in list_of_years_to_erase_condition_2:
            list_of_index_to_erase.append(index)

len(list_of_index_to_erase)
# Out:
# 309

# %% [markdown]
# # Note: Ireland, Serbia, Republic of, and Ukraine will be managed in this cell because they have even more special conditions

# %%
finer_conditions = {}
finer_conditions["Ireland"] = {"years": [1979], "modes": ["Inland","Inland (exl. Pipeline)", "Road"]}
finer_conditions["Serbia, Republic of"] = {"years": list(range(1997,2019)), "modes": ["Inland","Inland (exl. Pipeline)", "Road"]}
finer_conditions["Ukraine"] = {"years": list(range(1990,2009)), "modes": ["Inland","Inland (exl. Pipeline)", "Road"]}

list_of_countries_to_clean = list(finer_conditions.keys())

# For each country, perform the following operations based on the data passed to each country
for index, row in df.iterrows():
    country = row["Country"]
    if country in list_of_countries_to_clean:
        list_of_years_to_erase = finer_conditions[country]["years"]
        modes_to_erase = finer_conditions[country]["modes"]
        if (row["Year"] in list_of_years_to_erase) and (row["Mode"] in modes_to_erase):
            if row["Mode"] == "Road" and row["Vehicle Type"] != "All":
                pass
            else:
                list_of_index_to_erase.append(index)

len(list_of_index_to_erase)
# Out:
# 432

# %%
# Dropping the rows from the dataframe
df.drop(df.index[list_of_index_to_erase], inplace = True)
df
# Out:
#              Country Fuel                    Mode PowerCode  Service  \
# 0           Slovenia  All                    Road  Millions  Freight
# 1           Slovenia  All                    Road  Millions  Freight
# 2           Slovenia  All                    Road  Millions  Freight
# 3           Slovenia  All                    Road  Millions  Freight
# 4           Slovenia  All                    Road  Millions  Freight
# ...              ...  ...                     ...       ...      ...
# 13451  United States  All  Inland (exl. Pipeline)       NaN  Freight
# 13452  United States  All  Inland (exl. Pipeline)       NaN  Freight
# 13453  United States  All  Inland (exl. Pipeline)       NaN  Freight
# 13454  United States  All  Inland (exl. Pipeline)       NaN  Freight
# 13455  United States  All  Inland (exl. Pipeline)       NaN  Freight
#
#                               Source Technology                Unit     Value  \
# 0      International Transport Forum        All  10^9 tonne-km / yr     0.534
# 1      International Transport Forum        All  10^9 tonne-km / yr     0.700
# 2      International Transport Forum        All  10^9 tonne-km / yr     1.098
# 3      International Transport Forum        All  10^9 tonne-km / yr     1.078
# 4      International Transport Forum        All  10^9 tonne-km / yr     0.745
# ...                              ...        ...                 ...       ...
# 13451  International Transport Forum        All  10^9 tonne-km / yr  6770.271
# 13452  International Transport Forum        All  10^9 tonne-km / yr  6998.545
# 13453  International Transport Forum        All  10^9 tonne-km / yr  6292.634
# 13454  International Transport Forum        All  10^9 tonne-km / yr  6610.056
# 13455  International Transport Forum        All  10^9 tonne-km / yr  6848.869
#
#                Variable     Vehicle Type  Year
# 0      Freight Activity  For Own Account  1970
# 1      Freight Activity  For Own Account  1971
# 2      Freight Activity  For Own Account  1972
# 3      Freight Activity  For Own Account  1973
# 4      Freight Activity  For Own Account  1974
# ...                 ...              ...   ...
# 13451  Freight Activity              All  2007
# 13452  Freight Activity              All  2008
# 13453  Freight Activity              All  2009
# 13454  Freight Activity              All  2010
# 13455  Freight Activity              All  2011
#
# [13031 rows x 12 columns]

# %% [markdown]
# # Getting the ISO Code for each country
#     Rule: For each country, we have to assign their respective ISO code

# %% [markdown]
# ## Determining which countries do not appear in the list of ISO Codes
#     As seen from the code below, four countries appear to not have ISO code. However, the reason is because the countries are written in a format that is not understandable. So, this is how each those "missing" countries will be called in order to obtain their ISO code
#
#     Original Name --> New name
#         > Montenegro, Republic of --> Montenegro
#         > Bosnia-Herzegovina --> Bosnia and Herzegovina
#         > Korea --> Korea, Republic of
#         > Serbia, Republic of --> Serbia

# %%
# Getting the list of countries available
list_of_countries = list(set(df["Country"]))

# Getting the list of countries with no ISO code
countries_with_no_ISO_code = countryCodeManager.get_list_of_countries_with_no_iso_code(list_of_countries)
        
# Print this list of countries with no ISO codes
countries_with_no_ISO_code
# Out:
# ['Bosnia-Herzegovina',
#  'Serbia, Republic of',
#  'Montenegro, Republic of',
#  'Korea']

# %% [markdown]
# ## Adding the ISO column to the dataset

# %%
dirty_list_of_all_countries = df["Country"]
clean_list_of_all_countries = []

for country in dirty_list_of_all_countries:
    if country == "Montenegro, Republic of":
        clean_list_of_all_countries.append("Montenegro")
    elif country == "Bosnia-Herzegovina":
        clean_list_of_all_countries.append("Bosnia and Herzegovina")
    elif country == "Korea":
        clean_list_of_all_countries.append("Korea, Republic of")
    elif country == "Serbia, Republic of":
        clean_list_of_all_countries.append("Serbia")
    else:
        clean_list_of_all_countries.append(country)

# Ensure the size of the cleaned list is the same as the dirty list
assert len(clean_list_of_all_countries) == len(dirty_list_of_all_countries)

# Assert that for all elements in the new list, no country is left without an ISO code
assert len(countryCodeManager.get_list_of_countries_with_no_iso_code(clean_list_of_all_countries)) == 0

# Getting the list of iso codes
list_of_iso_codes = countryCodeManager.get_list_of_iso_for_countries(clean_list_of_all_countries)

# Adding the column to the dataframe
df[ColumnName.ISO_CODE.value] = list_of_iso_codes
df
# Out:
#              Country Fuel                    Mode PowerCode  Service  \
# 0           Slovenia  All                    Road  Millions  Freight
# 1           Slovenia  All                    Road  Millions  Freight
# 2           Slovenia  All                    Road  Millions  Freight
# 3           Slovenia  All                    Road  Millions  Freight
# 4           Slovenia  All                    Road  Millions  Freight
# ...              ...  ...                     ...       ...      ...
# 13451  United States  All  Inland (exl. Pipeline)       NaN  Freight
# 13452  United States  All  Inland (exl. Pipeline)       NaN  Freight
# 13453  United States  All  Inland (exl. Pipeline)       NaN  Freight
# 13454  United States  All  Inland (exl. Pipeline)       NaN  Freight
# 13455  United States  All  Inland (exl. Pipeline)       NaN  Freight
#
#                               Source Technology                Unit     Value  \
# 0      International Transport Forum        All  10^9 tonne-km / yr     0.534
# 1      International Transport Forum        All  10^9 tonne-km / yr     0.700
# 2      International Transport Forum        All  10^9 tonne-km / yr     1.098
# 3      International Transport Forum        All  10^9 tonne-km / yr     1.078
# 4      International Transport Forum        All  10^9 tonne-km / yr     0.745
# ...                              ...        ...                 ...       ...
# 13451  International Transport Forum        All  10^9 tonne-km / yr  6770.271
# 13452  International Transport Forum        All  10^9 tonne-km / yr  6998.545
# 13453  International Transport Forum        All  10^9 tonne-km / yr  6292.634
# 13454  International Transport Forum        All  10^9 tonne-km / yr  6610.056
# 13455  International Transport Forum        All  10^9 tonne-km / yr  6848.869
#
#                Variable     Vehicle Type  Year ISO Code
# 0      Freight Activity  For Own Account  1970      SVN
# 1      Freight Activity  For Own Account  1971      SVN
# 2      Freight Activity  For Own Account  1972      SVN
# 3      Freight Activity  For Own Account  1973      SVN
# 4      Freight Activity  For Own Account  1974      SVN
# ...                 ...              ...   ...      ...
# 13451  Freight Activity              All  2007      USA
# 13452  Freight Activity              All  2008      USA
# 13453  Freight Activity              All  2009      USA
# 13454  Freight Activity              All  2010      USA
# 13455  Freight Activity              All  2011      USA
#
# [13031 rows x 13 columns]

# %% [markdown]
# # Getting the ITEM region for each country
#     Rule: For each country, we need to specify the ITEM region it belongs to.

# %% [markdown]
# ## Determining which countries are missing an ITEM region
#     As seen below, all countries belong to a region. Therefore, no special processing needs to be done.

# %%
# Getting the list of ISO codes
list_of_iso_codes = list(set(df["ISO Code"]))

# Getting the list of ISO code with no region
iso_code_with_no_region = countryCodeManager.get_list_of_iso_codes_with_no_region(list_of_iso_codes)

# printing the list of ISO codes
iso_code_with_no_region
# Out:
# []

# %% [markdown]
# ## Adding the ITEM region column to the dataset

# %%
# Getting the complete list of iso codes
list_of_all_codes = df["ISO Code"]

item_region = countryCodeManager.get_list_of_regions_for_iso_codes(list_of_all_codes)

# Adding the column to the dataframe
df[ColumnName.ITEM_REGION.value] = item_region
df
# Out:
#              Country Fuel                    Mode PowerCode  Service  \
# 0           Slovenia  All                    Road  Millions  Freight
# 1           Slovenia  All                    Road  Millions  Freight
# 2           Slovenia  All                    Road  Millions  Freight
# 3           Slovenia  All                    Road  Millions  Freight
# 4           Slovenia  All                    Road  Millions  Freight
# ...              ...  ...                     ...       ...      ...
# 13451  United States  All  Inland (exl. Pipeline)       NaN  Freight
# 13452  United States  All  Inland (exl. Pipeline)       NaN  Freight
# 13453  United States  All  Inland (exl. Pipeline)       NaN  Freight
# 13454  United States  All  Inland (exl. Pipeline)       NaN  Freight
# 13455  United States  All  Inland (exl. Pipeline)       NaN  Freight
#
#                               Source Technology                Unit     Value  \
# 0      International Transport Forum        All  10^9 tonne-km / yr     0.534
# 1      International Transport Forum        All  10^9 tonne-km / yr     0.700
# 2      International Transport Forum        All  10^9 tonne-km / yr     1.098
# 3      International Transport Forum        All  10^9 tonne-km / yr     1.078
# 4      International Transport Forum        All  10^9 tonne-km / yr     0.745
# ...                              ...        ...                 ...       ...
# 13451  International Transport Forum        All  10^9 tonne-km / yr  6770.271
# 13452  International Transport Forum        All  10^9 tonne-km / yr  6998.545
# 13453  International Transport Forum        All  10^9 tonne-km / yr  6292.634
# 13454  International Transport Forum        All  10^9 tonne-km / yr  6610.056
# 13455  International Transport Forum        All  10^9 tonne-km / yr  6848.869
#
#                Variable     Vehicle Type  Year ISO Code Region
# 0      Freight Activity  For Own Account  1970      SVN  EU-27
# 1      Freight Activity  For Own Account  1971      SVN  EU-27
# 2      Freight Activity  For Own Account  1972      SVN  EU-27
# 3      Freight Activity  For Own Account  1973      SVN  EU-27
# 4      Freight Activity  For Own Account  1974      SVN  EU-27
# ...                 ...              ...   ...      ...    ...
# 13451  Freight Activity              All  2007      USA   U.S.
# 13452  Freight Activity              All  2008      USA   U.S.
# 13453  Freight Activity              All  2009      USA   U.S.
# 13454  Freight Activity              All  2010      USA   U.S.
# 13455  Freight Activity              All  2011      USA   U.S.
#
# [13031 rows x 14 columns]

# %% [markdown]
# # Reordering the columns
#     Rule: The columns have to be presented in the order established by the template.

# %%
df = dataframeManager.reorder_columns(df)
df
# Out:
#                               Source        Country ISO Code Region  \
# 0      International Transport Forum       Slovenia      SVN  EU-27
# 1      International Transport Forum       Slovenia      SVN  EU-27
# 2      International Transport Forum       Slovenia      SVN  EU-27
# 3      International Transport Forum       Slovenia      SVN  EU-27
# 4      International Transport Forum       Slovenia      SVN  EU-27
# ...                              ...            ...      ...    ...
# 13451  International Transport Forum  United States      USA   U.S.
# 13452  International Transport Forum  United States      USA   U.S.
# 13453  International Transport Forum  United States      USA   U.S.
# 13454  International Transport Forum  United States      USA   U.S.
# 13455  International Transport Forum  United States      USA   U.S.
#
#                Variable                Unit  Service                    Mode  \
# 0      Freight Activity  10^9 tonne-km / yr  Freight                    Road
# 1      Freight Activity  10^9 tonne-km / yr  Freight                    Road
# 2      Freight Activity  10^9 tonne-km / yr  Freight                    Road
# 3      Freight Activity  10^9 tonne-km / yr  Freight                    Road
# 4      Freight Activity  10^9 tonne-km / yr  Freight                    Road
# ...                 ...                 ...      ...                     ...
# 13451  Freight Activity  10^9 tonne-km / yr  Freight  Inland (exl. Pipeline)
# 13452  Freight Activity  10^9 tonne-km / yr  Freight  Inland (exl. Pipeline)
# 13453  Freight Activity  10^9 tonne-km / yr  Freight  Inland (exl. Pipeline)
# 13454  Freight Activity  10^9 tonne-km / yr  Freight  Inland (exl. Pipeline)
# 13455  Freight Activity  10^9 tonne-km / yr  Freight  Inland (exl. Pipeline)
#
#           Vehicle Type Technology Fuel     Value  Year
# 0      For Own Account        All  All     0.534  1970
# 1      For Own Account        All  All     0.700  1971
# 2      For Own Account        All  All     1.098  1972
# 3      For Own Account        All  All     1.078  1973
# 4      For Own Account        All  All     0.745  1974
# ...                ...        ...  ...       ...   ...
# 13451              All        All  All  6770.271  2007
# 13452              All        All  All  6998.545  2008
# 13453              All        All  All  6292.634  2009
# 13454              All        All  All  6610.056  2010
# 13455              All        All  All  6848.869  2011
#
# [13031 rows x 13 columns]

# %% [markdown]
# # Exporting Results

# %%
# Programming Friendly View
dataframeManager.create_programming_friendly_file(df)

# User Friendly View
dataframeManager.create_user_friendly_file(df)
# Out:
# > PF File saved at: /Users/hlinero/Documents/database/item/historical/scripts
# > UF File saved at: /Users/hlinero/Documents/database/item/historical/scripts
