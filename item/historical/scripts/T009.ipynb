# %%
import pandas as pd
import json
from pprint import pprint
from item.historical.scripts.util.managers.dataframe import DataframeManager
from item.historical.scripts.util.managers.dataframe import ColumnName
from item.historical.scripts.util.managers.country_code import CountryCodeManager
from item.common import paths

# %% [markdown]
# # Variables used across the noteboook and not changed

# %%
DATASET_ID = "T009"
dataframeManager = DataframeManager(DATASET_ID)
countryCodeManager = CountryCodeManager()

# %%
path = paths['data']/'historical'/'input'/'T009_input.csv'
df = pd.read_csv(path)
df
# Out:
#     REGIONS/COUNTRIES    2005    2006    2007    2008    2009    2010    2011  \
# 0             AUSTRIA   4,157   4,205   4,246   4,285   4,360   4,441   4,513
# 1             BELGIUM   4,861   4,929   5,006   5,087   5,160   5,279   5,359
# 2             DENMARK   1,971   2,026   2,075   2,105   2,126   2,169   2,203
# 3             FINLAND   2,414   2,489   2,481   2,450   2,450   2,486   2,532
# 4              FRANCE  30,100  30,400  30,700  30,850  31,050  31,300  31,550
# ..                ...     ...     ...     ...     ...     ...     ...     ...
# 136              TOGO     101     101     105     105     106     108     111
# 137           TUNISIA     852     874     830     787     820     848     855
# 138            UGANDA      57      59      91      94      97     101     110
# 139            ZAMBIA     294     303     200     135     190     200     210
# 140          ZIMBABWE     590     599     610     617     626     650     680
#
#        2012    2013    2014    2015
# 0     4,584   4,641   4,695   4,748
# 1     5,393   5,439   5,511   5,587
# 2     2,240   2,280   2,321   2,392
# 3     2,560   2,576   2,596   2,613
# 4    31,600  31,650  31,800  32,000
# ..      ...     ...     ...     ...
# 136     116     120     130     140
# 137     862     891     940     990
# 138     120     130     140     150
# 139     220     230     240     250
# 140     710     750     790     830
#
# [141 rows x 12 columns]

# %% [markdown]
# # Tranforming the view from PF to UF

# %%
df = dataframeManager.transform_from_uf_to_pf_view(df, 1)
df
# Out:
#      REGIONS/COUNTRIES  Year  Value
# 0              AUSTRIA  2005  4,157
# 1              AUSTRIA  2006  4,205
# 2              AUSTRIA  2007  4,246
# 3              AUSTRIA  2008  4,285
# 4              AUSTRIA  2009  4,360
# ...                ...   ...    ...
# 1546          ZIMBABWE  2011    680
# 1547          ZIMBABWE  2012    710
# 1548          ZIMBABWE  2013    750
# 1549          ZIMBABWE  2014    790
# 1550          ZIMBABWE  2015    830
#
# [1551 rows x 3 columns]

# %% [markdown]
# # Renaming the "Country" column

# %%
dataframeManager.rename_column(current_name="REGIONS/COUNTRIES",df=df,new_name=ColumnName.COUNTRY.value)
df
# Out:
#        Country  Year  Value
# 0      AUSTRIA  2005  4,157
# 1      AUSTRIA  2006  4,205
# 2      AUSTRIA  2007  4,246
# 3      AUSTRIA  2008  4,285
# 4      AUSTRIA  2009  4,360
# ...        ...   ...    ...
# 1546  ZIMBABWE  2011    680
# 1547  ZIMBABWE  2012    710
# 1548  ZIMBABWE  2013    750
# 1549  ZIMBABWE  2014    790
# 1550  ZIMBABWE  2015    830
#
# [1551 rows x 3 columns]

# %% [markdown]
# # Setting the "Source" column
#     Rule: This dataset comes from "International Organization of Motor Vehicle Manufacturers"

# %%
dataframeManager.simple_column_insert(cell_value="International Organization of Motor Vehicle Manufacturers", dataframe=df, column_name= ColumnName.SOURCE.value)
df
# Out:
#                                                  Source   Country  Year  Value
# 0     International Organization of Motor Vehicle Ma...   AUSTRIA  2005  4,157
# 1     International Organization of Motor Vehicle Ma...   AUSTRIA  2006  4,205
# 2     International Organization of Motor Vehicle Ma...   AUSTRIA  2007  4,246
# 3     International Organization of Motor Vehicle Ma...   AUSTRIA  2008  4,285
# 4     International Organization of Motor Vehicle Ma...   AUSTRIA  2009  4,360
# ...                                                 ...       ...   ...    ...
# 1546  International Organization of Motor Vehicle Ma...  ZIMBABWE  2011    680
# 1547  International Organization of Motor Vehicle Ma...  ZIMBABWE  2012    710
# 1548  International Organization of Motor Vehicle Ma...  ZIMBABWE  2013    750
# 1549  International Organization of Motor Vehicle Ma...  ZIMBABWE  2014    790
# 1550  International Organization of Motor Vehicle Ma...  ZIMBABWE  2015    830
#
# [1551 rows x 4 columns]

# %% [markdown]
# # Getting the ISO code for each country

# %% [markdown]
# ## Determining which countries do not have an ISO code
#     Rule: As seen below, 12 countries do not have an ISO code. The transformation that will be done for each country is as follows:
#     ORIGINAL NAME --> NAME TO USE
#      RUSSIA --> Russian Federation
#      SYRIA --> Syrian Arab Republic
#      IRAN --> Iran, Islamic Republic of
#      BOSNIA --> Bosnia and Herzegovina
#      HONG-KONG --> Hong Kong
#      IVORY COAST --> Côte d'Ivoire
#      BRUNEI --> Brunei Darussalam
#      MOLDAVIA --> Moldova, Republic of
#      SOUTH KOREA --> Korea, Republic of
#      CONGO KINSHASA --> Congo, The Democratic Republic of the
#      PALESTINE --> Palestine, State of
#      MACEDONIA --> North Macedonia

# %%
list_of_countries = list(set(df[ColumnName.COUNTRY.value]))
countries_with_no_iso_code = countryCodeManager.get_list_of_countries_with_no_iso_code(list_of_countries)
countries_with_no_iso_code
# Out:
# ['SOUTH KOREA',
#  'SYRIA',
#  'IRAN',
#  'MOLDAVIA',
#  'MACEDONIA',
#  'BOSNIA',
#  'RUSSIA',
#  'BRUNEI',
#  'HONG-KONG',
#  'PALESTINE',
#  'IVORY COAST',
#  'CONGO KINSHASA ']

# %%
# Creating a list to hold all the iso_codes
dirty_list_of_all_countries = df["Country"]
clean_list_of_all_countries = []

# Cleaning the list and replacing the missing countries with the appropriate name
for country in dirty_list_of_all_countries:
    if country == "RUSSIA":
        clean_list_of_all_countries.append("Russian Federation")
    elif country == "SYRIA":
        clean_list_of_all_countries.append("Syrian Arab Republic")
    elif country == "IRAN":
        clean_list_of_all_countries.append("Iran, Islamic Republic of")
    elif country == "BOSNIA":
        clean_list_of_all_countries.append("Bosnia and Herzegovina")
    elif country == "HONG-KONG":
        clean_list_of_all_countries.append("Hong Kong")
    elif country == "IVORY COAST":
        clean_list_of_all_countries.append("Côte d'Ivoire")
    elif country == "BRUNEI":
        clean_list_of_all_countries.append("Brunei Darussalam")
    elif country == "MOLDAVIA":
        clean_list_of_all_countries.append("Moldova, Republic of")
    elif country == "SOUTH KOREA":
        clean_list_of_all_countries.append("Korea, Republic of")
    elif country == "CONGO KINSHASA ":
        clean_list_of_all_countries.append("Congo, The Democratic Republic of the")
    elif country == "PALESTINE":
        clean_list_of_all_countries.append("Palestine, State of")
    elif country == "MACEDONIA":
        clean_list_of_all_countries.append("North Macedonia")
    else:
        clean_list_of_all_countries.append(country)
        
# Ensuring the size of the clean list is equal to the old list
assert len(clean_list_of_all_countries) == len(dirty_list_of_all_countries)

# Getting the list of iso codes
list_of_iso_codes = countryCodeManager.get_list_of_iso_for_countries(clean_list_of_all_countries)

# Setting the new country column
df.drop(columns=["Country"], inplace = True)
df[ColumnName.COUNTRY.value] = clean_list_of_all_countries

# Adding the column to the dataframe
df[ColumnName.ISO_CODE.value] = list_of_iso_codes
df
# Out:
#                                                  Source  Year  Value  \
# 0     International Organization of Motor Vehicle Ma...  2005  4,157
# 1     International Organization of Motor Vehicle Ma...  2006  4,205
# 2     International Organization of Motor Vehicle Ma...  2007  4,246
# 3     International Organization of Motor Vehicle Ma...  2008  4,285
# 4     International Organization of Motor Vehicle Ma...  2009  4,360
# ...                                                 ...   ...    ...
# 1546  International Organization of Motor Vehicle Ma...  2011    680
# 1547  International Organization of Motor Vehicle Ma...  2012    710
# 1548  International Organization of Motor Vehicle Ma...  2013    750
# 1549  International Organization of Motor Vehicle Ma...  2014    790
# 1550  International Organization of Motor Vehicle Ma...  2015    830
#
#        Country ISO Code
# 0      AUSTRIA      AUT
# 1      AUSTRIA      AUT
# 2      AUSTRIA      AUT
# 3      AUSTRIA      AUT
# 4      AUSTRIA      AUT
# ...        ...      ...
# 1546  ZIMBABWE      ZWE
# 1547  ZIMBABWE      ZWE
# 1548  ZIMBABWE      ZWE
# 1549  ZIMBABWE      ZWE
# 1550  ZIMBABWE      ZWE
#
# [1551 rows x 5 columns]

# %% [markdown]
# # Getting the ITEM region for each ISO code

# %% [markdown]
# ## Determining which countries do not have an ITEM region
#     Rule: As seen below, all ISO code have a respective region.

# %%
list_of_unique_iso_codes = list(set(df[ColumnName.ISO_CODE.value]))
iso_codes_with_no_region = countryCodeManager.get_list_of_iso_codes_with_no_region(list_of_unique_iso_codes)
iso_codes_with_no_region
# Out:
# []

# %% [markdown]
# ## Assigning the ITEM region

# %%
# Getting the complete list of iso codes
list_of_all_codes = df[ColumnName.ISO_CODE.value]

# Getting the list of regions
item_regions = countryCodeManager.get_list_of_regions_for_iso_codes(list_of_all_codes)

# Assert that the size of the list of iso codes is equivalent to the size of country column
assert len(df) == len(item_regions)

# Adding the column to the dataframe
df.insert(3, ColumnName.ITEM_REGION.value, item_regions, True)
df
# Out:
#                                                  Source  Year  Value  Region  \
# 0     International Organization of Motor Vehicle Ma...  2005  4,157   EU-27
# 1     International Organization of Motor Vehicle Ma...  2006  4,205   EU-27
# 2     International Organization of Motor Vehicle Ma...  2007  4,246   EU-27
# 3     International Organization of Motor Vehicle Ma...  2008  4,285   EU-27
# 4     International Organization of Motor Vehicle Ma...  2009  4,360   EU-27
# ...                                                 ...   ...    ...     ...
# 1546  International Organization of Motor Vehicle Ma...  2011    680  Africa
# 1547  International Organization of Motor Vehicle Ma...  2012    710  Africa
# 1548  International Organization of Motor Vehicle Ma...  2013    750  Africa
# 1549  International Organization of Motor Vehicle Ma...  2014    790  Africa
# 1550  International Organization of Motor Vehicle Ma...  2015    830  Africa
#
#        Country ISO Code
# 0      AUSTRIA      AUT
# 1      AUSTRIA      AUT
# 2      AUSTRIA      AUT
# 3      AUSTRIA      AUT
# 4      AUSTRIA      AUT
# ...        ...      ...
# 1546  ZIMBABWE      ZWE
# 1547  ZIMBABWE      ZWE
# 1548  ZIMBABWE      ZWE
# 1549  ZIMBABWE      ZWE
# 1550  ZIMBABWE      ZWE
#
# [1551 rows x 6 columns]

# %% [markdown]
# # Modifying the country name and making them capital and not upper case

# %%
# Variable holding the new names
new_names = []
old_names =list(df["Country"])

# Changing the names
for name in old_names:
    new_names.append(name.capitalize())
    
# Asserting that no data is missing
assert len(new_names) == len(df)

# Dropping current name and adding the new column
df.drop(columns=["Country"], inplace = True)
df.insert(0, ColumnName.COUNTRY.value, new_names, True)
df
# Out:
#        Country                                             Source  Year  \
# 0      Austria  International Organization of Motor Vehicle Ma...  2005
# 1      Austria  International Organization of Motor Vehicle Ma...  2006
# 2      Austria  International Organization of Motor Vehicle Ma...  2007
# 3      Austria  International Organization of Motor Vehicle Ma...  2008
# 4      Austria  International Organization of Motor Vehicle Ma...  2009
# ...        ...                                                ...   ...
# 1546  Zimbabwe  International Organization of Motor Vehicle Ma...  2011
# 1547  Zimbabwe  International Organization of Motor Vehicle Ma...  2012
# 1548  Zimbabwe  International Organization of Motor Vehicle Ma...  2013
# 1549  Zimbabwe  International Organization of Motor Vehicle Ma...  2014
# 1550  Zimbabwe  International Organization of Motor Vehicle Ma...  2015
#
#       Value  Region ISO Code
# 0     4,157   EU-27      AUT
# 1     4,205   EU-27      AUT
# 2     4,246   EU-27      AUT
# 3     4,285   EU-27      AUT
# 4     4,360   EU-27      AUT
# ...     ...     ...      ...
# 1546    680  Africa      ZWE
# 1547    710  Africa      ZWE
# 1548    750  Africa      ZWE
# 1549    790  Africa      ZWE
# 1550    830  Africa      ZWE
#
# [1551 rows x 6 columns]

# %% [markdown]
# # Adding the 'Service' column
#     Rule: The dataset is associated to passenger data, therefore, the "Service," is "Passenger"

# %%
dataframeManager.simple_column_insert(df, ColumnName.SERVICE.value, "Passenger", 6)
df
# Out:
#        Country                                             Source  Year  \
# 0      Austria  International Organization of Motor Vehicle Ma...  2005
# 1      Austria  International Organization of Motor Vehicle Ma...  2006
# 2      Austria  International Organization of Motor Vehicle Ma...  2007
# 3      Austria  International Organization of Motor Vehicle Ma...  2008
# 4      Austria  International Organization of Motor Vehicle Ma...  2009
# ...        ...                                                ...   ...
# 1546  Zimbabwe  International Organization of Motor Vehicle Ma...  2011
# 1547  Zimbabwe  International Organization of Motor Vehicle Ma...  2012
# 1548  Zimbabwe  International Organization of Motor Vehicle Ma...  2013
# 1549  Zimbabwe  International Organization of Motor Vehicle Ma...  2014
# 1550  Zimbabwe  International Organization of Motor Vehicle Ma...  2015
#
#       Value  Region ISO Code    Service
# 0     4,157   EU-27      AUT  Passenger
# 1     4,205   EU-27      AUT  Passenger
# 2     4,246   EU-27      AUT  Passenger
# 3     4,285   EU-27      AUT  Passenger
# 4     4,360   EU-27      AUT  Passenger
# ...     ...     ...      ...        ...
# 1546    680  Africa      ZWE  Passenger
# 1547    710  Africa      ZWE  Passenger
# 1548    750  Africa      ZWE  Passenger
# 1549    790  Africa      ZWE  Passenger
# 1550    830  Africa      ZWE  Passenger
#
# [1551 rows x 7 columns]

# %% [markdown]
# # Adding the "Technology", "Fuel", and "Vehicle Type" columns
#     Rule: Since the dataset does not provide information about technology or fuel, we set both as "All"

# %%
dataframeManager.simple_column_insert(df, ColumnName.TECHNOLOGY.value, "All", 7)
dataframeManager.simple_column_insert(df, ColumnName.VEHICLE_TYPE.value, "All", 8)
dataframeManager.simple_column_insert(df, ColumnName.FUEL.value, "All", 9)
df
# Out:
#        Country                                             Source  Year  \
# 0      Austria  International Organization of Motor Vehicle Ma...  2005
# 1      Austria  International Organization of Motor Vehicle Ma...  2006
# 2      Austria  International Organization of Motor Vehicle Ma...  2007
# 3      Austria  International Organization of Motor Vehicle Ma...  2008
# 4      Austria  International Organization of Motor Vehicle Ma...  2009
# ...        ...                                                ...   ...
# 1546  Zimbabwe  International Organization of Motor Vehicle Ma...  2011
# 1547  Zimbabwe  International Organization of Motor Vehicle Ma...  2012
# 1548  Zimbabwe  International Organization of Motor Vehicle Ma...  2013
# 1549  Zimbabwe  International Organization of Motor Vehicle Ma...  2014
# 1550  Zimbabwe  International Organization of Motor Vehicle Ma...  2015
#
#       Value  Region ISO Code    Service Technology Vehicle Type Fuel
# 0     4,157   EU-27      AUT  Passenger        All          All  All
# 1     4,205   EU-27      AUT  Passenger        All          All  All
# 2     4,246   EU-27      AUT  Passenger        All          All  All
# 3     4,285   EU-27      AUT  Passenger        All          All  All
# 4     4,360   EU-27      AUT  Passenger        All          All  All
# ...     ...     ...      ...        ...        ...          ...  ...
# 1546    680  Africa      ZWE  Passenger        All          All  All
# 1547    710  Africa      ZWE  Passenger        All          All  All
# 1548    750  Africa      ZWE  Passenger        All          All  All
# 1549    790  Africa      ZWE  Passenger        All          All  All
# 1550    830  Africa      ZWE  Passenger        All          All  All
#
# [1551 rows x 10 columns]

# %% [markdown]
# # Adding the "Mode" column
#     Rule: This dataset is about vehicles, the mode is "Road"

# %%
dataframeManager.simple_column_insert(df, ColumnName.MODE.value, "Road", 8)
df
# Out:
#        Country                                             Source  Year  \
# 0      Austria  International Organization of Motor Vehicle Ma...  2005
# 1      Austria  International Organization of Motor Vehicle Ma...  2006
# 2      Austria  International Organization of Motor Vehicle Ma...  2007
# 3      Austria  International Organization of Motor Vehicle Ma...  2008
# 4      Austria  International Organization of Motor Vehicle Ma...  2009
# ...        ...                                                ...   ...
# 1546  Zimbabwe  International Organization of Motor Vehicle Ma...  2011
# 1547  Zimbabwe  International Organization of Motor Vehicle Ma...  2012
# 1548  Zimbabwe  International Organization of Motor Vehicle Ma...  2013
# 1549  Zimbabwe  International Organization of Motor Vehicle Ma...  2014
# 1550  Zimbabwe  International Organization of Motor Vehicle Ma...  2015
#
#       Value  Region ISO Code    Service Technology  Mode Vehicle Type Fuel
# 0     4,157   EU-27      AUT  Passenger        All  Road          All  All
# 1     4,205   EU-27      AUT  Passenger        All  Road          All  All
# 2     4,246   EU-27      AUT  Passenger        All  Road          All  All
# 3     4,285   EU-27      AUT  Passenger        All  Road          All  All
# 4     4,360   EU-27      AUT  Passenger        All  Road          All  All
# ...     ...     ...      ...        ...        ...   ...          ...  ...
# 1546    680  Africa      ZWE  Passenger        All  Road          All  All
# 1547    710  Africa      ZWE  Passenger        All  Road          All  All
# 1548    750  Africa      ZWE  Passenger        All  Road          All  All
# 1549    790  Africa      ZWE  Passenger        All  Road          All  All
# 1550    830  Africa      ZWE  Passenger        All  Road          All  All
#
# [1551 rows x 11 columns]

# %% [markdown]
# # Adding the "Variable" and "Unit" columns
# Rule: This dataset is associated to stock data. Therefore, the variable is "Stock." The units of this data are expressed as either "10^6 vehicle"

# %% [markdown]
# ## Variable column

# %%
dataframeManager.simple_column_insert(df, ColumnName.VARIABLE.value, "Stock", 4)
df
# Out:
#        Country                                             Source  Year  \
# 0      Austria  International Organization of Motor Vehicle Ma...  2005
# 1      Austria  International Organization of Motor Vehicle Ma...  2006
# 2      Austria  International Organization of Motor Vehicle Ma...  2007
# 3      Austria  International Organization of Motor Vehicle Ma...  2008
# 4      Austria  International Organization of Motor Vehicle Ma...  2009
# ...        ...                                                ...   ...
# 1546  Zimbabwe  International Organization of Motor Vehicle Ma...  2011
# 1547  Zimbabwe  International Organization of Motor Vehicle Ma...  2012
# 1548  Zimbabwe  International Organization of Motor Vehicle Ma...  2013
# 1549  Zimbabwe  International Organization of Motor Vehicle Ma...  2014
# 1550  Zimbabwe  International Organization of Motor Vehicle Ma...  2015
#
#       Value Variable  Region ISO Code    Service Technology  Mode  \
# 0     4,157    Stock   EU-27      AUT  Passenger        All  Road
# 1     4,205    Stock   EU-27      AUT  Passenger        All  Road
# 2     4,246    Stock   EU-27      AUT  Passenger        All  Road
# 3     4,285    Stock   EU-27      AUT  Passenger        All  Road
# 4     4,360    Stock   EU-27      AUT  Passenger        All  Road
# ...     ...      ...     ...      ...        ...        ...   ...
# 1546    680    Stock  Africa      ZWE  Passenger        All  Road
# 1547    710    Stock  Africa      ZWE  Passenger        All  Road
# 1548    750    Stock  Africa      ZWE  Passenger        All  Road
# 1549    790    Stock  Africa      ZWE  Passenger        All  Road
# 1550    830    Stock  Africa      ZWE  Passenger        All  Road
#
#      Vehicle Type Fuel
# 0             All  All
# 1             All  All
# 2             All  All
# 3             All  All
# 4             All  All
# ...           ...  ...
# 1546          All  All
# 1547          All  All
# 1548          All  All
# 1549          All  All
# 1550          All  All
#
# [1551 rows x 12 columns]

# %% [markdown]
# ## Unit column

# %%
dataframeManager.simple_column_insert(df, ColumnName.UNIT.value, "10^6 vehicle", 5)
df
# Out:
#        Country                                             Source  Year  \
# 0      Austria  International Organization of Motor Vehicle Ma...  2005
# 1      Austria  International Organization of Motor Vehicle Ma...  2006
# 2      Austria  International Organization of Motor Vehicle Ma...  2007
# 3      Austria  International Organization of Motor Vehicle Ma...  2008
# 4      Austria  International Organization of Motor Vehicle Ma...  2009
# ...        ...                                                ...   ...
# 1546  Zimbabwe  International Organization of Motor Vehicle Ma...  2011
# 1547  Zimbabwe  International Organization of Motor Vehicle Ma...  2012
# 1548  Zimbabwe  International Organization of Motor Vehicle Ma...  2013
# 1549  Zimbabwe  International Organization of Motor Vehicle Ma...  2014
# 1550  Zimbabwe  International Organization of Motor Vehicle Ma...  2015
#
#       Value Variable          Unit  Region ISO Code    Service Technology  \
# 0     4,157    Stock  10^6 vehicle   EU-27      AUT  Passenger        All
# 1     4,205    Stock  10^6 vehicle   EU-27      AUT  Passenger        All
# 2     4,246    Stock  10^6 vehicle   EU-27      AUT  Passenger        All
# 3     4,285    Stock  10^6 vehicle   EU-27      AUT  Passenger        All
# 4     4,360    Stock  10^6 vehicle   EU-27      AUT  Passenger        All
# ...     ...      ...           ...     ...      ...        ...        ...
# 1546    680    Stock  10^6 vehicle  Africa      ZWE  Passenger        All
# 1547    710    Stock  10^6 vehicle  Africa      ZWE  Passenger        All
# 1548    750    Stock  10^6 vehicle  Africa      ZWE  Passenger        All
# 1549    790    Stock  10^6 vehicle  Africa      ZWE  Passenger        All
# 1550    830    Stock  10^6 vehicle  Africa      ZWE  Passenger        All
#
#       Mode Vehicle Type Fuel
# 0     Road          All  All
# 1     Road          All  All
# 2     Road          All  All
# 3     Road          All  All
# 4     Road          All  All
# ...    ...          ...  ...
# 1546  Road          All  All
# 1547  Road          All  All
# 1548  Road          All  All
# 1549  Road          All  All
# 1550  Road          All  All
#
# [1551 rows x 13 columns]

# %% [markdown]
# # Valut Column
#     Rule: The dataset provides values in thousands so we much change it to million

# %%
# Variable holding the new value
new_values = []
old_values = list(df["Value"])

# Transforming each value
for old_val in old_values:
    val = old_val.replace(",","")
    new_val = float(val) / float(1000)
    new_values.append(new_val)
    
# Asserting no data was lost
assert len(new_values) == len(df)

# Setting the new column
df.drop(columns=["Value"], inplace = True)
df[ColumnName.VALUE.value] = new_values
df
# Out:
#        Country                                             Source  Year  \
# 0      Austria  International Organization of Motor Vehicle Ma...  2005
# 1      Austria  International Organization of Motor Vehicle Ma...  2006
# 2      Austria  International Organization of Motor Vehicle Ma...  2007
# 3      Austria  International Organization of Motor Vehicle Ma...  2008
# 4      Austria  International Organization of Motor Vehicle Ma...  2009
# ...        ...                                                ...   ...
# 1546  Zimbabwe  International Organization of Motor Vehicle Ma...  2011
# 1547  Zimbabwe  International Organization of Motor Vehicle Ma...  2012
# 1548  Zimbabwe  International Organization of Motor Vehicle Ma...  2013
# 1549  Zimbabwe  International Organization of Motor Vehicle Ma...  2014
# 1550  Zimbabwe  International Organization of Motor Vehicle Ma...  2015
#
#      Variable          Unit  Region ISO Code    Service Technology  Mode  \
# 0       Stock  10^6 vehicle   EU-27      AUT  Passenger        All  Road
# 1       Stock  10^6 vehicle   EU-27      AUT  Passenger        All  Road
# 2       Stock  10^6 vehicle   EU-27      AUT  Passenger        All  Road
# 3       Stock  10^6 vehicle   EU-27      AUT  Passenger        All  Road
# 4       Stock  10^6 vehicle   EU-27      AUT  Passenger        All  Road
# ...       ...           ...     ...      ...        ...        ...   ...
# 1546    Stock  10^6 vehicle  Africa      ZWE  Passenger        All  Road
# 1547    Stock  10^6 vehicle  Africa      ZWE  Passenger        All  Road
# 1548    Stock  10^6 vehicle  Africa      ZWE  Passenger        All  Road
# 1549    Stock  10^6 vehicle  Africa      ZWE  Passenger        All  Road
# 1550    Stock  10^6 vehicle  Africa      ZWE  Passenger        All  Road
#
#      Vehicle Type Fuel  Value
# 0             All  All  4.157
# 1             All  All  4.205
# 2             All  All  4.246
# 3             All  All  4.285
# 4             All  All  4.360
# ...           ...  ...    ...
# 1546          All  All  0.680
# 1547          All  All  0.710
# 1548          All  All  0.750
# 1549          All  All  0.790
# 1550          All  All  0.830
#
# [1551 rows x 13 columns]

# %% [markdown]
# # Reordering Columns
#     Rule: To comply with the current template, the columns must be shown in a specific order. The dataframe manager specifies the order of the columns

# %%
df = dataframeManager.reorder_columns(df)
df
# Out:
#                                                  Source   Country ISO Code  \
# 0     International Organization of Motor Vehicle Ma...   Austria      AUT
# 1     International Organization of Motor Vehicle Ma...   Austria      AUT
# 2     International Organization of Motor Vehicle Ma...   Austria      AUT
# 3     International Organization of Motor Vehicle Ma...   Austria      AUT
# 4     International Organization of Motor Vehicle Ma...   Austria      AUT
# ...                                                 ...       ...      ...
# 1546  International Organization of Motor Vehicle Ma...  Zimbabwe      ZWE
# 1547  International Organization of Motor Vehicle Ma...  Zimbabwe      ZWE
# 1548  International Organization of Motor Vehicle Ma...  Zimbabwe      ZWE
# 1549  International Organization of Motor Vehicle Ma...  Zimbabwe      ZWE
# 1550  International Organization of Motor Vehicle Ma...  Zimbabwe      ZWE
#
#       Region Variable          Unit    Service  Mode Vehicle Type Technology  \
# 0      EU-27    Stock  10^6 vehicle  Passenger  Road          All        All
# 1      EU-27    Stock  10^6 vehicle  Passenger  Road          All        All
# 2      EU-27    Stock  10^6 vehicle  Passenger  Road          All        All
# 3      EU-27    Stock  10^6 vehicle  Passenger  Road          All        All
# 4      EU-27    Stock  10^6 vehicle  Passenger  Road          All        All
# ...      ...      ...           ...        ...   ...          ...        ...
# 1546  Africa    Stock  10^6 vehicle  Passenger  Road          All        All
# 1547  Africa    Stock  10^6 vehicle  Passenger  Road          All        All
# 1548  Africa    Stock  10^6 vehicle  Passenger  Road          All        All
# 1549  Africa    Stock  10^6 vehicle  Passenger  Road          All        All
# 1550  Africa    Stock  10^6 vehicle  Passenger  Road          All        All
#
#      Fuel  Value  Year
# 0     All  4.157  2005
# 1     All  4.205  2006
# 2     All  4.246  2007
# 3     All  4.285  2008
# 4     All  4.360  2009
# ...   ...    ...   ...
# 1546  All  0.680  2011
# 1547  All  0.710  2012
# 1548  All  0.750  2013
# 1549  All  0.790  2014
# 1550  All  0.830  2015
#
# [1551 rows x 13 columns]

# %% [markdown]
# # Exporting Results

# %%
# Programming Friendly View
dataframeManager.create_programming_friendly_file(df)

# User Friendly View
dataframeManager.create_user_friendly_file(df)
# Out:
# > PF File saved at: /Users/hlinero/Documents/database/item/historical/scripts
# > UF File saved at: /Users/hlinero/Documents/database/item/historical/scripts
