# %%
import pandas as pd
from item.historical.scripts.util.managers.dataframe import DataframeManager
from item.historical.scripts.util.managers.dataframe import ColumnName
from item.historical.scripts.util.managers.country_code import CountryCodeManager
from item.common import paths

# %% [markdown]
# # Variables used all over the notebook

# %%
DATASET_ID = "T001"
dataframeManager = DataframeManager(DATASET_ID)
countryCodeManager = CountryCodeManager()

# %% [markdown]
# # Creating the dataframe and viewing the data

# %%
# Creating a dataframe from the csv data
path = paths['data']/'historical'/'input'/'T001_input.csv'
df = pd.read_csv(path)
df
# Out:
#      COUNTRY         Country   VARIABLE  \
# 0        CAN          Canada  T-SEA-CAB
# 1        CAN          Canada  T-SEA-CAB
# 2        CAN          Canada  T-SEA-CAB
# 3        CAN          Canada  T-SEA-CAB
# 4        CAN          Canada  T-SEA-CAB
# ...      ...             ...        ...
# 1574     CZE  Czech Republic  T-SEA-CAB
# 1575     CZE  Czech Republic  T-SEA-CAB
# 1576     CZE  Czech Republic  T-SEA-CAB
# 1577     CZE  Czech Republic  T-SEA-CAB
# 1578     CZE  Czech Republic  T-SEA-CAB
#
#                                    Variable  YEAR  Year Unit Code  \
# 0     Coastal shipping (national transport)  1995  1995   TONNEKM
# 1     Coastal shipping (national transport)  1996  1996   TONNEKM
# 2     Coastal shipping (national transport)  1997  1997   TONNEKM
# 3     Coastal shipping (national transport)  1998  1998   TONNEKM
# 4     Coastal shipping (national transport)  1999  1999   TONNEKM
# ...                                     ...   ...   ...       ...
# 1574  Coastal shipping (national transport)  2014  2014   TONNEKM
# 1575  Coastal shipping (national transport)  2015  2015   TONNEKM
# 1576  Coastal shipping (national transport)  2016  2016   TONNEKM
# 1577  Coastal shipping (national transport)  2017  2017   TONNEKM
# 1578  Coastal shipping (national transport)  2018  2018   TONNEKM
#
#                    Unit  PowerCode Code PowerCode  Reference Period Code  \
# 0     Tonnes-kilometres               6  Millions                    NaN
# 1     Tonnes-kilometres               6  Millions                    NaN
# 2     Tonnes-kilometres               6  Millions                    NaN
# 3     Tonnes-kilometres               6  Millions                    NaN
# 4     Tonnes-kilometres               6  Millions                    NaN
# ...                 ...             ...       ...                    ...
# 1574  Tonnes-kilometres               6  Millions                    NaN
# 1575  Tonnes-kilometres               6  Millions                    NaN
# 1576  Tonnes-kilometres               6  Millions                    NaN
# 1577  Tonnes-kilometres               6  Millions                    NaN
# 1578  Tonnes-kilometres               6  Millions                    NaN
#
#       Reference Period    Value Flag Codes                             Flags
# 0                  NaN  10369.0        NaN                               NaN
# 1                  NaN  10166.0        NaN                               NaN
# 2                  NaN  10735.0        NaN                               NaN
# 3                  NaN  13420.0        NaN                               NaN
# 4                  NaN  14144.0        NaN                               NaN
# ...                ...      ...        ...                               ...
# 1574               NaN      NaN          M  Missing value; data cannot exist
# 1575               NaN      NaN          M  Missing value; data cannot exist
# 1576               NaN      NaN          M  Missing value; data cannot exist
# 1577               NaN      NaN          M  Missing value; data cannot exist
# 1578               NaN      NaN          M  Missing value; data cannot exist
#
# [1579 rows x 15 columns]

# %% [markdown]
# # Removing all unnecessary columns
#
# ### Rule: To comply with the latest template, we will drop all the unnecessary columns and rename others.

# %%
# Droping the repeated columns
columns_to_delete = ["COUNTRY", "YEAR", "VARIABLE","Reference Period Code","Unit Code","Reference Period", "Flag Codes", "Flags", "PowerCode Code"]
df.drop(columns=columns_to_delete, inplace = True)
df
# Out:
#              Country                               Variable  Year  \
# 0             Canada  Coastal shipping (national transport)  1995
# 1             Canada  Coastal shipping (national transport)  1996
# 2             Canada  Coastal shipping (national transport)  1997
# 3             Canada  Coastal shipping (national transport)  1998
# 4             Canada  Coastal shipping (national transport)  1999
# ...              ...                                    ...   ...
# 1574  Czech Republic  Coastal shipping (national transport)  2014
# 1575  Czech Republic  Coastal shipping (national transport)  2015
# 1576  Czech Republic  Coastal shipping (national transport)  2016
# 1577  Czech Republic  Coastal shipping (national transport)  2017
# 1578  Czech Republic  Coastal shipping (national transport)  2018
#
#                    Unit PowerCode    Value
# 0     Tonnes-kilometres  Millions  10369.0
# 1     Tonnes-kilometres  Millions  10166.0
# 2     Tonnes-kilometres  Millions  10735.0
# 3     Tonnes-kilometres  Millions  13420.0
# 4     Tonnes-kilometres  Millions  14144.0
# ...                 ...       ...      ...
# 1574  Tonnes-kilometres  Millions      NaN
# 1575  Tonnes-kilometres  Millions      NaN
# 1576  Tonnes-kilometres  Millions      NaN
# 1577  Tonnes-kilometres  Millions      NaN
# 1578  Tonnes-kilometres  Millions      NaN
#
# [1579 rows x 6 columns]

# %% [markdown]
# ## Getting a generic idea of what countries are missing values and dropping NaN values
#     Rule: Erase all value with NaN

# %%
list_of_countries_with_missing_values = list(set(df[df['Value'].isnull()]["Country"]))
print(">> Number of countries missing values: {}".format(len(list_of_countries_with_missing_values)))
print(">> Countries missing values:")
print(list_of_countries_with_missing_values)
print(">> Number of rows to erase: {}".format(len(df[df['Value'].isnull()])))
# Out:
# >> Number of countries missing values: 16
# >> Countries missing values:
# ['Liechtenstein', 'North Macedonia', 'Slovenia', 'Czech Republic', 'Slovak Republic', 'Lithuania', 'Luxembourg', 'Austria', 'Moldova', 'Hungary', 'Belarus', 'Armenia', 'Switzerland', 'Serbia, Republic of', 'Greece', 'Montenegro, Republic of']
# >> Number of rows to erase: 750

# %%
# Dropping the values
df.dropna(inplace = True)

# %% [markdown]
# # Adding the "Source Column"
#     Rule: Add the same source to all rows since all data comes from same source

# %%
dataframeManager.simple_column_insert(df,ColumnName.SOURCE.value,"International Transport Forum")
df
# Out:
#                              Source Country  \
# 0     International Transport Forum  Canada
# 1     International Transport Forum  Canada
# 2     International Transport Forum  Canada
# 3     International Transport Forum  Canada
# 4     International Transport Forum  Canada
# ...                             ...     ...
# 1428  International Transport Forum  Turkey
# 1429  International Transport Forum  Turkey
# 1430  International Transport Forum  Turkey
# 1431  International Transport Forum  Turkey
# 1432  International Transport Forum  Turkey
#
#                                    Variable  Year               Unit  \
# 0     Coastal shipping (national transport)  1995  Tonnes-kilometres
# 1     Coastal shipping (national transport)  1996  Tonnes-kilometres
# 2     Coastal shipping (national transport)  1997  Tonnes-kilometres
# 3     Coastal shipping (national transport)  1998  Tonnes-kilometres
# 4     Coastal shipping (national transport)  1999  Tonnes-kilometres
# ...                                     ...   ...                ...
# 1428  Coastal shipping (national transport)  2014  Tonnes-kilometres
# 1429  Coastal shipping (national transport)  2015  Tonnes-kilometres
# 1430  Coastal shipping (national transport)  2016  Tonnes-kilometres
# 1431  Coastal shipping (national transport)  2017  Tonnes-kilometres
# 1432  Coastal shipping (national transport)  2018  Tonnes-kilometres
#
#      PowerCode    Value
# 0     Millions  10369.0
# 1     Millions  10166.0
# 2     Millions  10735.0
# 3     Millions  13420.0
# 4     Millions  14144.0
# ...        ...      ...
# 1428  Millions  18553.0
# 1429  Millions  19189.0
# 1430  Millions  19492.0
# 1431  Millions  22087.0
# 1432  Millions  21779.0
#
# [829 rows x 7 columns]

# %% [markdown]
# # Adding the "Service" column
#     Rule: Since all the data is associated to "Freight," the Service is "Freight"

# %%
dataframeManager.simple_column_insert(df,ColumnName.SERVICE.value,"Freight")
df
# Out:
#       Service                         Source Country  \
# 0     Freight  International Transport Forum  Canada
# 1     Freight  International Transport Forum  Canada
# 2     Freight  International Transport Forum  Canada
# 3     Freight  International Transport Forum  Canada
# 4     Freight  International Transport Forum  Canada
# ...       ...                            ...     ...
# 1428  Freight  International Transport Forum  Turkey
# 1429  Freight  International Transport Forum  Turkey
# 1430  Freight  International Transport Forum  Turkey
# 1431  Freight  International Transport Forum  Turkey
# 1432  Freight  International Transport Forum  Turkey
#
#                                    Variable  Year               Unit  \
# 0     Coastal shipping (national transport)  1995  Tonnes-kilometres
# 1     Coastal shipping (national transport)  1996  Tonnes-kilometres
# 2     Coastal shipping (national transport)  1997  Tonnes-kilometres
# 3     Coastal shipping (national transport)  1998  Tonnes-kilometres
# 4     Coastal shipping (national transport)  1999  Tonnes-kilometres
# ...                                     ...   ...                ...
# 1428  Coastal shipping (national transport)  2014  Tonnes-kilometres
# 1429  Coastal shipping (national transport)  2015  Tonnes-kilometres
# 1430  Coastal shipping (national transport)  2016  Tonnes-kilometres
# 1431  Coastal shipping (national transport)  2017  Tonnes-kilometres
# 1432  Coastal shipping (national transport)  2018  Tonnes-kilometres
#
#      PowerCode    Value
# 0     Millions  10369.0
# 1     Millions  10166.0
# 2     Millions  10735.0
# 3     Millions  13420.0
# 4     Millions  14144.0
# ...        ...      ...
# 1428  Millions  18553.0
# 1429  Millions  19189.0
# 1430  Millions  19492.0
# 1431  Millions  22087.0
# 1432  Millions  21779.0
#
# [829 rows x 8 columns]

# %% [markdown]
# # Adding the "Technology" and "Fuel" columns
#     Rule: The dataset does not provide any data about those two columns, so we added the default value of "All" in both cases.

# %%
dataframeManager.simple_column_insert(df,ColumnName.TECHNOLOGY.value,"All")
dataframeManager.simple_column_insert(df,ColumnName.FUEL.value,"All")
df
# Out:
#      Fuel Technology  Service                         Source Country  \
# 0     All        All  Freight  International Transport Forum  Canada
# 1     All        All  Freight  International Transport Forum  Canada
# 2     All        All  Freight  International Transport Forum  Canada
# 3     All        All  Freight  International Transport Forum  Canada
# 4     All        All  Freight  International Transport Forum  Canada
# ...   ...        ...      ...                            ...     ...
# 1428  All        All  Freight  International Transport Forum  Turkey
# 1429  All        All  Freight  International Transport Forum  Turkey
# 1430  All        All  Freight  International Transport Forum  Turkey
# 1431  All        All  Freight  International Transport Forum  Turkey
# 1432  All        All  Freight  International Transport Forum  Turkey
#
#                                    Variable  Year               Unit  \
# 0     Coastal shipping (national transport)  1995  Tonnes-kilometres
# 1     Coastal shipping (national transport)  1996  Tonnes-kilometres
# 2     Coastal shipping (national transport)  1997  Tonnes-kilometres
# 3     Coastal shipping (national transport)  1998  Tonnes-kilometres
# 4     Coastal shipping (national transport)  1999  Tonnes-kilometres
# ...                                     ...   ...                ...
# 1428  Coastal shipping (national transport)  2014  Tonnes-kilometres
# 1429  Coastal shipping (national transport)  2015  Tonnes-kilometres
# 1430  Coastal shipping (national transport)  2016  Tonnes-kilometres
# 1431  Coastal shipping (national transport)  2017  Tonnes-kilometres
# 1432  Coastal shipping (national transport)  2018  Tonnes-kilometres
#
#      PowerCode    Value
# 0     Millions  10369.0
# 1     Millions  10166.0
# 2     Millions  10735.0
# 3     Millions  13420.0
# 4     Millions  14144.0
# ...        ...      ...
# 1428  Millions  18553.0
# 1429  Millions  19189.0
# 1430  Millions  19492.0
# 1431  Millions  22087.0
# 1432  Millions  21779.0
#
# [829 rows x 10 columns]

# %% [markdown]
# # Setting the correct unit name in the "Unit" column
#     Rule: Based on the template, the correct unit for "Fraight Activity" is "10^9 tonne-km / yr", so we will assign those units to the data

# %%
# Dropping the current "Unit" column
df.drop(columns=["Unit"], inplace = True)

# Adding the new "Unit" column
df[ColumnName.UNIT.value] = ["10^9 tonne-km / yr"]*len(df) 
df
# Out:
#      Fuel Technology  Service                         Source Country  \
# 0     All        All  Freight  International Transport Forum  Canada
# 1     All        All  Freight  International Transport Forum  Canada
# 2     All        All  Freight  International Transport Forum  Canada
# 3     All        All  Freight  International Transport Forum  Canada
# 4     All        All  Freight  International Transport Forum  Canada
# ...   ...        ...      ...                            ...     ...
# 1428  All        All  Freight  International Transport Forum  Turkey
# 1429  All        All  Freight  International Transport Forum  Turkey
# 1430  All        All  Freight  International Transport Forum  Turkey
# 1431  All        All  Freight  International Transport Forum  Turkey
# 1432  All        All  Freight  International Transport Forum  Turkey
#
#                                    Variable  Year PowerCode    Value  \
# 0     Coastal shipping (national transport)  1995  Millions  10369.0
# 1     Coastal shipping (national transport)  1996  Millions  10166.0
# 2     Coastal shipping (national transport)  1997  Millions  10735.0
# 3     Coastal shipping (national transport)  1998  Millions  13420.0
# 4     Coastal shipping (national transport)  1999  Millions  14144.0
# ...                                     ...   ...       ...      ...
# 1428  Coastal shipping (national transport)  2014  Millions  18553.0
# 1429  Coastal shipping (national transport)  2015  Millions  19189.0
# 1430  Coastal shipping (national transport)  2016  Millions  19492.0
# 1431  Coastal shipping (national transport)  2017  Millions  22087.0
# 1432  Coastal shipping (national transport)  2018  Millions  21779.0
#
#                     Unit
# 0     10^9 tonne-km / yr
# 1     10^9 tonne-km / yr
# 2     10^9 tonne-km / yr
# 3     10^9 tonne-km / yr
# 4     10^9 tonne-km / yr
# ...                  ...
# 1428  10^9 tonne-km / yr
# 1429  10^9 tonne-km / yr
# 1430  10^9 tonne-km / yr
# 1431  10^9 tonne-km / yr
# 1432  10^9 tonne-km / yr
#
# [829 rows x 10 columns]

# %% [markdown]
# # Setting the correct magnitude of the "Value" column
#     Rule: The current data is in million. We will convert all values to billions. In which (1M = 0.001B)

# %%
# Removing the "PowerCode" column since it is not necessary
df.drop(columns=["PowerCode"], inplace = True)

# Looping though each row and convert each value to billion magnitude
for index, row in df.iterrows():
    current_value = row.Value
    new_value = current_value * float(0.001)
    df.Value[index] = new_value
df
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      Fuel Technology  Service                         Source Country  \
# 0     All        All  Freight  International Transport Forum  Canada
# 1     All        All  Freight  International Transport Forum  Canada
# 2     All        All  Freight  International Transport Forum  Canada
# 3     All        All  Freight  International Transport Forum  Canada
# 4     All        All  Freight  International Transport Forum  Canada
# ...   ...        ...      ...                            ...     ...
# 1428  All        All  Freight  International Transport Forum  Turkey
# 1429  All        All  Freight  International Transport Forum  Turkey
# 1430  All        All  Freight  International Transport Forum  Turkey
# 1431  All        All  Freight  International Transport Forum  Turkey
# 1432  All        All  Freight  International Transport Forum  Turkey
#
#                                    Variable  Year   Value                Unit
# 0     Coastal shipping (national transport)  1995  10.369  10^9 tonne-km / yr
# 1     Coastal shipping (national transport)  1996  10.166  10^9 tonne-km / yr
# 2     Coastal shipping (national transport)  1997  10.735  10^9 tonne-km / yr
# 3     Coastal shipping (national transport)  1998  13.420  10^9 tonne-km / yr
# 4     Coastal shipping (national transport)  1999  14.144  10^9 tonne-km / yr
# ...                                     ...   ...     ...                 ...
# 1428  Coastal shipping (national transport)  2014  18.553  10^9 tonne-km / yr
# 1429  Coastal shipping (national transport)  2015  19.189  10^9 tonne-km / yr
# 1430  Coastal shipping (national transport)  2016  19.492  10^9 tonne-km / yr
# 1431  Coastal shipping (national transport)  2017  22.087  10^9 tonne-km / yr
# 1432  Coastal shipping (national transport)  2018  21.779  10^9 tonne-km / yr
#
# [829 rows x 9 columns]

# %% [markdown]
# # Adding the "Mode" column
#     Rule: Since all the data is about shipping, all rows have "Shipping" as mode

# %%
dataframeManager.simple_column_insert(df,ColumnName.MODE.value,"Shipping")
df
# Out:
#           Mode Fuel Technology  Service                         Source  \
# 0     Shipping  All        All  Freight  International Transport Forum
# 1     Shipping  All        All  Freight  International Transport Forum
# 2     Shipping  All        All  Freight  International Transport Forum
# 3     Shipping  All        All  Freight  International Transport Forum
# 4     Shipping  All        All  Freight  International Transport Forum
# ...        ...  ...        ...      ...                            ...
# 1428  Shipping  All        All  Freight  International Transport Forum
# 1429  Shipping  All        All  Freight  International Transport Forum
# 1430  Shipping  All        All  Freight  International Transport Forum
# 1431  Shipping  All        All  Freight  International Transport Forum
# 1432  Shipping  All        All  Freight  International Transport Forum
#
#      Country                               Variable  Year   Value  \
# 0     Canada  Coastal shipping (national transport)  1995  10.369
# 1     Canada  Coastal shipping (national transport)  1996  10.166
# 2     Canada  Coastal shipping (national transport)  1997  10.735
# 3     Canada  Coastal shipping (national transport)  1998  13.420
# 4     Canada  Coastal shipping (national transport)  1999  14.144
# ...      ...                                    ...   ...     ...
# 1428  Turkey  Coastal shipping (national transport)  2014  18.553
# 1429  Turkey  Coastal shipping (national transport)  2015  19.189
# 1430  Turkey  Coastal shipping (national transport)  2016  19.492
# 1431  Turkey  Coastal shipping (national transport)  2017  22.087
# 1432  Turkey  Coastal shipping (national transport)  2018  21.779
#
#                     Unit
# 0     10^9 tonne-km / yr
# 1     10^9 tonne-km / yr
# 2     10^9 tonne-km / yr
# 3     10^9 tonne-km / yr
# 4     10^9 tonne-km / yr
# ...                  ...
# 1428  10^9 tonne-km / yr
# 1429  10^9 tonne-km / yr
# 1430  10^9 tonne-km / yr
# 1431  10^9 tonne-km / yr
# 1432  10^9 tonne-km / yr
#
# [829 rows x 10 columns]

# %% [markdown]
# # Adding the column "Vehicle Type"
#     Rule: Since all the data in this dataset is associted to coastal shipping, the vehicle type is "Coastal"

# %%
dataframeManager.simple_column_insert(df,ColumnName.VEHICLE_TYPE.value,"Coastal")
df
# Out:
#      Vehicle Type      Mode Fuel Technology  Service  \
# 0         Coastal  Shipping  All        All  Freight
# 1         Coastal  Shipping  All        All  Freight
# 2         Coastal  Shipping  All        All  Freight
# 3         Coastal  Shipping  All        All  Freight
# 4         Coastal  Shipping  All        All  Freight
# ...           ...       ...  ...        ...      ...
# 1428      Coastal  Shipping  All        All  Freight
# 1429      Coastal  Shipping  All        All  Freight
# 1430      Coastal  Shipping  All        All  Freight
# 1431      Coastal  Shipping  All        All  Freight
# 1432      Coastal  Shipping  All        All  Freight
#
#                              Source Country  \
# 0     International Transport Forum  Canada
# 1     International Transport Forum  Canada
# 2     International Transport Forum  Canada
# 3     International Transport Forum  Canada
# 4     International Transport Forum  Canada
# ...                             ...     ...
# 1428  International Transport Forum  Turkey
# 1429  International Transport Forum  Turkey
# 1430  International Transport Forum  Turkey
# 1431  International Transport Forum  Turkey
# 1432  International Transport Forum  Turkey
#
#                                    Variable  Year   Value                Unit
# 0     Coastal shipping (national transport)  1995  10.369  10^9 tonne-km / yr
# 1     Coastal shipping (national transport)  1996  10.166  10^9 tonne-km / yr
# 2     Coastal shipping (national transport)  1997  10.735  10^9 tonne-km / yr
# 3     Coastal shipping (national transport)  1998  13.420  10^9 tonne-km / yr
# 4     Coastal shipping (national transport)  1999  14.144  10^9 tonne-km / yr
# ...                                     ...   ...     ...                 ...
# 1428  Coastal shipping (national transport)  2014  18.553  10^9 tonne-km / yr
# 1429  Coastal shipping (national transport)  2015  19.189  10^9 tonne-km / yr
# 1430  Coastal shipping (national transport)  2016  19.492  10^9 tonne-km / yr
# 1431  Coastal shipping (national transport)  2017  22.087  10^9 tonne-km / yr
# 1432  Coastal shipping (national transport)  2018  21.779  10^9 tonne-km / yr
#
# [829 rows x 11 columns]

# %% [markdown]
# # Renaming the column "Variable"
#     Rule: There is only one activity being perform in this dataset and that is the "Freight Activity". We are setting, for each row, the variable "Freight Activity"

# %%
# Dropping the current "Variable" column
df.drop(columns=["Variable"], inplace = True)

# Adding the new "Variable" column with the new data
dataframeManager.simple_column_insert(df,ColumnName.VARIABLE.value,"Freight Activity")
df
# Out:
#               Variable Vehicle Type      Mode Fuel Technology  Service  \
# 0     Freight Activity      Coastal  Shipping  All        All  Freight
# 1     Freight Activity      Coastal  Shipping  All        All  Freight
# 2     Freight Activity      Coastal  Shipping  All        All  Freight
# 3     Freight Activity      Coastal  Shipping  All        All  Freight
# 4     Freight Activity      Coastal  Shipping  All        All  Freight
# ...                ...          ...       ...  ...        ...      ...
# 1428  Freight Activity      Coastal  Shipping  All        All  Freight
# 1429  Freight Activity      Coastal  Shipping  All        All  Freight
# 1430  Freight Activity      Coastal  Shipping  All        All  Freight
# 1431  Freight Activity      Coastal  Shipping  All        All  Freight
# 1432  Freight Activity      Coastal  Shipping  All        All  Freight
#
#                              Source Country  Year   Value                Unit
# 0     International Transport Forum  Canada  1995  10.369  10^9 tonne-km / yr
# 1     International Transport Forum  Canada  1996  10.166  10^9 tonne-km / yr
# 2     International Transport Forum  Canada  1997  10.735  10^9 tonne-km / yr
# 3     International Transport Forum  Canada  1998  13.420  10^9 tonne-km / yr
# 4     International Transport Forum  Canada  1999  14.144  10^9 tonne-km / yr
# ...                             ...     ...   ...     ...                 ...
# 1428  International Transport Forum  Turkey  2014  18.553  10^9 tonne-km / yr
# 1429  International Transport Forum  Turkey  2015  19.189  10^9 tonne-km / yr
# 1430  International Transport Forum  Turkey  2016  19.492  10^9 tonne-km / yr
# 1431  International Transport Forum  Turkey  2017  22.087  10^9 tonne-km / yr
# 1432  International Transport Forum  Turkey  2018  21.779  10^9 tonne-km / yr
#
# [829 rows x 11 columns]

# %% [markdown]
# # Getting the ISO code for each country
#     Rule: For each country, we need to assign their respective ISO Code

# %% [markdown]
# ## Determining which countries do not appear in the list of ISO Code
#     As seen from the code below, four countries appear to not have ISO code. However, the reason is because the countries are written in a format that is not understandable. So, this is how each those "missing" countries will be called in order to obtain their ISO code
#
#     Original Name --> New name
#         > Montenegro, Republic of --> Montenegro
#         > Korea --> Korea, Republic of
#         > Serbia, Republic of --> Serbia

# %%
# Getting the list of countries available
list_of_countries = list(set(df["Country"]))

# Getting the list of countries with no ISO code
countries_with_no_ISO_code = countryCodeManager.get_list_of_countries_with_no_iso_code(list_of_countries)
        
# Print this list of countries with no ISO codes
countries_with_no_ISO_code
# Out:
# ['Korea']

# %% [markdown]
# ## Adding the ISO column to the df

# %%
dirty_list_of_all_countries = df["Country"]
clean_list_of_all_countries = []

for country in dirty_list_of_all_countries:
    if country == "Montenegro, Republic of":
        clean_list_of_all_countries.append("Montenegro")
    elif country == "Bosnia-Herzegovina":
        clean_list_of_all_countries.append("Bosnia and Herzegovina")
    elif country == "Korea":
        clean_list_of_all_countries.append("Korea, Republic of")
    elif country == "Serbia, Republic of":
        clean_list_of_all_countries.append("Serbia")
    else:
        clean_list_of_all_countries.append(country)

# Ensure the size of the cleaned list is the same as the dirty list
assert len(clean_list_of_all_countries) == len(dirty_list_of_all_countries)

# Assert that for all elements in the new list, no country is left without an ISO code
assert len(countryCodeManager.get_list_of_countries_with_no_iso_code(clean_list_of_all_countries)) == 0

# Getting the list of iso codes
list_of_iso_codes = countryCodeManager.get_list_of_iso_for_countries(clean_list_of_all_countries)

# Adding the column to the dataframe
df[ColumnName.ISO_CODE.value] = list_of_iso_codes
df
# Out:
#               Variable Vehicle Type      Mode Fuel Technology  Service  \
# 0     Freight Activity      Coastal  Shipping  All        All  Freight
# 1     Freight Activity      Coastal  Shipping  All        All  Freight
# 2     Freight Activity      Coastal  Shipping  All        All  Freight
# 3     Freight Activity      Coastal  Shipping  All        All  Freight
# 4     Freight Activity      Coastal  Shipping  All        All  Freight
# ...                ...          ...       ...  ...        ...      ...
# 1428  Freight Activity      Coastal  Shipping  All        All  Freight
# 1429  Freight Activity      Coastal  Shipping  All        All  Freight
# 1430  Freight Activity      Coastal  Shipping  All        All  Freight
# 1431  Freight Activity      Coastal  Shipping  All        All  Freight
# 1432  Freight Activity      Coastal  Shipping  All        All  Freight
#
#                              Source Country  Year   Value                Unit  \
# 0     International Transport Forum  Canada  1995  10.369  10^9 tonne-km / yr
# 1     International Transport Forum  Canada  1996  10.166  10^9 tonne-km / yr
# 2     International Transport Forum  Canada  1997  10.735  10^9 tonne-km / yr
# 3     International Transport Forum  Canada  1998  13.420  10^9 tonne-km / yr
# 4     International Transport Forum  Canada  1999  14.144  10^9 tonne-km / yr
# ...                             ...     ...   ...     ...                 ...
# 1428  International Transport Forum  Turkey  2014  18.553  10^9 tonne-km / yr
# 1429  International Transport Forum  Turkey  2015  19.189  10^9 tonne-km / yr
# 1430  International Transport Forum  Turkey  2016  19.492  10^9 tonne-km / yr
# 1431  International Transport Forum  Turkey  2017  22.087  10^9 tonne-km / yr
# 1432  International Transport Forum  Turkey  2018  21.779  10^9 tonne-km / yr
#
#      ISO Code
# 0         CAN
# 1         CAN
# 2         CAN
# 3         CAN
# 4         CAN
# ...       ...
# 1428      TUR
# 1429      TUR
# 1430      TUR
# 1431      TUR
# 1432      TUR
#
# [829 rows x 12 columns]

# %% [markdown]
# # Getting the ITEM region for each country
#     Rule: For each country, we need to assign an ITEM region

# %% [markdown]
# ## Determining which countries are missing an ITEM region
#     As seen from the cell below, there is no country that does no have a respective ITEM region. Therefore, no further cleaning needs to be done to get the item regions.

# %%
# Getting the list of ISO codes
list_of_iso_codes = list(set(df["ISO Code"]))

# Getting the list of ISO code with no region
iso_code_with_no_region = countryCodeManager.get_list_of_iso_codes_with_no_region(list_of_iso_codes)

# printing the list of ISO codes
iso_code_with_no_region
# Out:
# []

# %% [markdown]
# ## Adding the ITEM region column to the dataset

# %%
# Getting the complete list of iso codes
list_of_all_codes = df["ISO Code"]

item_region = countryCodeManager.get_list_of_regions_for_iso_codes(list_of_all_codes)

# Adding the column to the dataframe
df[ColumnName.ITEM_REGION.value] = item_region
df
# Out:
#               Variable Vehicle Type      Mode Fuel Technology  Service  \
# 0     Freight Activity      Coastal  Shipping  All        All  Freight
# 1     Freight Activity      Coastal  Shipping  All        All  Freight
# 2     Freight Activity      Coastal  Shipping  All        All  Freight
# 3     Freight Activity      Coastal  Shipping  All        All  Freight
# 4     Freight Activity      Coastal  Shipping  All        All  Freight
# ...                ...          ...       ...  ...        ...      ...
# 1428  Freight Activity      Coastal  Shipping  All        All  Freight
# 1429  Freight Activity      Coastal  Shipping  All        All  Freight
# 1430  Freight Activity      Coastal  Shipping  All        All  Freight
# 1431  Freight Activity      Coastal  Shipping  All        All  Freight
# 1432  Freight Activity      Coastal  Shipping  All        All  Freight
#
#                              Source Country  Year   Value                Unit  \
# 0     International Transport Forum  Canada  1995  10.369  10^9 tonne-km / yr
# 1     International Transport Forum  Canada  1996  10.166  10^9 tonne-km / yr
# 2     International Transport Forum  Canada  1997  10.735  10^9 tonne-km / yr
# 3     International Transport Forum  Canada  1998  13.420  10^9 tonne-km / yr
# 4     International Transport Forum  Canada  1999  14.144  10^9 tonne-km / yr
# ...                             ...     ...   ...     ...                 ...
# 1428  International Transport Forum  Turkey  2014  18.553  10^9 tonne-km / yr
# 1429  International Transport Forum  Turkey  2015  19.189  10^9 tonne-km / yr
# 1430  International Transport Forum  Turkey  2016  19.492  10^9 tonne-km / yr
# 1431  International Transport Forum  Turkey  2017  22.087  10^9 tonne-km / yr
# 1432  International Transport Forum  Turkey  2018  21.779  10^9 tonne-km / yr
#
#      ISO Code         Region
# 0         CAN         Canada
# 1         CAN         Canada
# 2         CAN         Canada
# 3         CAN         Canada
# 4         CAN         Canada
# ...       ...            ...
# 1428      TUR  Non-EU Europe
# 1429      TUR  Non-EU Europe
# 1430      TUR  Non-EU Europe
# 1431      TUR  Non-EU Europe
# 1432      TUR  Non-EU Europe
#
# [829 rows x 13 columns]

# %% [markdown]
# # Reordering the columns
#     Rule: The columns should follow the order established in the latest template

# %%
df = dataframeManager.reorder_columns(df)
df
# Out:
#                              Source Country ISO Code         Region  \
# 0     International Transport Forum  Canada      CAN         Canada
# 1     International Transport Forum  Canada      CAN         Canada
# 2     International Transport Forum  Canada      CAN         Canada
# 3     International Transport Forum  Canada      CAN         Canada
# 4     International Transport Forum  Canada      CAN         Canada
# ...                             ...     ...      ...            ...
# 1428  International Transport Forum  Turkey      TUR  Non-EU Europe
# 1429  International Transport Forum  Turkey      TUR  Non-EU Europe
# 1430  International Transport Forum  Turkey      TUR  Non-EU Europe
# 1431  International Transport Forum  Turkey      TUR  Non-EU Europe
# 1432  International Transport Forum  Turkey      TUR  Non-EU Europe
#
#               Variable                Unit  Service      Mode Vehicle Type  \
# 0     Freight Activity  10^9 tonne-km / yr  Freight  Shipping      Coastal
# 1     Freight Activity  10^9 tonne-km / yr  Freight  Shipping      Coastal
# 2     Freight Activity  10^9 tonne-km / yr  Freight  Shipping      Coastal
# 3     Freight Activity  10^9 tonne-km / yr  Freight  Shipping      Coastal
# 4     Freight Activity  10^9 tonne-km / yr  Freight  Shipping      Coastal
# ...                ...                 ...      ...       ...          ...
# 1428  Freight Activity  10^9 tonne-km / yr  Freight  Shipping      Coastal
# 1429  Freight Activity  10^9 tonne-km / yr  Freight  Shipping      Coastal
# 1430  Freight Activity  10^9 tonne-km / yr  Freight  Shipping      Coastal
# 1431  Freight Activity  10^9 tonne-km / yr  Freight  Shipping      Coastal
# 1432  Freight Activity  10^9 tonne-km / yr  Freight  Shipping      Coastal
#
#      Technology Fuel   Value  Year
# 0           All  All  10.369  1995
# 1           All  All  10.166  1996
# 2           All  All  10.735  1997
# 3           All  All  13.420  1998
# 4           All  All  14.144  1999
# ...         ...  ...     ...   ...
# 1428        All  All  18.553  2014
# 1429        All  All  19.189  2015
# 1430        All  All  19.492  2016
# 1431        All  All  22.087  2017
# 1432        All  All  21.779  2018
#
# [829 rows x 13 columns]

# %% [markdown]
# # Exporting results

# %%
# Programming Friendly View
dataframeManager.create_programming_friendly_file(df)

# User Friendly View
dataframeManager.create_user_friendly_file(df)
# Out:
# > PF File saved at: /Users/hlinero/Documents/database/item/historical/scripts
# > UF File saved at: /Users/hlinero/Documents/database/item/historical/scripts
