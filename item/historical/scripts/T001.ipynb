# %%
import pandas as pd
from pprint import pprint

# %% [markdown]
# # Creating the dataframe and viewing the data

# %%
# Creating a dataframe from the csv data
data_id = "T001"
raw_data_csv_path = "/Users/hlinero/Desktop/iTEM Material/raw dataset/T001/"
df = pd.read_csv(raw_data_csv_path+"T001_ITF_GOODS_TRANSPORT_25102019112251109.csv")
df.head(50)
# Out:
#    COUNTRY Country   VARIABLE                               Variable  YEAR  \
# 0      CAN  Canada  T-SEA-CAB  Coastal shipping (national transport)  1995
# 1      CAN  Canada  T-SEA-CAB  Coastal shipping (national transport)  1996
# 2      CAN  Canada  T-SEA-CAB  Coastal shipping (national transport)  1997
# 3      CAN  Canada  T-SEA-CAB  Coastal shipping (national transport)  1998
# 4      CAN  Canada  T-SEA-CAB  Coastal shipping (national transport)  1999
# 5      CAN  Canada  T-SEA-CAB  Coastal shipping (national transport)  2000
# 6      CAN  Canada  T-SEA-CAB  Coastal shipping (national transport)  2001
# 7      CAN  Canada  T-SEA-CAB  Coastal shipping (national transport)  2002
# 8      CAN  Canada  T-SEA-CAB  Coastal shipping (national transport)  2003
# 9      CAN  Canada  T-SEA-CAB  Coastal shipping (national transport)  2004
# 10     CAN  Canada  T-SEA-CAB  Coastal shipping (national transport)  2005
# 11     CAN  Canada  T-SEA-CAB  Coastal shipping (national transport)  2006
# 12     CAN  Canada  T-SEA-CAB  Coastal shipping (national transport)  2007
# 13     CAN  Canada  T-SEA-CAB  Coastal shipping (national transport)  2008
# 14     CAN  Canada  T-SEA-CAB  Coastal shipping (national transport)  2009
# 15     CAN  Canada  T-SEA-CAB  Coastal shipping (national transport)  2010
# 16     CAN  Canada  T-SEA-CAB  Coastal shipping (national transport)  2011
# 17     SWE  Sweden  T-SEA-CAB  Coastal shipping (national transport)  1970
# 18     SWE  Sweden  T-SEA-CAB  Coastal shipping (national transport)  1971
# 19     SWE  Sweden  T-SEA-CAB  Coastal shipping (national transport)  1972
# 20     SWE  Sweden  T-SEA-CAB  Coastal shipping (national transport)  1973
# 21     SWE  Sweden  T-SEA-CAB  Coastal shipping (national transport)  1974
# 22     SWE  Sweden  T-SEA-CAB  Coastal shipping (national transport)  1975
# 23     SWE  Sweden  T-SEA-CAB  Coastal shipping (national transport)  1976
# 24     SWE  Sweden  T-SEA-CAB  Coastal shipping (national transport)  1977
# 25     SWE  Sweden  T-SEA-CAB  Coastal shipping (national transport)  1978
# 26     SWE  Sweden  T-SEA-CAB  Coastal shipping (national transport)  1979
# 27     SWE  Sweden  T-SEA-CAB  Coastal shipping (national transport)  1980
# 28     SWE  Sweden  T-SEA-CAB  Coastal shipping (national transport)  1981
# 29     SWE  Sweden  T-SEA-CAB  Coastal shipping (national transport)  1982
# 30     SWE  Sweden  T-SEA-CAB  Coastal shipping (national transport)  1983
# 31     SWE  Sweden  T-SEA-CAB  Coastal shipping (national transport)  1984
# 32     SWE  Sweden  T-SEA-CAB  Coastal shipping (national transport)  1985
# 33     SWE  Sweden  T-SEA-CAB  Coastal shipping (national transport)  1986
# 34     SWE  Sweden  T-SEA-CAB  Coastal shipping (national transport)  1987
# 35     SWE  Sweden  T-SEA-CAB  Coastal shipping (national transport)  1988
# 36     SWE  Sweden  T-SEA-CAB  Coastal shipping (national transport)  1989
# 37     SWE  Sweden  T-SEA-CAB  Coastal shipping (national transport)  1990
# 38     SWE  Sweden  T-SEA-CAB  Coastal shipping (national transport)  1991
# 39     SWE  Sweden  T-SEA-CAB  Coastal shipping (national transport)  1992
# 40     SWE  Sweden  T-SEA-CAB  Coastal shipping (national transport)  1993
# 41     SWE  Sweden  T-SEA-CAB  Coastal shipping (national transport)  1994
# 42     SWE  Sweden  T-SEA-CAB  Coastal shipping (national transport)  1995
# 43     SWE  Sweden  T-SEA-CAB  Coastal shipping (national transport)  1996
# 44     SWE  Sweden  T-SEA-CAB  Coastal shipping (national transport)  1997
# 45     SWE  Sweden  T-SEA-CAB  Coastal shipping (national transport)  1998
# 46     SWE  Sweden  T-SEA-CAB  Coastal shipping (national transport)  1999
# 47     SWE  Sweden  T-SEA-CAB  Coastal shipping (national transport)  2000
# 48     SWE  Sweden  T-SEA-CAB  Coastal shipping (national transport)  2001
# 49     SWE  Sweden  T-SEA-CAB  Coastal shipping (national transport)  2002
#
#     Year Unit Code               Unit  PowerCode Code PowerCode  \
# 0   1995   TONNEKM  Tonnes-kilometres               6  Millions
# 1   1996   TONNEKM  Tonnes-kilometres               6  Millions
# 2   1997   TONNEKM  Tonnes-kilometres               6  Millions
# 3   1998   TONNEKM  Tonnes-kilometres               6  Millions
# 4   1999   TONNEKM  Tonnes-kilometres               6  Millions
# 5   2000   TONNEKM  Tonnes-kilometres               6  Millions
# 6   2001   TONNEKM  Tonnes-kilometres               6  Millions
# 7   2002   TONNEKM  Tonnes-kilometres               6  Millions
# 8   2003   TONNEKM  Tonnes-kilometres               6  Millions
# 9   2004   TONNEKM  Tonnes-kilometres               6  Millions
# 10  2005   TONNEKM  Tonnes-kilometres               6  Millions
# 11  2006   TONNEKM  Tonnes-kilometres               6  Millions
# 12  2007   TONNEKM  Tonnes-kilometres               6  Millions
# 13  2008   TONNEKM  Tonnes-kilometres               6  Millions
# 14  2009   TONNEKM  Tonnes-kilometres               6  Millions
# 15  2010   TONNEKM  Tonnes-kilometres               6  Millions
# 16  2011   TONNEKM  Tonnes-kilometres               6  Millions
# 17  1970   TONNEKM  Tonnes-kilometres               6  Millions
# 18  1971   TONNEKM  Tonnes-kilometres               6  Millions
# 19  1972   TONNEKM  Tonnes-kilometres               6  Millions
# 20  1973   TONNEKM  Tonnes-kilometres               6  Millions
# 21  1974   TONNEKM  Tonnes-kilometres               6  Millions
# 22  1975   TONNEKM  Tonnes-kilometres               6  Millions
# 23  1976   TONNEKM  Tonnes-kilometres               6  Millions
# 24  1977   TONNEKM  Tonnes-kilometres               6  Millions
# 25  1978   TONNEKM  Tonnes-kilometres               6  Millions
# 26  1979   TONNEKM  Tonnes-kilometres               6  Millions
# 27  1980   TONNEKM  Tonnes-kilometres               6  Millions
# 28  1981   TONNEKM  Tonnes-kilometres               6  Millions
# 29  1982   TONNEKM  Tonnes-kilometres               6  Millions
# 30  1983   TONNEKM  Tonnes-kilometres               6  Millions
# 31  1984   TONNEKM  Tonnes-kilometres               6  Millions
# 32  1985   TONNEKM  Tonnes-kilometres               6  Millions
# 33  1986   TONNEKM  Tonnes-kilometres               6  Millions
# 34  1987   TONNEKM  Tonnes-kilometres               6  Millions
# 35  1988   TONNEKM  Tonnes-kilometres               6  Millions
# 36  1989   TONNEKM  Tonnes-kilometres               6  Millions
# 37  1990   TONNEKM  Tonnes-kilometres               6  Millions
# 38  1991   TONNEKM  Tonnes-kilometres               6  Millions
# 39  1992   TONNEKM  Tonnes-kilometres               6  Millions
# 40  1993   TONNEKM  Tonnes-kilometres               6  Millions
# 41  1994   TONNEKM  Tonnes-kilometres               6  Millions
# 42  1995   TONNEKM  Tonnes-kilometres               6  Millions
# 43  1996   TONNEKM  Tonnes-kilometres               6  Millions
# 44  1997   TONNEKM  Tonnes-kilometres               6  Millions
# 45  1998   TONNEKM  Tonnes-kilometres               6  Millions
# 46  1999   TONNEKM  Tonnes-kilometres               6  Millions
# 47  2000   TONNEKM  Tonnes-kilometres               6  Millions
# 48  2001   TONNEKM  Tonnes-kilometres               6  Millions
# 49  2002   TONNEKM  Tonnes-kilometres               6  Millions
#
#     Reference Period Code  Reference Period    Value Flag Codes Flags
# 0                     NaN               NaN  10369.0        NaN   NaN
# 1                     NaN               NaN  10166.0        NaN   NaN
# 2                     NaN               NaN  10735.0        NaN   NaN
# 3                     NaN               NaN  13420.0        NaN   NaN
# 4                     NaN               NaN  14144.0        NaN   NaN
# 5                     NaN               NaN  13891.0        NaN   NaN
# 6                     NaN               NaN  15055.0        NaN   NaN
# 7                     NaN               NaN  21451.0        NaN   NaN
# 8                     NaN               NaN  25517.0        NaN   NaN
# 9                     NaN               NaN  25329.0        NaN   NaN
# 10                    NaN               NaN  24450.0        NaN   NaN
# 11                    NaN               NaN  24881.0        NaN   NaN
# 12                    NaN               NaN  29388.0        NaN   NaN
# 13                    NaN               NaN  27852.0        NaN   NaN
# 14                    NaN               NaN  26678.0        NaN   NaN
# 15                    NaN               NaN  29547.0        NaN   NaN
# 16                    NaN               NaN  31735.0        NaN   NaN
# 17                    NaN               NaN   5200.0        NaN   NaN
# 18                    NaN               NaN   5500.0        NaN   NaN
# 19                    NaN               NaN   5900.0        NaN   NaN
# 20                    NaN               NaN   6300.0        NaN   NaN
# 21                    NaN               NaN   7200.0        NaN   NaN
# 22                    NaN               NaN   8200.0        NaN   NaN
# 23                    NaN               NaN   9293.0        NaN   NaN
# 24                    NaN               NaN   9340.0        NaN   NaN
# 25                    NaN               NaN   8650.0        NaN   NaN
# 26                    NaN               NaN  10163.0        NaN   NaN
# 27                    NaN               NaN  10256.0        NaN   NaN
# 28                    NaN               NaN   9364.0        NaN   NaN
# 29                    NaN               NaN   9381.0        NaN   NaN
# 30                    NaN               NaN   9209.0        NaN   NaN
# 31                    NaN               NaN   9144.0        NaN   NaN
# 32                    NaN               NaN   9183.0        NaN   NaN
# 33                    NaN               NaN   9447.0        NaN   NaN
# 34                    NaN               NaN   8665.0        NaN   NaN
# 35                    NaN               NaN   7859.0        NaN   NaN
# 36                    NaN               NaN   7853.0        NaN   NaN
# 37                    NaN               NaN   7900.0        NaN   NaN
# 38                    NaN               NaN   7538.0        NaN   NaN
# 39                    NaN               NaN   7091.0        NaN   NaN
# 40                    NaN               NaN   7349.0        NaN   NaN
# 41                    NaN               NaN   7641.0        NaN   NaN
# 42                    NaN               NaN   8274.0        NaN   NaN
# 43                    NaN               NaN   8634.0        NaN   NaN
# 44                    NaN               NaN   8387.0        NaN   NaN
# 45                    NaN               NaN   8334.0        NaN   NaN
# 46                    NaN               NaN   7700.0        NaN   NaN
# 47                    NaN               NaN   8118.0        NaN   NaN
# 48                    NaN               NaN   7579.0        NaN   NaN
# 49                    NaN               NaN   7183.0        NaN   NaN

# %% [markdown]
# # General Info About the Data

# %%
# Getting general info about the data
rows, cols = df.shape
print(">> Number of Columns: {}".format(cols))
print(">> Number of Rows: {}".format(rows))

# Grouping the data by Countries
group_by_country = df.groupby(df.Country)
list_of_countries = list(group_by_country.groups.keys())
print(">> Number of countries: {}".format(len(list_of_countries)))
# Out:
# >> Number of Columns: 15
# >> Number of Rows: 1579
# >> Number of countries: 40

# %% [markdown]
# # Removing all unnecessary columns
#
# ### Rule: To comply with the latest template, we will drop all the unnecessary columns and rename others.

# %%
# Droping the repeated columns
columns_to_delete = ["COUNTRY", "YEAR", "VARIABLE","Reference Period Code","Unit Code","Reference Period", "Flag Codes", "Flags", "PowerCode Code"]
df.drop(columns=columns_to_delete, inplace = True)
df.rename(columns={"Country":"Region"}, inplace = True)
df
# Out:
#               Region                               Variable  Year  \
# 0             Canada  Coastal shipping (national transport)  1995
# 1             Canada  Coastal shipping (national transport)  1996
# 2             Canada  Coastal shipping (national transport)  1997
# 3             Canada  Coastal shipping (national transport)  1998
# 4             Canada  Coastal shipping (national transport)  1999
# ...              ...                                    ...   ...
# 1574  Czech Republic  Coastal shipping (national transport)  2014
# 1575  Czech Republic  Coastal shipping (national transport)  2015
# 1576  Czech Republic  Coastal shipping (national transport)  2016
# 1577  Czech Republic  Coastal shipping (national transport)  2017
# 1578  Czech Republic  Coastal shipping (national transport)  2018
#
#                    Unit PowerCode    Value
# 0     Tonnes-kilometres  Millions  10369.0
# 1     Tonnes-kilometres  Millions  10166.0
# 2     Tonnes-kilometres  Millions  10735.0
# 3     Tonnes-kilometres  Millions  13420.0
# 4     Tonnes-kilometres  Millions  14144.0
# ...                 ...       ...      ...
# 1574  Tonnes-kilometres  Millions      NaN
# 1575  Tonnes-kilometres  Millions      NaN
# 1576  Tonnes-kilometres  Millions      NaN
# 1577  Tonnes-kilometres  Millions      NaN
# 1578  Tonnes-kilometres  Millions      NaN
#
# [1579 rows x 6 columns]

# %% [markdown]
# ## Getting a generic idea of what countries are missing values and dropping NaN values
#     Rule: Erase all value with NaN

# %%
list_of_countries_with_missing_values = list(set(df[df['Value'].isnull()]["Region"]))
print(">> Number of countries missing values: {}".format(len(list_of_countries_with_missing_values)))
print(">> Countries missing values:")
pprint(list_of_countries_with_missing_values)
print(">> Number of rows to erase: {}".format(len(df[df['Value'].isnull()])))
# Out:
# >> Number of countries missing values: 16
# >> Countries missing values:
# ['North Macedonia',
#  'Lithuania',
#  'Hungary',
#  'Czech Republic',
#  'Serbia, Republic of',
#  'Greece',
#  'Moldova',
#  'Liechtenstein',
#  'Belarus',
#  'Luxembourg',
#  'Montenegro, Republic of',
#  'Slovak Republic',
#  'Switzerland',
#  'Armenia',
#  'Austria',
#  'Slovenia']
# >> Number of rows to erase: 750

# %%
# Dropping the values
df.dropna(inplace = True)

# %% [markdown]
# # Adding the "Source Column"
#     Rule: Add the same source to all rows since all data comes from same source

# %%
# Creating the values for the source column
source_column = ["International Transport Forum"] * len(df)

# Adding the column to the dataframe
df.insert(0,"Source", source_column, True)
df
# Out:
#                              Source  Region  \
# 0     International Transport Forum  Canada
# 1     International Transport Forum  Canada
# 2     International Transport Forum  Canada
# 3     International Transport Forum  Canada
# 4     International Transport Forum  Canada
# ...                             ...     ...
# 1428  International Transport Forum  Turkey
# 1429  International Transport Forum  Turkey
# 1430  International Transport Forum  Turkey
# 1431  International Transport Forum  Turkey
# 1432  International Transport Forum  Turkey
#
#                                    Variable  Year               Unit  \
# 0     Coastal shipping (national transport)  1995  Tonnes-kilometres
# 1     Coastal shipping (national transport)  1996  Tonnes-kilometres
# 2     Coastal shipping (national transport)  1997  Tonnes-kilometres
# 3     Coastal shipping (national transport)  1998  Tonnes-kilometres
# 4     Coastal shipping (national transport)  1999  Tonnes-kilometres
# ...                                     ...   ...                ...
# 1428  Coastal shipping (national transport)  2014  Tonnes-kilometres
# 1429  Coastal shipping (national transport)  2015  Tonnes-kilometres
# 1430  Coastal shipping (national transport)  2016  Tonnes-kilometres
# 1431  Coastal shipping (national transport)  2017  Tonnes-kilometres
# 1432  Coastal shipping (national transport)  2018  Tonnes-kilometres
#
#      PowerCode    Value
# 0     Millions  10369.0
# 1     Millions  10166.0
# 2     Millions  10735.0
# 3     Millions  13420.0
# 4     Millions  14144.0
# ...        ...      ...
# 1428  Millions  18553.0
# 1429  Millions  19189.0
# 1430  Millions  19492.0
# 1431  Millions  22087.0
# 1432  Millions  21779.0
#
# [829 rows x 7 columns]

# %% [markdown]
# # Adding the "Service" column
#     Rule: Since all the data is associated to "Freight," the Service is "Freight"

# %%
# Creating the values for the source column
service_column = ["Freight"] * len(df)

# Adding the column to the dataframe
df.insert(0,"Service", service_column, True)
df
# Out:
#       Service                         Source  Region  \
# 0     Freight  International Transport Forum  Canada
# 1     Freight  International Transport Forum  Canada
# 2     Freight  International Transport Forum  Canada
# 3     Freight  International Transport Forum  Canada
# 4     Freight  International Transport Forum  Canada
# ...       ...                            ...     ...
# 1428  Freight  International Transport Forum  Turkey
# 1429  Freight  International Transport Forum  Turkey
# 1430  Freight  International Transport Forum  Turkey
# 1431  Freight  International Transport Forum  Turkey
# 1432  Freight  International Transport Forum  Turkey
#
#                                    Variable  Year               Unit  \
# 0     Coastal shipping (national transport)  1995  Tonnes-kilometres
# 1     Coastal shipping (national transport)  1996  Tonnes-kilometres
# 2     Coastal shipping (national transport)  1997  Tonnes-kilometres
# 3     Coastal shipping (national transport)  1998  Tonnes-kilometres
# 4     Coastal shipping (national transport)  1999  Tonnes-kilometres
# ...                                     ...   ...                ...
# 1428  Coastal shipping (national transport)  2014  Tonnes-kilometres
# 1429  Coastal shipping (national transport)  2015  Tonnes-kilometres
# 1430  Coastal shipping (national transport)  2016  Tonnes-kilometres
# 1431  Coastal shipping (national transport)  2017  Tonnes-kilometres
# 1432  Coastal shipping (national transport)  2018  Tonnes-kilometres
#
#      PowerCode    Value
# 0     Millions  10369.0
# 1     Millions  10166.0
# 2     Millions  10735.0
# 3     Millions  13420.0
# 4     Millions  14144.0
# ...        ...      ...
# 1428  Millions  18553.0
# 1429  Millions  19189.0
# 1430  Millions  19492.0
# 1431  Millions  22087.0
# 1432  Millions  21779.0
#
# [829 rows x 8 columns]

# %% [markdown]
# # Adding the "Technology" and "Fuel" columns
#     Rule: The dataset does not provide any data about those two columns, so we added the default value of "All" in both cases.

# %%
# Adding the "Technology" and "Fuel" columns
df["Fuel"] = ["All"]*len(df) 
df["Technology"] = ["All"]*len(df)
df
# Out:
#       Service                         Source  Region  \
# 0     Freight  International Transport Forum  Canada
# 1     Freight  International Transport Forum  Canada
# 2     Freight  International Transport Forum  Canada
# 3     Freight  International Transport Forum  Canada
# 4     Freight  International Transport Forum  Canada
# ...       ...                            ...     ...
# 1428  Freight  International Transport Forum  Turkey
# 1429  Freight  International Transport Forum  Turkey
# 1430  Freight  International Transport Forum  Turkey
# 1431  Freight  International Transport Forum  Turkey
# 1432  Freight  International Transport Forum  Turkey
#
#                                    Variable  Year               Unit  \
# 0     Coastal shipping (national transport)  1995  Tonnes-kilometres
# 1     Coastal shipping (national transport)  1996  Tonnes-kilometres
# 2     Coastal shipping (national transport)  1997  Tonnes-kilometres
# 3     Coastal shipping (national transport)  1998  Tonnes-kilometres
# 4     Coastal shipping (national transport)  1999  Tonnes-kilometres
# ...                                     ...   ...                ...
# 1428  Coastal shipping (national transport)  2014  Tonnes-kilometres
# 1429  Coastal shipping (national transport)  2015  Tonnes-kilometres
# 1430  Coastal shipping (national transport)  2016  Tonnes-kilometres
# 1431  Coastal shipping (national transport)  2017  Tonnes-kilometres
# 1432  Coastal shipping (national transport)  2018  Tonnes-kilometres
#
#      PowerCode    Value Fuel Technology
# 0     Millions  10369.0  All        All
# 1     Millions  10166.0  All        All
# 2     Millions  10735.0  All        All
# 3     Millions  13420.0  All        All
# 4     Millions  14144.0  All        All
# ...        ...      ...  ...        ...
# 1428  Millions  18553.0  All        All
# 1429  Millions  19189.0  All        All
# 1430  Millions  19492.0  All        All
# 1431  Millions  22087.0  All        All
# 1432  Millions  21779.0  All        All
#
# [829 rows x 10 columns]

# %% [markdown]
# # Setting the correct unit name in the "Unit" column
#     Rule: Based on the template, the correct unit for "Fraight Activity" is "10^9 tonne-km / yr", so we will assign those units to the data

# %%
# Dropping the current "Unit" column
df.drop(columns=["Unit"], inplace = True)

# Adding the new "Unit" column
df["Unit"] = ["10^9 tonne-km / yr"]*len(df) 
df
# Out:
#       Service                         Source  Region  \
# 0     Freight  International Transport Forum  Canada
# 1     Freight  International Transport Forum  Canada
# 2     Freight  International Transport Forum  Canada
# 3     Freight  International Transport Forum  Canada
# 4     Freight  International Transport Forum  Canada
# ...       ...                            ...     ...
# 1428  Freight  International Transport Forum  Turkey
# 1429  Freight  International Transport Forum  Turkey
# 1430  Freight  International Transport Forum  Turkey
# 1431  Freight  International Transport Forum  Turkey
# 1432  Freight  International Transport Forum  Turkey
#
#                                    Variable  Year PowerCode    Value Fuel  \
# 0     Coastal shipping (national transport)  1995  Millions  10369.0  All
# 1     Coastal shipping (national transport)  1996  Millions  10166.0  All
# 2     Coastal shipping (national transport)  1997  Millions  10735.0  All
# 3     Coastal shipping (national transport)  1998  Millions  13420.0  All
# 4     Coastal shipping (national transport)  1999  Millions  14144.0  All
# ...                                     ...   ...       ...      ...  ...
# 1428  Coastal shipping (national transport)  2014  Millions  18553.0  All
# 1429  Coastal shipping (national transport)  2015  Millions  19189.0  All
# 1430  Coastal shipping (national transport)  2016  Millions  19492.0  All
# 1431  Coastal shipping (national transport)  2017  Millions  22087.0  All
# 1432  Coastal shipping (national transport)  2018  Millions  21779.0  All
#
#      Technology                Unit
# 0           All  10^9 tonne-km / yr
# 1           All  10^9 tonne-km / yr
# 2           All  10^9 tonne-km / yr
# 3           All  10^9 tonne-km / yr
# 4           All  10^9 tonne-km / yr
# ...         ...                 ...
# 1428        All  10^9 tonne-km / yr
# 1429        All  10^9 tonne-km / yr
# 1430        All  10^9 tonne-km / yr
# 1431        All  10^9 tonne-km / yr
# 1432        All  10^9 tonne-km / yr
#
# [829 rows x 10 columns]

# %% [markdown]
# # Setting the correct magnitude of the "Value" column
#     Rule: The current data is in million. We will convert all values to billions. In which (1M = 0.001B)

# %%
# Removing the "PowerCode" column since it is not necessary
df.drop(columns=["PowerCode"], inplace = True)

# Looping though each row and convert each value to billion magnitude
for index, row in df.iterrows():
    current_value = row.Value
    new_value = current_value * float(0.001)
    df.Value[index] = new_value
df
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       Service                         Source  Region  \
# 0     Freight  International Transport Forum  Canada
# 1     Freight  International Transport Forum  Canada
# 2     Freight  International Transport Forum  Canada
# 3     Freight  International Transport Forum  Canada
# 4     Freight  International Transport Forum  Canada
# ...       ...                            ...     ...
# 1428  Freight  International Transport Forum  Turkey
# 1429  Freight  International Transport Forum  Turkey
# 1430  Freight  International Transport Forum  Turkey
# 1431  Freight  International Transport Forum  Turkey
# 1432  Freight  International Transport Forum  Turkey
#
#                                    Variable  Year   Value Fuel Technology  \
# 0     Coastal shipping (national transport)  1995  10.369  All        All
# 1     Coastal shipping (national transport)  1996  10.166  All        All
# 2     Coastal shipping (national transport)  1997  10.735  All        All
# 3     Coastal shipping (national transport)  1998  13.420  All        All
# 4     Coastal shipping (national transport)  1999  14.144  All        All
# ...                                     ...   ...     ...  ...        ...
# 1428  Coastal shipping (national transport)  2014  18.553  All        All
# 1429  Coastal shipping (national transport)  2015  19.189  All        All
# 1430  Coastal shipping (national transport)  2016  19.492  All        All
# 1431  Coastal shipping (national transport)  2017  22.087  All        All
# 1432  Coastal shipping (national transport)  2018  21.779  All        All
#
#                     Unit
# 0     10^9 tonne-km / yr
# 1     10^9 tonne-km / yr
# 2     10^9 tonne-km / yr
# 3     10^9 tonne-km / yr
# 4     10^9 tonne-km / yr
# ...                  ...
# 1428  10^9 tonne-km / yr
# 1429  10^9 tonne-km / yr
# 1430  10^9 tonne-km / yr
# 1431  10^9 tonne-km / yr
# 1432  10^9 tonne-km / yr
#
# [829 rows x 9 columns]

# %% [markdown]
# # Adding the "Mode" column
#     Rule: Since all the data is about shipping, all rows have "Shipping" as mode

# %%
# Adding the mode columns
df["Mode"] = ["Shipping"]*len(df) 
df
# Out:
#       Service                         Source  Region  \
# 0     Freight  International Transport Forum  Canada
# 1     Freight  International Transport Forum  Canada
# 2     Freight  International Transport Forum  Canada
# 3     Freight  International Transport Forum  Canada
# 4     Freight  International Transport Forum  Canada
# ...       ...                            ...     ...
# 1428  Freight  International Transport Forum  Turkey
# 1429  Freight  International Transport Forum  Turkey
# 1430  Freight  International Transport Forum  Turkey
# 1431  Freight  International Transport Forum  Turkey
# 1432  Freight  International Transport Forum  Turkey
#
#                                    Variable  Year   Value Fuel Technology  \
# 0     Coastal shipping (national transport)  1995  10.369  All        All
# 1     Coastal shipping (national transport)  1996  10.166  All        All
# 2     Coastal shipping (national transport)  1997  10.735  All        All
# 3     Coastal shipping (national transport)  1998  13.420  All        All
# 4     Coastal shipping (national transport)  1999  14.144  All        All
# ...                                     ...   ...     ...  ...        ...
# 1428  Coastal shipping (national transport)  2014  18.553  All        All
# 1429  Coastal shipping (national transport)  2015  19.189  All        All
# 1430  Coastal shipping (national transport)  2016  19.492  All        All
# 1431  Coastal shipping (national transport)  2017  22.087  All        All
# 1432  Coastal shipping (national transport)  2018  21.779  All        All
#
#                     Unit      Mode
# 0     10^9 tonne-km / yr  Shipping
# 1     10^9 tonne-km / yr  Shipping
# 2     10^9 tonne-km / yr  Shipping
# 3     10^9 tonne-km / yr  Shipping
# 4     10^9 tonne-km / yr  Shipping
# ...                  ...       ...
# 1428  10^9 tonne-km / yr  Shipping
# 1429  10^9 tonne-km / yr  Shipping
# 1430  10^9 tonne-km / yr  Shipping
# 1431  10^9 tonne-km / yr  Shipping
# 1432  10^9 tonne-km / yr  Shipping
#
# [829 rows x 10 columns]

# %% [markdown]
# # Adding the column "Vehicle Type"
#     Rule: Since all the data in this dataset is associted to coastal shipping, the vehicle type is "Coastal"

# %%
# Adding the mode columns
df["Vehicle Type"] = ["Coastal"]*len(df) 
df
# Out:
#       Service                         Source  Region  \
# 0     Freight  International Transport Forum  Canada
# 1     Freight  International Transport Forum  Canada
# 2     Freight  International Transport Forum  Canada
# 3     Freight  International Transport Forum  Canada
# 4     Freight  International Transport Forum  Canada
# ...       ...                            ...     ...
# 1428  Freight  International Transport Forum  Turkey
# 1429  Freight  International Transport Forum  Turkey
# 1430  Freight  International Transport Forum  Turkey
# 1431  Freight  International Transport Forum  Turkey
# 1432  Freight  International Transport Forum  Turkey
#
#                                    Variable  Year   Value Fuel Technology  \
# 0     Coastal shipping (national transport)  1995  10.369  All        All
# 1     Coastal shipping (national transport)  1996  10.166  All        All
# 2     Coastal shipping (national transport)  1997  10.735  All        All
# 3     Coastal shipping (national transport)  1998  13.420  All        All
# 4     Coastal shipping (national transport)  1999  14.144  All        All
# ...                                     ...   ...     ...  ...        ...
# 1428  Coastal shipping (national transport)  2014  18.553  All        All
# 1429  Coastal shipping (national transport)  2015  19.189  All        All
# 1430  Coastal shipping (national transport)  2016  19.492  All        All
# 1431  Coastal shipping (national transport)  2017  22.087  All        All
# 1432  Coastal shipping (national transport)  2018  21.779  All        All
#
#                     Unit      Mode Vehicle Type
# 0     10^9 tonne-km / yr  Shipping      Coastal
# 1     10^9 tonne-km / yr  Shipping      Coastal
# 2     10^9 tonne-km / yr  Shipping      Coastal
# 3     10^9 tonne-km / yr  Shipping      Coastal
# 4     10^9 tonne-km / yr  Shipping      Coastal
# ...                  ...       ...          ...
# 1428  10^9 tonne-km / yr  Shipping      Coastal
# 1429  10^9 tonne-km / yr  Shipping      Coastal
# 1430  10^9 tonne-km / yr  Shipping      Coastal
# 1431  10^9 tonne-km / yr  Shipping      Coastal
# 1432  10^9 tonne-km / yr  Shipping      Coastal
#
# [829 rows x 11 columns]

# %% [markdown]
# # Renaming the column "Variable"
#     Rule: There is only one activity being perform in this dataset and that is the "Freight Activity". We are setting, for each row, the variable "Freight Activity"

# %%
# Dropping the current "Variable" column
df.drop(columns=["Variable"], inplace = True)

# Adding the new "Variable" column with the new data
df["Variable"] = ["Freight Activity"]*len(df)

df
# Out:
#       Service                         Source  Region  Year   Value Fuel  \
# 0     Freight  International Transport Forum  Canada  1995  10.369  All
# 1     Freight  International Transport Forum  Canada  1996  10.166  All
# 2     Freight  International Transport Forum  Canada  1997  10.735  All
# 3     Freight  International Transport Forum  Canada  1998  13.420  All
# 4     Freight  International Transport Forum  Canada  1999  14.144  All
# ...       ...                            ...     ...   ...     ...  ...
# 1428  Freight  International Transport Forum  Turkey  2014  18.553  All
# 1429  Freight  International Transport Forum  Turkey  2015  19.189  All
# 1430  Freight  International Transport Forum  Turkey  2016  19.492  All
# 1431  Freight  International Transport Forum  Turkey  2017  22.087  All
# 1432  Freight  International Transport Forum  Turkey  2018  21.779  All
#
#      Technology                Unit      Mode Vehicle Type          Variable
# 0           All  10^9 tonne-km / yr  Shipping      Coastal  Freight Activity
# 1           All  10^9 tonne-km / yr  Shipping      Coastal  Freight Activity
# 2           All  10^9 tonne-km / yr  Shipping      Coastal  Freight Activity
# 3           All  10^9 tonne-km / yr  Shipping      Coastal  Freight Activity
# 4           All  10^9 tonne-km / yr  Shipping      Coastal  Freight Activity
# ...         ...                 ...       ...          ...               ...
# 1428        All  10^9 tonne-km / yr  Shipping      Coastal  Freight Activity
# 1429        All  10^9 tonne-km / yr  Shipping      Coastal  Freight Activity
# 1430        All  10^9 tonne-km / yr  Shipping      Coastal  Freight Activity
# 1431        All  10^9 tonne-km / yr  Shipping      Coastal  Freight Activity
# 1432        All  10^9 tonne-km / yr  Shipping      Coastal  Freight Activity
#
# [829 rows x 11 columns]

# %% [markdown]
# # Reordering the columns
#     Rule: The columns should follow the order established in the latest template

# %%
columnsTitles = ['Source', 'Region', 'Variable','Unit','Service','Mode','Vehicle Type','Technology','Fuel','Value','Year']
df = df.reindex(columns=columnsTitles)
df
# Out:
#                              Source  Region          Variable  \
# 0     International Transport Forum  Canada  Freight Activity
# 1     International Transport Forum  Canada  Freight Activity
# 2     International Transport Forum  Canada  Freight Activity
# 3     International Transport Forum  Canada  Freight Activity
# 4     International Transport Forum  Canada  Freight Activity
# ...                             ...     ...               ...
# 1428  International Transport Forum  Turkey  Freight Activity
# 1429  International Transport Forum  Turkey  Freight Activity
# 1430  International Transport Forum  Turkey  Freight Activity
# 1431  International Transport Forum  Turkey  Freight Activity
# 1432  International Transport Forum  Turkey  Freight Activity
#
#                     Unit  Service      Mode Vehicle Type Technology Fuel  \
# 0     10^9 tonne-km / yr  Freight  Shipping      Coastal        All  All
# 1     10^9 tonne-km / yr  Freight  Shipping      Coastal        All  All
# 2     10^9 tonne-km / yr  Freight  Shipping      Coastal        All  All
# 3     10^9 tonne-km / yr  Freight  Shipping      Coastal        All  All
# 4     10^9 tonne-km / yr  Freight  Shipping      Coastal        All  All
# ...                  ...      ...       ...          ...        ...  ...
# 1428  10^9 tonne-km / yr  Freight  Shipping      Coastal        All  All
# 1429  10^9 tonne-km / yr  Freight  Shipping      Coastal        All  All
# 1430  10^9 tonne-km / yr  Freight  Shipping      Coastal        All  All
# 1431  10^9 tonne-km / yr  Freight  Shipping      Coastal        All  All
# 1432  10^9 tonne-km / yr  Freight  Shipping      Coastal        All  All
#
#        Value  Year
# 0     10.369  1995
# 1     10.166  1996
# 2     10.735  1997
# 3     13.420  1998
# 4     14.144  1999
# ...      ...   ...
# 1428  18.553  2014
# 1429  19.189  2015
# 1430  19.492  2016
# 1431  22.087  2017
# 1432  21.779  2018
#
# [829 rows x 11 columns]

# %% [markdown]
# # Exporting Result - Programming Friendly View

# %%
# Setting the column id for the dataframe
df["ID"] = [data_id] *len(df)

# Exporting results
df.to_csv(raw_data_csv_path+data_id+"_cleaned_PF.csv",index=False)

# %% [markdown]
# # Exporting Result - User Friendly View

# %%
# Get the columns to preserve
columns_to_preserve = ['Source','Region','Variable','Unit','Service','Mode','Vehicle Type','Technology','Fuel']

# Grouping by country
group_by_country = df.groupby(df.Region)

# Getting the list of countries
list_of_countries = list(group_by_country.groups.keys())

# Saving the dict of all the final dataframes of each country
dict_of_final_dataframes_per_country = {}

# For each country, perform the following algorithm
for country in list_of_countries:
    
    # Get the df corresponding to the given country
    df_country_X = group_by_country.get_group(country)
    
    # Get the list of years available for the given year
    list_of_years_for_country_X = list(set(df_country_X["Year"]))

    # Group the data of country X by year
    group_by_year_country_X = df_country_X.groupby(df_country_X.Year)
    
    # Create a structure that will hold the dataframes of each year
    df_per_year_for_country_X = {}
    
    # Obtain the dataframe for each year
    for name, group in group_by_year_country_X:
        df_per_year_for_country_X[name] = group

    # Do the necessary processing required in the DF of each year
    for year in list_of_years_for_country_X:
        
        # Obtain the dataframe for country X in year Y
        df_country_X_in_year_Y = df_per_year_for_country_X[year]
        
        # Renaming and droping columns
        df_country_X_in_year_Y.rename(columns={"Value":year}, inplace = True)
        df_country_X_in_year_Y.drop(columns=["Year"], inplace = True)

    # Concatenating all the dataframes of a given country into a single dataframe
    list_of_all_df_for_country_X = list(df_per_year_for_country_X.values())
    df_concat_all_dfs_for_country_x = pd.concat(list_of_all_df_for_country_X,sort=False, verify_integrity=True,join='outer')

    # Creating the final df for country X by eliminating all NAN and combining rows
    final_df_for_country_x = df_concat_all_dfs_for_country_x.groupby(columns_to_preserve)[list_of_years_for_country_X].first().reset_index()

    # Saving the final df of country X in the list of all countries df
    dict_of_final_dataframes_per_country[country] = final_df_for_country_x

# Concatenate all the dataframes of the countries
list_df_for_all_countries_final = list(dict_of_final_dataframes_per_country.values())
df_with_all_countries_data = pd.concat(list_df_for_all_countries_final,sort=False, verify_integrity=True,join='outer',ignore_index=True)

# Setting the column id for the dataframe
df_with_all_countries_data["ID"] = [data_id] *len(df_with_all_countries_data)

# Exporting the final dataframe
df_with_all_countries_data.to_csv(raw_data_csv_path+data_id+"_cleaned_UF.csv",index=False)
