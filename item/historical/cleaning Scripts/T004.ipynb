# %%
import pandas as pd
from pprint import pprint

# %%
# Creating a dataframe from the csv data
data_id = "T002"
raw_data_csv_path = "/Users/hlinero/Desktop/iTEM Material/raw dataset/T004/"
df = pd.read_csv(raw_data_csv_path+"T004_unece_new_road_vehicle.csv")
df
# Out:
#      Fuel Type                        Type of Vehicle         Country 1993  \
# 0        Total  New lorries (vehicle wt over 3500 kg)         Albania   ..
# 1        Total  New lorries (vehicle wt over 3500 kg)         Andorra   ..
# 2        Total  New lorries (vehicle wt over 3500 kg)         Armenia   ..
# 3        Total  New lorries (vehicle wt over 3500 kg)         Austria   ..
# 4        Total  New lorries (vehicle wt over 3500 kg)      Azerbaijan   ..
# ...        ...                                    ...             ...  ...
# 5035    #NAME?                      New road tractors    Turkmenistan   ..
# 5036    #NAME?                      New road tractors         Ukraine   ..
# 5037    #NAME?                      New road tractors  United Kingdom   ..
# 5038    #NAME?                      New road tractors   United States   ..
# 5039    #NAME?                      New road tractors      Uzbekistan   ..
#
# ...

# %%
df.tail(50)
# Out:
#      Fuel Type    Type of Vehicle                 Country 1993 1994 1995 1996  \
# 4990    #NAME?  New road tractors                 Belgium   ..   ..   ..   ..
# 4991    #NAME?  New road tractors  Bosnia and Herzegovina   ..   ..   ..   ..
# 4992    #NAME?  New road tractors                Bulgaria   ..   ..   ..   ..
# 4993    #NAME?  New road tractors                  Canada   ..   ..   ..   ..
# 4994    #NAME?  New road tractors                 Croatia   ..   ..   ..   ..
# 4995    #NAME?  New road tractors                  Cyprus   ..   ..   ..   ..
# 4996    #NAME?  New road tractors                 Czechia   ..   ..   ..   ..
# 4997    #NAME?  New road tractors                 Denmark   ..   ..   ..   ..
# 4998    #NAME?  New road tractors                 Estonia   ..   ..   ..   ..
# 4999    #NAME?  New road tractors                 Finland   ..   ..   ..   ..
# 5000    #NAME?  New road tractors                  France   ..   ..   ..   ..
# ...
